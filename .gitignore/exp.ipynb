# %%
pip install requests
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.12.14-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl (102 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.2.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.0-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
# import lxml
import re
import pandas as pd

# %%
url = "https://www.jumia.co.ke/catalog/?q=phones"

# %%
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html><html lang="en" dir="ltr"><head><meta charset="utf-8"/><title> Shop &amp; Buy Online | Jumia Kenya</title><meta property="og:type" content="product"/><meta property="og:site_name" content="Jumia Kenya"/><meta property="og:title" content=" Shop &amp; Buy Online | Jumia Kenya"/><meta property="og:url" content="/catalog/"/><meta property="og:image" content="https://ke.jumia.is/cms/icons/jumialogo-x-4.png"/><meta property="og:locale" content="en_KE"/><meta name="title" content=" Shop &amp; Buy Online | Jumia Kenya"/><meta name="robots" content="noindex,follow"/><link rel="alternate" href="android-app://com.jumia.android/JUMIA/KE/s/phones?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.co.ke%2Fcatalog%2F%3Fq%3Dphones"/><link rel="canonical" href="https://www.jumia.co.ke/catalog/"/><link rel="next" href="https://www.jumia.co.ke/catalog/?q=phones&amp;page=2"/><meta property="fb:app
# ...

# %%
soup = BeautifulSoup(r.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Shop &amp; Buy Online | Jumia Kenya
#   </title>
#   <meta content="product" property="og:type"/>
#   <meta content="Jumia Kenya" property="og:site_name"/>
#   <meta content=" Shop &amp; Buy Online | Jumia Kenya" property="og:title"/>
#   <meta content="/catalog/" property="og:url"/>
#   <meta content="https://ke.jumia.is/cms/icons/jumialogo-x-4.png" property="og:image"/>
#   <meta content="en_KE" property="og:locale"/>
#   <meta content=" Shop &amp; Buy Online | Jumia Kenya" name="title"/>
#   <meta content="noindex,follow" name="robots"/>
#   <link href="android-app://com.jumia.android/JUMIA/KE/s/phones?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.co.ke%2Fcatalog%2F%3Fq%3Dphones" rel="alternate"/>
#   <link href="https://www.jumia.co.ke/catalog/" rel="canonical"/>
# ...

# %%
print(soup.ul.prettify())
# Out:
# <ul class="-lsn">
#  <li>
#   <a class="_link -pbxs" href="https://www.jumia.co.ke/help/">
#    Help Center
#   </a>
#  </li>
#  <li>
#   <a class="_link -pbxs" href="https://www.jumia.co.ke/sp-contact/">
#    Contact Us
#   </a>
#  </li>
# </ul>

# %%
tags = soup.div
print(tags.prettify())
# Out:
# <div id="jm">
#  <div class="banner" data-bnrid="101" data-end="2024-12-31T11:42:00+03:00" style="background:#1EAD77;">
#   <div class="row _no-go -phs">
#    <a class="col16 ar _1168-56" data-ga4-creative_name="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" data-ga4-creative_slot="banner_top" data-ga4-promotion_id="catalog_searchResults_STB_FDY2020_GEN" data-ga4-promotion_name="STB_FDY2020_GEN" data-gtm-creative="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" data-gtm-id="catalog_searchResults_STB_FDY2020_GEN" data-gtm-name="STB_FDY2020_GEN" data-gtm-position="banner_top" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="/mlp-krisi-na-jumia/?source=MSTB_FDY2020_GEN">
#     <img alt="STB_FDY2020_GEN" class="_ni" data-lazy="true" data-src="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" src="..."/>
#    </a>
#   </div>
#  </div>
#  <div class="vb row -i-ctr -j-ctr _head -bg-gy05">
# ...

# %%
#attributes
print(tags.attrs)
# Out:
# {'id': 'jm'}

# %%
headers = soup.header
print(headers.attrs)
# Out:
# {'class': ['header']}

# %%
print(soup.div.p.string)
# Out:
# None

# %%
print(soup.header.div.div.a.button)
# Out:
# None

# %%
soup.find('div')
# Out:
# <div id="jm"><div class="banner" data-bnrid="101" data-end="2024-12-31T11:42:00+03:00" style="background:#1EAD77;"><div class="row _no-go -phs"><a class="col16 ar _1168-56" data-ga4-creative_name="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" data-ga4-creative_slot="banner_top" data-ga4-promotion_id="catalog_searchResults_STB_FDY2020_GEN" data-ga4-promotion_name="STB_FDY2020_GEN" data-gtm-creative="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" data-gtm-id="catalog_searchResults_STB_FDY2020_GEN" data-gtm-name="STB_FDY2020_GEN" data-gtm-position="banner_top" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="/mlp-krisi-na-jumia/?source=MSTB_FDY2020_GEN"><img alt="STB_FDY2020_GEN" class="_ni" data-lazy="true" data-src="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" src="..."/></a></div></div><div class="vb row -i-ctr -j-ctr _head -bg-gy05"><div class="col3 -df -j-start"><a class="_link -d
# ...

# %%
price = soup.find("div", {"class": "prc"})
print(price)
print(price.string)
# Out:
# <div class="prc">KSh 8,999</div>
# KSh 8,999

# %%
price = soup.find("div", class_ = "prc")
print(price.string)
# Out:
# KSh 8,999

# %%
desc = soup.find("h3", class_ = "name")
print(desc.string)
# Out:
# XIAOMI Redmi A3, 6.71", 3GB RAM + 64GB (Dual SIM), 5000mAh, Star Blue (2YRs WRTY)

# %%
prices = soup.find_all('div', class_ = 'prc')
print(prices)

price_values = []
for i in prices:
    price_values.append(i.string)

print(price_values)
# Out:
# [<div class="prc">KSh 8,999</div>, <div class="prc">KSh 9,999</div>, <div class="prc">KSh 12,999</div>, <div class="prc">KSh 13,599</div>, <div class="prc">KSh 13,999</div>, <div class="prc">KSh 18,999</div>, <div class="prc">KSh 13,192</div>, <div class="prc">KSh 699</div>, <div class="prc">KSh 9,200</div>, <div class="prc">KSh 11,285</div>, <div class="prc">KSh 9,200</div>, <div class="prc">KSh 11,599</div>, <div class="prc">KSh 11,599</div>, <div class="prc">KSh 18,849</div>, <div class="prc">KSh 8,999</div>, <div class="prc">KSh 990</div>, <div class="prc">KSh 10,999</div>, <div class="prc">KSh 11,290</div>, <div class="prc">KSh 22,389</div>, <div class="prc">KSh 11,399</div>, <div class="prc">KSh 9,200</div>, <div class="prc">KSh 1,849</div>, <div class="prc">KSh 12,999</div>, <div class="prc">KSh 13,850</div>, <div class="prc">KSh 9,299</div>, <div class="prc">KSh 9,500</div>, <div class="prc">KSh 12,999</div>, <div class="prc">KSh 4,690</div>, <div class="prc">KSh 1,118</div>,
# ...

# %%
old_prices = soup.find_all("div", class_ = "old")
print(old_prices)

older_prices = []

for i in old_prices:
    older_prices.append(i.string)

print(older_prices)
# Out:
# [<div class="old">KSh 11,000</div>, <div class="old">KSh 12,000</div>, <div class="old">KSh 15,000</div>, <div class="old">KSh 23,000</div>, <div class="old">KSh 14,999</div>, <div class="old">KSh 23,000</div>, <div class="old">KSh 15,999</div>, <div class="old">KSh 1,200</div>, <div class="old">KSh 10,000</div>, <div class="old">KSh 14,999</div>, <div class="old">KSh 10,000</div>, <div class="old">KSh 14,280</div>, <div class="old">KSh 14,280</div>, <div class="old">KSh 18,999</div>, <div class="old">KSh 10,500</div>, <div class="old">KSh 1,500</div>, <div class="old">KSh 14,999</div>, <div class="old">KSh 19,888</div>, <div class="old">KSh 35,000</div>, <div class="old">KSh 19,999</div>, <div class="old">KSh 10,000</div>, <div class="old">KSh 2,500</div>, <div class="old">KSh 19,999</div>, <div class="old">KSh 25,000</div>, <div class="old">KSh 17,183</div>, <div class="old">KSh 12,000</div>, <div class="old">KSh 15,000</div>, <div class="old">KSh 9,000</div>, <div class="old">KSh 
# ...

# %%
desc = soup.find_all("h3", class_ = 'name')
print(desc)

# for i in desc:
#     print(i.string)

print(len(desc))
# Out:
# [<h3 class="name">XIAOMI Redmi A3, 6.71", 3GB RAM + 64GB (Dual SIM), 5000mAh, Star Blue (2YRs WRTY)</h3>, <h3 class="name">XIAOMI Redmi A3x, 6.71", 128GB + 4GB RAM (Dual SIM), 5000mAh, Black ( 2YRs WRTY)</h3>, <h3 class="name">XIAOMI Redmi 14C, 6.88" (4GB RAM+128GB Storage) (Dual Sim) 5160mAh - Starry Blue (2YRs WRTY)</h3>, <h3 class="name">Itel S23+ 6.78", 128GB + 4GB RAM, 50MP Camera, (Dual SIM), 4G, 5000mAh - Energetic Orange</h3>, <h3 class="name">Tecno Spark 30c, 6.67'' HD+, UP to 128GB ROM+ 4GB RAM +(4GB RAM Extended)  (Dual Sim) 50MP, 5000 mAh - Orbit Black</h3>, <h3 class="name">XIAOMI Redmi 13 6.79'' 8GB+256GB Dual SIM, 4G, 5030 MAh - Ocean Blue (2YRS WRTY)</h3>, <h3 class="name">Oppo A3X, 6.67", 64GB + 4GB RAM, 4G LTE, 45W Flash Charge (Dual SIM) 5,100 MAh - Nebula Red</h3>, <h3 class="name">VILLAON V101 177" Kabambe, Wireless FM, Camera, Bright Touch, Facebook, 1000mAh (Dual Sim)</h3>, <h3 class="name">Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Android 13 (Dual sim) 5000mAh
# ...

# %%
data = soup.find_all(["h4", "a", "p"])
print(data)
# Out:
# [<a class="col16 ar _1168-56" data-ga4-creative_name="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" data-ga4-creative_slot="banner_top" data-ga4-promotion_id="catalog_searchResults_STB_FDY2020_GEN" data-ga4-promotion_name="STB_FDY2020_GEN" data-gtm-creative="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" data-gtm-id="catalog_searchResults_STB_FDY2020_GEN" data-gtm-name="STB_FDY2020_GEN" data-gtm-position="banner_top" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="/mlp-krisi-na-jumia/?source=MSTB_FDY2020_GEN"><img alt="STB_FDY2020_GEN" class="_ni" data-lazy="true" data-src="https://ke.jumia.is/cms/2024/W49/KE_ONS_Krisi24_Generic_1224_STB_rvsd.gif" src="..."/></a>, <a class="_link -df -i-ctr -or5 -m -fs12" href="https://www.jumia.co.ke/sp-sell/" rel="noopener" target="_blank"><svg class="ic -f-or5 -maxs" height="16" viewbox="0 0 24 24" width="16"><use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.
# ...

# %%
soup.find_all(string = "Samsung Galaxy A23 128 GB HDD - 4 GB RAM - Black")
# Out:
# []

# %%
soup.find_all(string = re.compile("Galaxy"))
# Out:
# ["Samsung Galaxy A05, 6.7'' 4GB RAM + 64GB ROM (Dual Sim) 50MP Camera, 5000mAh - Black",
#  "Samsung Galaxy A05, 6.7''  4GB RAM + 64GB ROM (Dual Sim) 50MP Camera, 5000mAh - Black",
#  'Samsung Galaxy A52 5G 128 GB HDD- 6GB RAM - Awesome White',
# ...

# %%
desc = soup.find_all("h3", class_ = "name")
description = []
for i in desc:
    print(i.string)
    description.append(i)

print(description)
# print(desc)
# Out:
# XIAOMI Redmi A3, 6.71", 3GB RAM + 64GB (Dual SIM), 5000mAh, Star Blue (2YRs WRTY)
# XIAOMI Redmi A3x, 6.71", 128GB + 4GB RAM (Dual SIM), 5000mAh, Black ( 2YRs WRTY)
# XIAOMI Redmi 14C, 6.88" (4GB RAM+128GB Storage) (Dual Sim) 5160mAh - Starry Blue (2YRs WRTY)
# Itel S23+ 6.78", 128GB + 4GB RAM, 50MP Camera, (Dual SIM), 4G, 5000mAh - Energetic Orange
# Tecno Spark 30c, 6.67'' HD+, UP to 128GB ROM+ 4GB RAM +(4GB RAM Extended)  (Dual Sim) 50MP, 5000 mAh - Orbit Black
# XIAOMI Redmi 13 6.79'' 8GB+256GB Dual SIM, 4G, 5030 MAh - Ocean Blue (2YRS WRTY)
# Oppo A3X, 6.67", 64GB + 4GB RAM, 4G LTE, 45W Flash Charge (Dual SIM) 5,100 MAh - Nebula Red
# VILLAON V101 177" Kabambe, Wireless FM, Camera, Bright Touch, Facebook, 1000mAh (Dual Sim)
# Infinix Smart 8 6.6" HD, 2GB RAM + 64GB , Android 13 (Dual sim) 5000mAh - Timber Black
# Samsung Galaxy A05, 6.7'' 4GB RAM + 64GB ROM (Dual Sim) 50MP Camera, 5000mAh - Black
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
url = "https://www.jumia.co.ke/phones-tablets/"

r = requests.get(url)

# %%
soup = BeautifulSoup(r.text, "html.parser")

# %%
names = soup.find_all("div", class_ = "name")
print(names)

products = []
for i in names:
    products.append(i.string)

print(products)
len(products)
# Out:
# [<div class="name">XIAOMI Redmi A3, 6.71", 3GB RAM + 64GB (Dual SIM), 5000mAh, Star Blue (2YRs WRTY)</div>, <div class="name">Samsung Galaxy A05, 6.7'' 4GB RAM + 64GB ROM (Dual Sim) 50MP Camera, 5000mAh - Black</div>, <div class="name">Poco C75, 6.88", 128GB + 6GB RAM (Dual SIM), 5160mAh, Black (2YRs WRTY)</div>, <div class="name">XIAOMI Redmi A3x, 6.71", 64GB + 3GB RAM (Dual SIM) 5000mAh, Green ( 2YRs WRTY)</div>, <div class="name">Vivo V40 Lite-  6.67,-  8GB + 256 GB ROM -(Dual SIM) -5000 MAh- Emerald Green- (2YRs WRTY)</div>, <div class="name">Blackview Wave 6C, 6.5", 2GB RAM + 32GB (Dual SIM), 8MP Camera, 5100mAh Battery - 4G, Black.</div>, <div class="name">XIAOMI A3 Pro, 6.88", 4GB RAM + 128GB (Dual Sim), 5160mAH,Midnight Black (2YRs WRTY)</div>, <div class="name">Itel A60s, 6.6", 128GB + 4GB RAM, Dual SIM, 5000mAh, 4G -?Glacier Green (1YR WRTY)</div>, <div class="name">Itel S23+ 6.78", 128GB + 4GB RAM, 50MP Camera, (Dual SIM), 4G, 5000mAh - Energetic Orange</div>, <div class="
# ...

# %%
prices = soup.find_all("div", class_ = "prc")
item_prices = []

for i in prices:
    item_prices.append(i.string)



print(item_prices)
print(len(item_prices))
# Out:
# ['KSh 8,999', 'KSh 11,285', 'KSh 13,580', 'KSh 8,999', 'KSh 36,999', 'KSh 12,999', 'KSh 11,599', 'KSh 9,500', 'KSh 13,599', 'KSh 12,600', 'KSh 9,200', 'KSh 13,192', 'KSh 2,699', 'KSh 1,199', 'KSh 899', 'KSh 2,999', 'KSh 2,299', 'KSh 2,699', 'KSh 999', 'KSh 2,499', 'KSh 3,199', 'KSh 3,499', 'KSh 999', 'KSh 2,099', 'KSh 1,269', 'KSh 1,199', 'KSh 999', 'KSh 13,599', 'KSh 11,999', 'KSh 12,660', 'KSh 9,500', 'KSh 12,600', 'KSh 5,277', 'KSh 8,999', 'KSh 11,599', 'KSh 12,999', 'KSh 9,948', 'KSh 11,285', 'KSh 8,999', 'KSh 11,599', 'KSh 5,299', 'KSh 9,999', 'KSh 3,000', 'KSh 699', 'KSh 1,299', 'KSh 1,790', 'KSh 1,499', 'KSh 1,399', 'KSh 1,680', 'KSh 2,990', 'KSh 1,000', 'KSh 1,800', 'KSh 1,599', 'KSh 2,290', 'KSh 1,299', 'KSh 1,650', 'KSh 2,250 - KSh 2,699', 'KSh 7,999', 'KSh 7,870', 'KSh 11,199', 'KSh 9,499', 'KSh 18,999', 'KSh 29,999', 'KSh 6,999', 'KSh 34,400', 'KSh 7,662', 'KSh 57,999', 'KSh 7,663', 'KSh 54,999', 'KSh 8,000', 'KSh 4,966', 'KSh 8,999', 'KSh 12,999', 'KSh 13,599', 'KSh 13,9
# ...

# %%
#converting to a dataframe
#data = pd.DataFrame({"products":products, "prices":item_prices})
#data

#converting to a csv
#data.to_csv("jumia_phones.csv")

#pip install openpyxl
#data.to_excel("jumia_phones.xlsx")

# %%
url = "https://www.jumia.co.ke/phones-tablets/"

r = requests.get(url)
print(r)
soup = BeautifulSoup(r.text, "html.parser")
boxes = soup.find_all("article", class_ = "prd _box col _hvr")
print(boxes)
print(len(boxes))
a = soup.find("a").text
print(a)
# Out:
# <Response [200]>
# ...

# %%
#Note that you can also add the ID together with the tag and class.

url = "https://www.jumia.co.ke/phones-tablets/"

r = requests.get(url)

soup = BeautifulSoup(r.text, "html.parser")

p = soup.find_all("div", class_ = "prc", id = "data-oprc")
print(p)
# Out:
# []

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://finance.yahoo.com/quote/AAPL/"
r = requests.get(url)
print(r)

soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("")
# Out:
# <Response [200]>

# %%
import requests

url = "https://www.nasdaq.com/market-activity/stocks/aapl/historical"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

r = requests.get(url, headers=headers)
print(r)

soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("table", class_ = "jupiter22-c-skeleton jupiter22-c-skeleton--table-loader jupiter22-c-skeleton-size--xs __skeleton-container")

headers = table.find_all("th")

titles = []
for i in headers:
    titles.append(i.text)

print(titles)

df=pd.DataFrame(columns = titles)
print(df)

rows = table.find_all("tr")
print(rows)

for i in rows[1:]:
    data = i.find_all("tr")
    row = [tr.text for tr in data]
    print(row)
    l = len(df)
    df.loc[l] = row


df.to_csv("stock_data.csv")
# Out:
# <Response [200]>
# ['\n\n\n']
# Empty DataFrame
# Columns: [
#
#
# ]
# Index: []
# [<tr>
# <th class="col1" colspan="">
# <span>
# </span>
# </th>
# </tr>, <tr>
# <td class="col-first" colspan="">
# <span class="span1"></span>
# <span class="span1"></span>
# </td>
# </tr>, <tr>
# <td class="col-first" colspan="">
# <span class="span1"></span>
# <span class="span1"></span>
# </td>
# </tr>, <tr>
# <td class="col-first" colspan="">
# <span class="span1"></span>
# <span class="span1"></span>
# </td>
# </tr>, <tr>
# <td class="col-first" colspan="">
# <span class="span1"></span>
# <span class="span1"></span>
# </td>
# </tr>, <tr>
# <td class="col-first" colspan="">
# <span class="span1"></span>
# <span class="span1"></span>
# </td>
# </tr>, <tr>
# <td class="col-first" colspan="">
# <span class="span1"></span>
# <span class="span1"></span>
# </td>
# </tr>, <tr>
# <td class="col-first" colspan="">
# <span class="span1"></span>
# <span class="span1"></span>
# </td>
# </tr>, <tr>
# ...

# %%
np = soup.find("")

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.jumia.co.ke/mobile-phones/"

r = requests.get(url)
print(r)

soup = BeautifulSoup(r.text, "html.parser")
# print(soup)

np = soup.find("a", class_ = "pg").get("href")
print(np)

cnp = "https://www.jumia.co.ke/" +np 
print(cnp)

url = cnp
r = requests.get(url)
print(r)
# Out:
# <Response [200]>
# /mobile-phones/?page=2#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=2#catalog-listing
# <Response [200]>

# %%
np = soup.find("a", class_ = "pg").get("href")
print(np)

cnp = "https://www.jumia.co.ke/" +np 
print(cnp)

url = cnp
r = requests.get(cnp)
soup = BeautifulSoup(r.text, "html.parser")
# Out:
# /mobile-phones/
# https://www.jumia.co.ke//mobile-phones/

# %%
for i in range(2,50):
    url = "https://www.jumia.co.ke//mobile-phones/?page=" + str(i) +"#catalog-listing"
    # print(url)
    r = requests.get(url)
    # print(r)
    print(url)
    soup = BeautifulSoup(r.text, "html.parser")
# Out:
# https://www.jumia.co.ke//mobile-phones/?page=2#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=3#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=4#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=5#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=6#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=7#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=8#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=9#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=10#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=11#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=12#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=13#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=14#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=15#catalog-listing
# https://www.jumia.co.ke//mobile-phones/?page=16#catalog-listing
# ...

# %%
url = "https://www.jumia.co.ke//mobile-phones/?page=2#catalog-listing"
r = requests.get(url)
print(r.status_code)

soup = BeautifulSoup(r.text, 'html.parser')

reviews = soup.find_all("div", class_ = "stars _s")

reviewss = []
for rev in reviews:
    revs = rev.text.strip()
    reviewss.append(rev)

print(reviewss)
# Out:
# 200
# ...
