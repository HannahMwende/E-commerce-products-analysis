# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def web_scraping_jumia_microwaves(url):

    descriptions = []
    prices = []
    older_prices = []
    reviews_list = []


    r = requests.get(url)
    print(f"Fetching data from {url} Status {r}")

    if r.status_code == 200:
        soup = BeautifulSoup(r.text, "html.parser")

        # Extract product prices
        price_elements = soup.find_all("div", {"class": "prc"})
        for price_element in price_elements:
            prices.append(price_element.text.strip())

        # Extract old prices
        old_price_elements = soup.find_all("div", class_="old")
        for old_price_element in old_price_elements:
            older_prices.append(old_price_element.text.strip())

        # Extract product descriptions
        desc_elements = soup.find_all("h3", class_="name")
        for desc_element in desc_elements:
            descriptions.append(desc_element.text.strip())

        # Extract reviews
        reviews = soup.find_all("div", class_="in")
        for rev in reviews:
            reviews_list.append(rev.text.strip())
    else:
        print(f"Failed to fetch data from {first_page_url}")
    

    rows = list(zip(descriptions, prices, older_prices, reviews_list))
    return rows

# %%
def collect_data_microwaves():
    data = web_scraping_jumia_microwaves(url)

    df = pd.DataFrame(data, columns = ['descriptions', 'price', 'old_price', 'ratings'])

    df.to_csv("jumia_microwaves.csv", index = False)

# %%
url = "https://www.jumia.co.ke/small-appliances-microwave/"

# %%
web_scraping_jumia_microwaves(url)
# Out:
# Fetching data from https://www.jumia.co.ke/small-appliances-microwave/ Status <Response [200]>
# [('Ramtons RM/458 - Digital Glass Microwave, 700W - 20L -Black & Silver',
#   'KSh 18,200',
#   'KSh 11,800',
#   ''),
#  ('Nunix Digital Microwave Oven 20L WITH GRILL',
#   'KSh 10,395',
#   'KSh 11,080',
#   ''),
#  ('Nunix  3 IN 1 BREAKFAST MAKER, TOASTER,OVEN, COFFEE MAKER',
#   'KSh 14,200',
#   'KSh 12,000',
#   ''),
#  ('Ramtons RM/684-25 LITERS MICROWAVE+GRILL (1YR WRTY)',
#   'KSh 7,779',
#   'KSh 16,390',
#   ''),
#  ('Mika MMWMSKH2012B - Microwave, 20L, Manual - Black',
#   'KSh 8,499',
#   'KSh 9,999',
#   ''),
#  ('Nunix 20L Electric Oven With Grill (3 Knobs)',
#   'KSh 8,500',
#   'KSh 9,500',
#   ''),
#  ('Nunix 20L Electric Rotisserie Oven', 'KSh 8,200', 'KSh 8,000', ''),
#  ('Mika MMWMSKH2011W - Microwave, 20L, Manual - White',
#   'KSh 7,799',
#   'KSh 956',
#   ''),
#  ('Nunix  20L Electric Rotisserie Oven, 1280W',
#   'KSh 14,650',
#   'KSh 20,000',
#   ''),
#  ('Baking Gloves Anti-Scalding Microwave Oven Gloves Heat',
#   'KSh 9,399',
#   'KSh 18,999',
#   ''),
#  ('Hisense 20L Digital Microwave oven', 'KSh 18,130', 'KSh 19,999', ''),
#  ('Nunix 20L Digital Electric Microwave Oven WITH GRILL',
#   'KSh 11,450',
#   'KSh 19,000',
#   ''),
#  ('Nunix Digital Microwave with Grill, 20L', 'KSh 12,990', 'KSh 8,000', ''),
#  ('Nunix Digital Microwave Oven 20L With Grill',
#   'KSh 7,695',
#   'KSh 16,000',
#   '')]

# %%
collect_data_microwaves()
# Out:
# Fetching data from https://www.jumia.co.ke/small-appliances-microwave/ Status <Response [200]>

# %%
data = pd.read_csv("jumia_microwaves.csv")
data.head(14)
# Out:
#                                          descriptions       price   old_price  \
# 0   Ramtons RM/458 - Digital Glass Microwave, 700W...  KSh 18,200  KSh 11,800
# 1         Nunix Digital Microwave Oven 20L WITH GRILL  KSh 10,395  KSh 11,080
# 2   Nunix  3 IN 1 BREAKFAST MAKER, TOASTER,OVEN, C...  KSh 14,200  KSh 12,000
# 3   Ramtons RM/684-25 LITERS MICROWAVE+GRILL (1YR ...   KSh 7,779  KSh 16,390
# 4   Mika MMWMSKH2012B - Microwave, 20L, Manual - B...   KSh 8,499   KSh 9,999
# 5        Nunix 20L Electric Oven With Grill (3 Knobs)   KSh 8,500   KSh 9,500
# 6                  Nunix 20L Electric Rotisserie Oven   KSh 8,200   KSh 8,000
# 7   Mika MMWMSKH2011W - Microwave, 20L, Manual - W...   KSh 7,799  KSh 19,999
# 8          Nunix  20L Electric Rotisserie Oven, 1280W  KSh 14,650  KSh 20,000
# 9             Nunix Digital Microwave with Grill, 20L   KSh 9,399  KSh 19,000
# 10                 Hisense 20L Digital Microwave oven  KSh 18,130  KSh 18,999
# 11        Nunix Digital Microwave Oven 20L With Grill  KSh 11,450  KSh 16,000
# 12  Nunix 20L Digital Electric Microwave Oven WITH...  KSh 12,990   KSh 8,000
# 13                         Nunix manual microwave 20l   KSh 7,695  KSh 13,999
#
#     ratings
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
