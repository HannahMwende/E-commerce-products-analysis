# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def web_scraping_jumia_microwaves(url, baseurl):

    descriptions = []
    prices = []
    older_prices = []
    reviews_list = []
    urls = []

    r = requests.get(url)
    print(f"Fetching data from {url} Status {r}")

    if r.status_code == 200:
        soup = BeautifulSoup(r.text, "html.parser")

        # Extract product prices
        price_elements = soup.find_all("div", {"class": "prc"})
        for price_element in price_elements:
            prices.append(price_element.text.strip())

        # Extract old prices
        old_price_elements = soup.find_all("div", class_="old")
        for old_price_element in old_price_elements:
            older_prices.append(old_price_element.text.strip())

        # Extract product descriptions
        desc_elements = soup.find_all("h3", class_="name")
        for desc_element in desc_elements:
            descriptions.append(desc_element.text.strip())

        # Extract reviews
        reviews = soup.find_all("div", class_="stars _s")
        for rev in reviews:
            reviews_list.append(rev.text.strip())

        products = soup.find_all('a', class_='core')

        for product in products:
                # Extract product link
                link = product['href'] if 'href' in product.attrs else None
                # Complete the URL if the link is relative
                link = f"https://www.jumia.co.ke{link}" if link and link.startswith('/') else link
                urls.append(link)
    else:
        print(f"Failed to fetch data from {url}")
    
    for i in range(2, 51):
        page_url = f"{baseurl}{i}#catalog-listing"
        r = requests.get(page_url)
        print(f"Fetching data from: {page_url} - Status: {r.status_code}")
    
        if r.status_code == 200:
            soup = BeautifulSoup(r.text, "html.parser")

        # Extract product prices
        price_elements = soup.find_all("div", {"class": "prc"})
        for price_element in price_elements:
            prices.append(price_element.text.strip())

        # Extract old prices
        old_price_elements = soup.find_all("div", class_="old")
        for old_price_element in old_price_elements:
            older_prices.append(old_price_element.text.strip())

        # Extract product descriptions
        desc_elements = soup.find_all("h3", class_="name")
        for desc_element in desc_elements:
            descriptions.append(desc_element.text.strip())

        # Extract reviews
        reviews = soup.find_all("div", class_="stars _s")
        for rev in reviews:
            reviews_list.append(rev.text.strip())
        

        
        products = soup.find_all('a', class_='core')

        for product in products:
                # Extract product link
                link = product['href'] if 'href' in product.attrs else None
                # Complete the URL if the link is relative
                link = f"https://www.jumia.co.ke{link}" if link and link.startswith('/') else link
                urls.append(link)
                
    else:
        print(f"Failed to fetch data from {page_url}")

    rows = list(zip(descriptions, prices, older_prices, reviews_list, urls))
    return rows

# %%
def collect_data_microwaves():
    data = web_scraping_jumia_microwaves(url, baseurl)

    df = pd.DataFrame(data, columns = ['descriptions', 'price', 'old_price', 'ratings', 'urls'])

    df.to_csv(r"..\data\scraped_data\jumia_scraped_microwaves.csv", index = False)

# %%
url = "https://www.jumia.co.ke/small-appliances-microwave/"
# baseurl = "https://www.jumia.co.ke/catalog/?q=microwaves&amp;page="
baseurl = "https://www.jumia.co.ke/catalog/?q=microwaves&page="

# %%
web_scraping_jumia_microwaves(url, baseurl)
# Out:
# Fetching data from https://www.jumia.co.ke/small-appliances-microwave/ Status <Response [200]>
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=2#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=3#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=4#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=5#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=6#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=7#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=8#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=9#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=10#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=11#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=12#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=13#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=14#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=15#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=16#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=17#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=18#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=19#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=20#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=21#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=22#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=23#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=24#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=25#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=26#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=27#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=28#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=29#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=30#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=31#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=32#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=33#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=34#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=35#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=36#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=37#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=38#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=39#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=40#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=41#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=42#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=43#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=44#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=45#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=46#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=47#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=48#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=49#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=50#catalog-listing - Status: 200
# Failed to fetch data from https://www.jumia.co.ke/catalog/?q=microwaves&page=50#catalog-listing
# [('Ramtons RM/458 - Digital Glass Microwave, 700W - 20L -Black & Silver',
#   'KSh 19,999',
#   'KSh 11,800',
#   '4.6 out of 5',
#   'https://www.jumia.co.ke/hisense-30l-microwave-2yrs-wrty-129537441.html'),
#  ('Nunix Digital Microwave Oven 20L WITH GRILL',
#   'KSh 9,999',
#   'KSh 11,080',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/haier-hmw20dbm-digital-microwave-oven-700w-20l-black-95922981.html'),
#  ('Nunix 20L Electric Oven With Grill (3 Knobs)',
#   'KSh 15,200',
#   'KSh 9,999',
#   '4.2 out of 5',
#   'https://www.jumia.co.ke/hisense-h25moms7hg-25l-grill-microwave-2yrs-wrty.-73548924.html'),
#  ('Nunix  3 IN 1 BREAKFAST MAKER, TOASTER,OVEN, COFFEE MAKER',
#   'KSh 7,799',
#   'KSh 12,000',
#   '2 out of 5',
#   'https://www.jumia.co.ke/smart-pro-20l-digital-microwave-oven-smv-20l-v42-black-1yr-wrty-280221109.html'),
#  ('Ramtons RM/684-25 LITERS MICROWAVE+GRILL (1YR WRTY)',
#   'KSh 8,199',
#   'KSh 19,999',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/haier-hmw20mb-analog-microwave-oven-700w-20l-black.-95922980.html'),
#  ('Mika MMWMSKH2012B - Microwave, 20L, Manual - Black',
#   'KSh 8,999',
#   'KSh 15,999',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/hisense-h20moms11-20-liters-microwave-white-2yrs-wrty-90543127.html'),
#  ('Nunix Digital Microwave with Grill, 20L',
#   'KSh 7,428',
#   'KSh 20,000',
#   '3.5 out of 5',
#   'https://www.jumia.co.ke/roch-rmw-20px7p-b-b-microwave-oven-700w-20l-black-1yr-wrty-125570761.html'),
#  ('Hisense  20L Digital Microwave oven',
#   'KSh 14,650',
#   'KSh 13,999',
#   '3.5 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm589-microwave-grill-black-1yr-wrty-39220900.html'),
#  ('Mika MMWMSKH2011W - Microwave, 20L, Manual - White',
#   'KSh 10,599',
#   'KSh 16,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm458-digital-glass-microwave-700w-20l-black-silver-23427463.html'),
#  ('Hisense 20L Digital Microwave oven',
#   'KSh 18,130',
#   'KSh 18,999',
#   '1 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm326-25l-microwave-grill-glass-black-1yr-wrty-186411.html'),
#  ('Mika MMWDSTH2342BF - Flat Bed 23L Microwave Oven - 800W - Black',
#   'KSh 11,450',
#   'KSh 8,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm459-20l-manual-glass-microwave-black-1yr-wrty-30262124.html'),
#  ('Hisense  20L Digital Microwave oven',
#   'KSh 14,995',
#   'KSh 14,999',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm550-23-litres-microwavegrill-black-1yr-wrty-421292.html'),
#  ('Nunix manual microwave 20l',
#   'KSh 7,499',
#   'KSh 14,999',
#   '4.4 out of 5',
#   'https://www.jumia.co.ke/midea-mmo-mm7p012mzebk-20l-manual-microwave-oven-700w-black-190706827.html'),
#  ('Nunix 20L Digital Electric Microwave Oven WITH GRILL',
#   'KSh 10,599',
#   'KSh 18,999',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm458-digital-glass-microwave-700w-20l-black-silver-23427463.html'),
#  ('Nunix  20L Electric Rotisserie Oven, 1280W',
#   'KSh 9,979',
#   'KSh 18,499',
#   '4.2 out of 5',
#   'https://www.jumia.co.ke/digital-microwave-oven-20l-with-grill-nunix-mpg1832580.html'),
#  ('Synix High quality microwave 20 ltrs black',
#   'KSh 6,299',
#   'KSh 15,500',
#   '3 out of 5',
#   'https://www.jumia.co.ke/20l-electric-rotisserie-oven-for-baking-and-grilling-nunix-mpg1832582.html'),
#  ('Synix Syinix 20l microwave oven',
#   'KSh 7,499',
#   'KSh 15,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-3-in-1-breakfast-maker-toasteroven-coffee-maker-201678676.html'),
#  ('Nunix  20L Digital Electric Microwave Oven WITH GRILL',
#   'KSh 16,390',
#   'KSh 16,499',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm684-25-liters-microwavegrill-1yr-wrty-183080669.html'),
#  ('Nunix Microwave Oven 20L WITH GRILL',
#   'KSh 11,395',
#   'KSh 19,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/mika-mmwmskh2012b-microwave-20l-manual-black-43904554.html'),
#  ('Armco Electric Oven Conventional 38LTR 1600W 60 Minute Timer Multi Stage Switch Heating Selection Stainless Steel Housing High Quality Energy Saving 1 Yr Warranty',
#   'KSh 10,999',
#   'KSh 8,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/electric-microwave-oven-and-grill-20l-nunix-mpg1577172.html'),
#  ('Synix quality microwave oven',
#   'KSh 15,499',
#   'KSh 17,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-177503728.html'),
#  ('Nunix 20l Digital microwave with grill',
#   'KSh 11,995',
#   'KSh 15,999',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/mika-mmwmskh2011w-microwave-20l-manual-white-43904295.html'),
#  ('Nunix 20L Digital Microwave with Grill',
#   'KSh 14,999',
#   'KSh 15,999',
#   '4 out of 5',
#   'https://www.jumia.co.ke/20l-digital-microwave-oven-hisense-mpg1701743.html'),
#  ('Nunix Digital Microwave Oven 20L With Grill',
#   'KSh 18,995',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-mmwdsth2342bf-flat-bed-23l-microwave-oven-800w-black-37970575.html'),
#  ('Nunix 20L Electric Rotisserie Oven, 1280W',
#   'KSh 13,899',
#   'KSh 956',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-189556683.html'),
#  ('Nunix Digital Microwave Oven 20L WITH GRILL',
#   'KSh 8,999',
#   'KSh 12,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/nunix-manual-microwave-20l-217632803.html'),
#  ('Nunix Digital Microwave Oven 20L. C20PG1',
#   'KSh 10,499',
#   'KSh 2,270',
#   '4.6 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-digital-electric-microwave-oven-with-grill-167242915.html'),
#  ('Nunix High Quality  Microwave Oven 20L',
#   'KSh 6,299',
#   'KSh 20,000',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-electric-rotisserie-oven-1280w-191940287.html'),
#  ('Nunix Digital microwave 20 liters',
#   'KSh 12,499',
#   'KSh 13,999',
#   '4.2 out of 5',
#   'https://www.jumia.co.ke/synix-high-quality-microwave-20-ltrs-black-221514758.html'),
#  ('Baking Gloves Anti-Scalding Microwave Oven Gloves Heat',
#   'KSh 10,999',
#   'KSh 18,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/synix-syinix-20l-microwave-oven-190566271.html'),
#  ('Nunix  Digital Microwave Oven 20L WITH GRILL',
#   'KSh 10,499',
#   'KSh 11,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-digital-electric-microwave-oven-with-grill-160779925.html'),
#  ('Thickened microwave oven gloves high temperature insulation kitchen household kitchen oven oven baking tools insulation gloves (dark green 1 pair)',
#   'KSh 10,499',
#   'KSh 16,499',
#   '4.2 out of 5',
#   'https://www.jumia.co.ke/nunix-microwave-oven-20l-with-grill-169408080.html'),
#  ('Hisense 20L Digital Microwave oven',
#   'KSh 15,495',
#   'KSh 1,800',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/armco-electric-oven-conventional-38ltr-1600w-60-minute-timer-multi-stage-switch-heating-selection-stainless-steel-housing-high-quality-energy-saving-1-yr-warranty-201796118.html'),
#  ('Reusable Silicon Air Fryer Liner Basket Tray',
#   'KSh 12,999',
#   'KSh 21,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/synix-quality-microwave-oven-211201677.html'),
#  ('Hisense  20L Digital Microwave oven',
#   'KSh 10,999',
#   'KSh 18,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-digital-microwave-with-grill-189599857.html'),
#  ('Hisense  H20MOMWS11-Digital 20L Microwave Oven,700W -WHITE+2YRS WARRANTY',
#   'KSh 10,499',
#   'KSh 16,395',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/20l-digital-microwave-with-grill-nunix-mpg1577183.html'),
#  ('Midea MMO-MM7P012MZE(BK) , 20L Manual Microwave Oven , 700W - Black',
#   'KSh 12,950',
#   'KSh 14,999',
#   '4 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-with-grill-184142404.html'),
#  ('Nunix 20L Digital Microwave with Grill',
#   'KSh 6,299',
#   'KSh 680',
#   '3.5 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-electric-rotisserie-oven-1280w-191940296.html'),
#  ('Ramtons RM/326 - 25L Microwave+ Grill Glass - Black (1YR WRTY)',
#   'KSh 10,999',
#   'KSh 18,499',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-with-grill-180371910.html'),
#  ('Adjustable Microwave Organizer / Stand-Quite Elegant',
#   'KSh 10,999',
#   'KSh 20,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l.-c20pg1-190824140.html'),
#  ('Hisense 30L Microwave (2YRs WRTY)',
#   'KSh 8,999',
#   'KSh 14,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-high-quality-microwave-oven-20l-171370836.html'),
#  ('Hisense Microwave Oven H20MOMWS11 700W 20L Digital Microwave,WHITE+2YRS WARRANTY',
#   'KSh 12,999',
#   'KSh 23,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-20-liters-228303601.html'),
#  ('Midea EG8P022MX-S, 25L Digital Microwave Grill Oven, 700W - Black',
#   'KSh 478',
#   'KSh 18,000',
#   '1 out of 5',
#   'https://www.jumia.co.ke/generic-baking-gloves-anti-scalding-microwave-oven-gloves-heat-85969182.html'),
#  ('Synix High quality microwave 20 ltrs black',
#   'KSh 10,999',
#   'KSh 680',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-with-grill-189749156.html'),
#  ('Microwave Food Cover with Steam Vents – BPA-Free Splatter Guard for Microwave Cooking Heat-Resistant and Dishwasher-Safe Fits Most Plate Sizes',
#   'KSh 1,334',
#   'KSh 18,000',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/generic-thickened-microwave-oven-gloves-high-temperature-insulation-kitchen-household-kitchen-oven-oven-baking-tools-insulation-gloves-dark-green-1-pair-160096025.html'),
#  ('Nunix Microwave Oven 20L WITH GRILL',
#   'KSh 14,999',
#   'KSh 19,000',
#   '3 out of 5',
#   'https://www.jumia.co.ke/20l-digital-microwave-oven-hisense-mpg1701743.html'),
#  ('Hisense 20L Digital Microwave Oven H20MOMWS11 -BLACK+2YRS WARRANTY',
#   'KSh 345',
#   'KSh 26,000',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/generic-reusable-silicon-air-fryer-liner-basket-tray-134729185.html'),
#  ('Synix Syinix 20l microwave oven',
#   'KSh 13,899',
#   'KSh 22,000',
#   '4.4 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-189556683.html'),
#  ('Hisense 20L Digital Microwave Oven 20 Liters Microwave',
#   'KSh 8,990',
#   'KSh 18,000',
#   '1 out of 5',
#   'https://www.jumia.co.ke/hisense-h20momws11-digital-20l-microwave-oven700w-white2yrs-warranty-277482930.html'),
#  ('24.5cm microwave replacement turntable plate',
#   'KSh 7,499',
#   'KSh 17,999',
#   '4 out of 5',
#   'https://www.jumia.co.ke/midea-mmo-mm7p012mzebk-20l-manual-microwave-oven-700w-black-190706827.html'),
#  ('Hisense 700W,20L Microwave,H20MOWS11 -WHITE+2 YEARS WARRANTY',
#   'KSh 10,499',
#   'KSh 15,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/20l-digital-microwave-with-grill-nunix-mpg1577183.html'),
#  ('Microwave Food Cover with Steam Vents – BPA-Free Splatter Guard for Microwave Cooking Heat-Resistant and Dishwasher-Safe Fits Most Plate Sizes',
#   'KSh 18,130',
#   'KSh 17,338',
#   '3 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm326-25l-microwave-grill-glass-black-1yr-wrty-186411.html'),
#  ('Hisense Digital  Microwave Oven -700W , 20L-SILVER',
#   'KSh 1,649',
#   'KSh 10,000',
#   '3 out of 5',
#   'https://www.jumia.co.ke/generic-adjustable-microwave-organizer-stand-quite-elegant-159335606.html'),
#  ('Nunix Digital Microwave Oven 20L With Grill',
#   'KSh 19,999',
#   'KSh 18,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-30l-microwave-2yrs-wrty-129537441.html'),
#  ('Ramtons RM/588-23LT Microwave- Black (1YR WRTY)',
#   'KSh 8,990',
#   'KSh 12,799',
#   '4 out of 5',
#   'https://www.jumia.co.ke/hisense-microwave-oven-h20momws11-700w-20l-digital-microwavewhite2yrs-warranty-287799612.html'),
#  ('Mika 20L Digital Microwave with Grill+2YEARS WARRANTY',
#   'KSh 12,999',
#   'KSh 956',
#   '5 out of 5',
#   'https://www.jumia.co.ke/midea-eg8p022mx-s-25l-digital-microwave-grill-oven-700w-black-263452425.html'),
#  ('Mika 20L Digital Microwave with Grill - Silver+1 YEAR WARRANTY',
#   'KSh 12,499',
#   'KSh 15,999',
#   '3.5 out of 5',
#   'https://www.jumia.co.ke/synix-high-quality-microwave-20-ltrs-black-221514758.html'),
#  ('Hisense 20 LITRES Digital Microwave Oven-H20MOWS11',
#   'KSh 662',
#   'KSh 18,000',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/generic-microwave-food-cover-with-steam-vents-bpa-free-splatter-guard-for-microwave-cooking-heat-resistant-and-dishwasher-safe-fits-most-plate-sizes-299894444.html'),
#  ('Nunix Digital Microwave Oven 20L WITH GRILL',
#   'KSh 10,499',
#   'KSh 15,000',
#   '4.4 out of 5',
#   'https://www.jumia.co.ke/nunix-microwave-oven-20l-with-grill-169408080.html'),
#  ('Nunix Digital Microwave Oven 20L. C20PG1',
#   'KSh 9,799',
#   'KSh 15,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-h20momws11-black2yrs-warranty-279523270.html'),
#  ('Nunix 20 LITRES MANUAL MICROWAVE',
#   'KSh 10,999',
#   'KSh 15,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/synix-syinix-20l-microwave-oven-190566271.html'),
#  ('Nunix 20L Manual Setting Microwave Oven',
#   'KSh 10,599',
#   'KSh 13,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-20-liters-microwave-254542908.html'),
#  ('Ramtons RM/684-25 LITERS MICROWAVE+GRILL (1YR WRTY)',
#   'KSh 2,800',
#   'KSh 18,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/generic-24.5cm-microwave-replacement-turntable-plate-298702143.html'),
#  ('Ramtons RM/682-20 LITERS MICROWAVE+GRILL MIRROR FINISH (1YR WRTY)',
#   'KSh 8,990',
#   'KSh 16,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/hisense-700w20l-microwaveh20mows11-white2-years-warranty-264475807.html'),
#  ('Ramtons RM/573 - Manual Microwave - 20L - Black (1YR WRTY)',
#   'KSh 629',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-microwave-food-cover-with-steam-vents-bpa-free-splatter-guard-for-microwave-cooking-heat-resistant-and-dishwasher-safe-fits-most-plate-sizes-275644426.html'),
#  ('Ramtons RM/328 - 20L Manual Microwave - White (1YR WRTY)',
#   'KSh 9,999',
#   'KSh 3,899',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/hisense-digital-microwave-oven-700w-20l-silver-261934133.html'),
#  ('Hisense 700W 20L Digital Microwave,H20MOMS11  - Silver+5YR WARRANTY',
#   'KSh 12,950',
#   'KSh 20,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-with-grill-184142404.html'),
#  ('Ramtons RM/319 - Digital Microwave - 20L - White (1YR WRTY)',
#   'KSh 13,450',
#   'KSh 9,500',
#   '3.7 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm588-23lt-microwave-black-1yr-wrty-39220863.html'),
#  ('Mika 20L MICROWAVE WITH GRILL',
#   'KSh 11,499',
#   'KSh 18,000',
#   '4.6 out of 5',
#   'https://www.jumia.co.ke/mika-20l-digital-microwave-with-grill2years-warranty-266380150.html'),
#  ('Baking Gloves Anti-Scalding Microwave Oven Gloves Heat',
#   'KSh 11,289',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-20l-digital-microwave-with-grill-silver1-year-warranty-303438175.html'),
#  ('Hisense 20L Digital Microwave - Black',
#   'KSh 9,399',
#   'KSh 18,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/hisense-20-litres-digital-microwave-oven-h20mows11-284463565.html'),
#  ('Hisense  Microwave Oven H20MOMS11 700W 20L Digital Microwave+2 years warranty',
#   'KSh 10,999',
#   'KSh 17,899',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-with-grill-180371910.html'),
#  ('Nunix Digital microwave 20 liters',
#   'KSh 10,999',
#   'KSh 18,000',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l.-c20pg1-190824140.html'),
#  ('Ramtons RM/240, Microwave With Grill - 20L -Silver (1YR WRTY)',
#   'KSh 8,669',
#   'KSh 20,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/nunix-20-litres-manual-microwave-176202312.html'),
#  ('Nunix 20L Microwave Oven - White',
#   'KSh 8,499',
#   'KSh 22,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-manual-setting-microwave-oven-277098345.html'),
#  ('Ramtons RM/320 - Digital Microwave, 700W - 20L - Silver (1YR WRTY)',
#   'KSh 16,390',
#   'KSh 18,000',
#   '4.6 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm684-25-liters-microwavegrill-1yr-wrty-183080669.html'),
#  ('Haier 20l digital control microwave oven-Silver',
#   'KSh 12,450',
#   'KSh 15,000',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm682-20-liters-microwavegrill-mirror-finish-1yr-wrty-186554464.html'),
#  ('Hisense Microwave 36 Liters (2YRs WRTY) (2YRs WRTY).',
#   'KSh 11,450',
#   'KSh 11,742',
#   '4 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm573-manual-microwave-20l-black-1yr-wrty-30497747.html'),
#  ('Hisense H20MOMS11 20L Microwave Oven Silver',
#   'KSh 10,490',
#   'KSh 15,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm328-20l-manual-microwave-white-1yr-wrty-143493.html'),
#  ('Hisense 20 LITRES Microwave Oven-H20MOWS11',
#   'KSh 9,999',
#   'KSh 8,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/hisense-700w-20l-digital-microwaveh20moms11-silver5yr-warranty-291750337.html'),
#  ('Nunix Microwave Oven 20L - White',
#   'KSh 10,700',
#   'KSh 3,480',
#   '3 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm319-digital-microwave-20l-white-1yr-wrty-143553.html'),
#  ('Nunix 20L Microwave Oven - White',
#   'KSh 11,495',
#   'KSh 18,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/mika-20l-microwave-with-grill-254499884.html'),
#  ('Multipurpose Microwave Oven Stand',
#   'KSh 478',
#   'KSh 2,545',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/generic-baking-gloves-anti-scalding-microwave-oven-gloves-heat-85969182.html'),
#  ('Ramtons RM/310- Microwave+Grill 20Litres - Silver (1YR WRTY)',
#   'KSh 9,799',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-black-264271639.html'),
#  ('Hisense H20MOMS11 ,20L Digital Microwave Oven,SILVER+2YEARS WARRANTY',
#   'KSh 9,999',
#   'KSh 11,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-microwave-oven-h20moms11-700w-20l-digital-microwave2-years-warranty-261879227.html'),
#  ('Nunix Microwave Oven 20L  With Manual Setting Function C20MX1',
#   'KSh 12,999',
#   'KSh 23,599',
#   '2.7 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-20-liters-228303601.html'),
#  ('Hisense Digital Microwave Oven 20L White 2yrs Warranty.',
#   'KSh 13,350',
#   'KSh 22,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm240-microwave-with-grill-20l-silver-1yr-wrty-27615762.html'),
#  ('Nunix 20L Microwave Oven',
#   'KSh 9,999',
#   'KSh 15,000',
#   '4.4 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-microwave-oven-white-127821570.html'),
#  ('Hisense 20L Digital Microwave Oven H20MOMWS11-WHITE+2YRS WARRANTY',
#   'KSh 11,550',
#   'KSh 1,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm320-digital-microwave-700w-20l-silver-1yr-wrty-143491.html'),
#  ('Nunix Microwave Oven 20L WITH GRILL',
#   'KSh 13,999',
#   'KSh 15,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/haier-20l-digital-control-microwave-oven-silver-298703582.html'),
#  ('Roch Digital Microwave 20ltrs',
#   'KSh 25,000',
#   'KSh 18,000',
#   '3 out of 5',
#   'https://www.jumia.co.ke/hisense-microwave-36-liters-2yrs-wrty-2yrs-wrty.-48813990.html'),
#  ('Haier 20l digital control microwave oven-Silver',
#   'KSh 9,999',
#   'KSh 24,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-h20moms11-20l-microwave-oven-silver-201037709.html'),
#  ('Mika  20 LITRES  Digital Microwave with Grill,700W- Silver+2YEARS WARRANTY',
#   'KSh 9,399',
#   'KSh 15,999',
#   '4.9 out of 5',
#   'https://www.jumia.co.ke/hisense-20-litres-microwave-oven-h20mows11-284463559.html'),
#  ('Hisense 20L Digital Microwave Oven H20MOMS11 -BLACK',
#   'KSh 8,625',
#   'KSh 20,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-microwave-oven-20l-white-126330283.html'),
#  ('Mika 20L Digital Grill Microwave Push Door Open Mirror With Multi Stage Cooking Feature 1yr Warranty Free Food Cover',
#   'KSh 8,675',
#   'KSh 14,000',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-microwave-oven-white-126330250.html'),
#  ('Hisense 700W 20L Digital Microwave - Silver',
#   'KSh 2,999',
#   'KSh 14,999',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/multipurpose-microwave-oven-stand-generic-mpg256798.html'),
#  ('Metallic 2 Layers Microwave Stand/Organizer',
#   'KSh 12,290',
#   'KSh 15,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/ramtons-rm310-microwavegrill-20litres-silver-1yr-wrty-143882.html'),
#  ('Mika \t20L Digital Microwave with Grill - 2 YRS WRTY',
#   'KSh 10,599',
#   'KSh 19,000',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/hisense-h20moms11-20l-digital-microwave-ovensilver2years-warranty-284471373.html'),
#  ('Nunix  20L Electric Rotisserie Oven, 1280W',
#   'KSh 8,394',
#   'KSh 21,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/nunix-microwave-oven-20l-with-manual-setting-function-c20mx1-153991563.html'),
#  ('Microwave Turntable Tray',
#   'KSh 11,899',
#   'KSh 22,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-digital-microwave-oven-20l-white-2yrs-warranty.-221063632.html'),
#  ('Mika MMWMSKH2012B - Microwave, 20L, Manual - Black',
#   'KSh 8,625',
#   'KSh 700',
#   '4.6 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-microwave-oven-126330267.html'),
#  ('Mika 20L Manual Microwave, 700W+1YEAR WARRANTY',
#   'KSh 8,890',
#   'KSh 3,000',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-h20momws11-white2yrs-warranty-283283484.html'),
#  ('1Pc Transparent Microwave Oven Turntable Glass Tray Glass Plate Diameter: 24.5cm',
#   'KSh 10,399',
#   'KSh 16,000',
#   '4.2 out of 5',
#   'https://www.jumia.co.ke/nunix-microwave-oven-20l-with-grill-275339838.html'),
#  ('Mika \tDigital Microwave - 20L, 700W, Grill (1 Year Warranty)',
#   'KSh 9,485',
#   'KSh 15,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/roch-digital-microwave-20ltrs-127498995.html'),
#  ('Hisense  H20MOWS11 700W 20L Digital Microwave',
#   'KSh 13,999',
#   'KSh 7,500',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/haier-20l-digital-control-microwave-oven-silver-287378182.html'),
#  ('Hisense  25L Grill Microwave Oven H25MOMS7HG',
#   'KSh 11,250',
#   'KSh 8,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/mika-20-litres-digital-microwave-with-grill700w-silver2years-warranty-293419168.html'),
#  ('Mika 20L Digital Microwave Plus Grill+2YRS WARRANTY,SILVER',
#   'KSh 9,799',
#   'KSh 20,000',
#   '4.2 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-h20moms11-black-283283708.html'),
#  ('Angry Mama Microwave Cleaner',
#   'KSh 13,995',
#   'KSh 13,997',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-20l-digital-grill-microwave-push-door-open-mirror-with-multi-stage-cooking-feature-1yr-warranty-free-food-cover-299589057.html'),
#  ('VON VAMS-20DGB, 20L, 700Watts Microwave Oven',
#   'KSh 9,990',
#   'KSh 344,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/hisense-700w-20l-digital-microwave-silver-262990549.html'),
#  ('Medium Air fryer silicon liners pot reusable oven tray accessories',
#   'KSh 5,871',
#   'KSh 14,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/metallic-2-layers-microwave-standorganizer-generic-mpg2088220.html'),
#  ('Hisense 20L Digital Microwave Oven - Black   (2YRs WRTY) H20MOBS11',
#   'KSh 10,999',
#   'KSh 17,999',
#   '4.7 out of 5',
#   'https://www.jumia.co.ke/mika-20l-digital-microwave-with-grill-2-yrs-wrty-303771448.html'),
#  ('Hisense 20L Digital Microwave Oven H20MOMWS11-WHITE',
#   'KSh 6,299',
#   'KSh 12,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-electric-rotisserie-oven-1280w-191940287.html'),
#  ('VON 20L DIGITAL MICROWAVE',
#   'KSh 2,374',
#   'KSh 35,995',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/generic-microwave-turntable-tray-238218318.html'),
#  ('Nunix 20l Digital microwave with grill',
#   'KSh 11,395',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-mmwmskh2012b-microwave-20l-manual-black-43904554.html'),
#  ('Nunix 20l Digital microwave with grill',
#   'KSh 9,990',
#   'KSh 11,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-20l-manual-microwave-700w1year-warranty-287302830.html'),
#  ('Hisense 20L, 700W Digital Microwave - White',
#   'KSh 2,414',
#   'KSh 15,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/1pc-transparent-microwave-oven-turntable-glass-tray-glass-plate-diameter-24.5cm-generic-mpg6976778.html'),
#  ('ICONA Microwave oven 25L With Digital Setting  ILDMO-2565XB',
#   'KSh 10,600',
#   'KSh 12,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-digital-microwave-20l-700w-grill-1-year-warranty-286577330.html'),
#  ('Nunix Digital Microwave Oven 20L. C20PG1',
#   'KSh 8,990',
#   'KSh 2,000',
#   '3.5 out of 5',
#   'https://www.jumia.co.ke/hisense-h20mows11-700w-20l-digital-microwave-288330730.html'),
#  ('Nunix Digital Microwave Oven 20L With Grill',
#   'KSh 16,300',
#   'KSh 118,400',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/hisense-25l-grill-microwave-oven-h25moms7hg-280221428.html'),
#  ('Foldable 2-Layer Microwave Rack/Insulating Plate Rack',
#   'KSh 11,199',
#   'KSh 5,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-20l-digital-microwave-plus-grill2yrs-warrantysilver-293420578.html'),
#  ('Hisense Microwave 23 Liters H23moms5H (2YRs WRTY)',
#   'KSh 435',
#   'KSh 14,999',
#   '4 out of 5',
#   'https://www.jumia.co.ke/angry-mama-microwave-cleaner-generic-mpg2779049.html'),
#  ('Mika  MMWDGPB2074MR-20L Digital Microwave with Grill+2YRS WARRANTY',
#   'KSh 12,499',
#   'KSh 799',
#   '4.1 out of 5',
#   'https://www.jumia.co.ke/von-vams-20dgb-20l-700watts-microwave-oven-263521010.html'),
#  ('2-Layer Microwave Placement Rack/Insulating Rack Fridge Placement Rack',
#   'KSh 650',
#   'KSh 15,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/generic-medium-air-fryer-silicon-liners-pot-reusable-oven-tray-accessories-296336950.html'),
#  ('Food Cover Microwave Safe Set 4 Pcs',
#   'KSh 9,999',
#   'KSh 1,780',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-black-2yrs-wrty-h20mobs11-116429387.html'),
#  ('Mika Digital Microwave Oven with Grill - 20L',
#   'KSh 9,490',
#   'KSh 18,000',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-digital-microwave-oven-h20momws11-white-283283417.html'),
#  ('Nunix Digital microwave 20 liters',
#   'KSh 12,500',
#   'KSh 10,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/von-20l-digital-microwave-156970954.html'),
#  ('2Tier Heavy Duty Telescopic Adjustable Microwave stand',
#   'KSh 10,999',
#   'KSh 22,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-digital-microwave-with-grill-189599857.html'),
#  ('Metallic microwave stand',
#   'KSh 10,999',
#   'KSh 34,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/20l-digital-microwave-with-grill-nunix-mpg5512616.html'),
#  ('Hisense  Microwave 23 Liters H23moms5H (2YRs WRTY)',
#   'KSh 8,990',
#   'KSh 2,500',
#   '3 out of 5',
#   'https://www.jumia.co.ke/hisense-20l-700w-digital-microwave-white-277783315.html'),
#  ('VON Digital Microwave Oven, VAMS-20DGX, Solo No Grill, 20LTR - BLACK',
#   'KSh 12,999',
#   'KSh 11,500',
#   '5 out of 5',
#   'https://www.jumia.co.ke/icona-microwave-oven-25l-with-digital-setting-ildmo-2565xb-278823345.html'),
#  ('Premier COMMERCIAL ELECRTRIC OVEN THREE DECK SIX TRAYS',
#   'KSh 10,999',
#   'KSh 11,742',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l.-c20pg1-190824140.html'),
#  ('VON Microwave Oven, Solo, 20L Mechanical VAMS-20MGW',
#   'KSh 12,950',
#   'KSh 2,140',
#   '3 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-with-grill-184142404.html'),
#  ('Nunix Digital Microwave Oven 20L WITH GRILL',
#   'KSh 485',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/foldable-2-layer-microwave-rackinsulating-plate-rack-generic-mpg6956863.html'),
#  ('Nunix  Digital Microwave Oven 20L WITH GRILL',
#   'KSh 15,999',
#   'KSh 14,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/microwave-23-liters-h23moms5h-2yrs-wrty-hisense-mpg4929850.html'),
#  ('LG 30L NeoChef® Microwave Oven (Black Finish)',
#   'KSh 11,259',
#   'KSh 1,150',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-mmwdgpb2074mr-20l-digital-microwave-with-grill2yrs-warranty-293419025.html'),
#  ('Retractable Expandable Microwave Stand',
#   'KSh 485',
#   'KSh 900',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-2-layer-microwave-placement-rackinsulating-rack-fridge-placement-rack-286115518.html'),
#  ('Nunix Digital Microwave Oven 20L',
#   'KSh 2,900',
#   'KSh 12,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-food-cover-microwave-safe-set-4-pcs-189313661.html'),
#  ('HANMAC 20L Manual Microwave with Turntable Glass, Push-Button Door, Kitchen Timer HMR20M',
#   'KSh 10,999',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-digital-microwave-oven-with-grill-20l-303789469.html'),
#  ('ICONA 20 Ltrs Digital Microwave Oven',
#   'KSh 12,999',
#   'KSh 28,000',
#   '3.5 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-20-liters-228303601.html'),
#  ('Nunix 20L Manual Setting Microwave Oven',
#   'KSh 5,999',
#   'KSh 16,999',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/generic-2tier-heavy-duty-telescopic-adjustable-microwave-stand-256602313.html'),
#  ('Rotating Cake Turntable Cake Stand, Revolving Cake Stand,Cake Decorating Tools,White Baking Cake Decorating Supplies',
#   'KSh 7,500',
#   'KSh 11,000',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/generic-metallic-microwave-stand-221074138.html'),
#  ('Microwave Plate Cover Food Covers Purple',
#   'KSh 16,199',
#   'KSh 10,399',
#   '5 out of 5',
#   'https://www.jumia.co.ke/hisense-microwave-23-liters-h23moms5h-2yrs-wrty-262983410.html'),
#  ('Universal Oven Glassplate replacement',
#   'KSh 13,001',
#   'KSh 26,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/generic-von-digital-microwave-oven-vams-20dgx-solo-no-grill-20ltr-black-303211000.html'),
#  ('Roch Manual Microwave Oven 700W, 20L – RMW-20L8M-B (B)',
#   'KSh 172,000',
#   'KSh 1,150',
#   '5 out of 5',
#   'https://www.jumia.co.ke/premier-commercial-elecrtric-oven-three-deck-six-trays-159164683.html'),
#  ('Synix High quality microwave 20 ltrs black',
#   'KSh 10,499',
#   'KSh 22,000',
#   '4.2 out of 5',
#   'https://www.jumia.co.ke/von-microwave-oven-solo-20l-mechanical-vams-20mgw-170956206.html'),
#  ('Insulated Cotton Kitchen/Oven Gloves mittens',
#   'KSh 10,999',
#   'KSh 900',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-with-grill-180371910.html'),
#  ('Redberry  Microwave Oven 20L - White',
#   'KSh 10,999',
#   'KSh 11,499',
#   '4.3 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-with-grill-189749156.html'),
#  ('Reusable Silicon Air Fryer Liner Basket Tray',
#   'KSh 29,995',
#   'KSh 12,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/lg-30l-neochefr-microwave-oven-black-finish-264410735.html'),
#  ('VON VAMS-21DGK, 700W Digital Microwave Oven- 20L',
#   'KSh 6,300',
#   'KSh 20,100',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-retractable-expandable-microwave-stand-132258124.html'),
#  ('Icona London 20L Manual Setting Microwave Oven',
#   'KSh 10,300',
#   'KSh 17,000',
#   '4.8 out of 5',
#   'https://www.jumia.co.ke/nunix-digital-microwave-oven-20l-258169688.html'),
#  ('Mika MMWDGPB2074MR, 20L  Digital Microwave with Grill,700W- Silver+2YEARS WARRANTY',
#   'KSh 9,199',
#   'KSh 1,150',
#   '2.5 out of 5',
#   'https://www.jumia.co.ke/hanmac-20l-manual-microwave-with-turntable-glass-push-button-door-kitchen-timer-hmr20m-262410885.html'),
#  ('VON 20L DIGITAL MICROWAVE WITH GRILL',
#   'KSh 10,499',
#   'KSh 11,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/icona-20-ltrs-digital-microwave-oven-275210814.html'),
#  ('Adjustable Microwave Organizer / Stand-Quite Elegant',
#   'KSh 9,500',
#   'KSh 1,560',
#   '3 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-manual-setting-microwave-oven-295571131.html'),
#  ('Syinix Microwave Manual Oven 20L MW720-03M',
#   'KSh 1,499',
#   'KSh 2,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/generic-rotating-cake-turntable-cake-stand-revolving-cake-standcake-decorating-toolswhite-baking-cake-decorating-supplies-263658684.html'),
#  ('Metallic 2 Layers Microwave Stand/Organizer',
#   'KSh 118,399',
#   'KSh 4,284',
#   '1 out of 5',
#   'https://www.jumia.co.ke/generic-microwave-plate-cover-food-covers-purple-158926069.html'),
#  ('Microwaves Food Cover',
#   'KSh 2,600',
#   'KSh 1,800',
#   '4 out of 5',
#   'https://www.jumia.co.ke/generic-universal-oven-glassplate-replacement-264424563.html'),
#  ('Cake Turntable Revolving Rotating Cake Decorating Stand',
#   'KSh 9,999',
#   'KSh 11,500',
#   '5 out of 5',
#   'https://www.jumia.co.ke/roch-manual-microwave-oven-700w-20l-rmw-20l8m-b-b-262265287.html'),
#  ('Mika 700W Digital Microwave (1 YR WRTY)',
#   'KSh 12,499',
#   'KSh 22,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/synix-high-quality-microwave-20-ltrs-black-221514758.html'),
#  ('Rock  DIGITAL MICROWAVE 20lts',
#   'KSh 740',
#   'KSh 17,995',
#   '4 out of 5',
#   'https://www.jumia.co.ke/generic-insulated-cotton-kitchenoven-gloves-mittens-200505473.html'),
#  ('Microwave Dust Cover',
#   'KSh 10,500',
#   'KSh 13,999',
#   '4 out of 5',
#   'https://www.jumia.co.ke/redberry-microwave-oven-20l-white-278034644.html'),
#  ('Gloves Heat Insulation//super Quality',
#   'KSh 1,190',
#   'KSh 13,999',
#   '3.5 out of 5',
#   'https://www.jumia.co.ke/reusable-silicon-air-fryer-liner-basket-tray-generic-mpg5583803.html'),
#  ('Nunix 20L Manual Setting Microwave Oven',
#   'KSh 15,000',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/von-vams-21dgk-700w-digital-microwave-oven-20l-268466347.html'),
#  ('Nunix 20L Microwave Oven',
#   'KSh 8,650',
#   'KSh 14,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/20l-manual-setting-microwave-oven-icona-london-mpg2256923.html'),
#  ('Hisense 20 LITRE MICROWAVE OVEN, FOR QUICK AND EFFICIENT COOKING, DIGITAL CONTROL PANEL',
#   'KSh 11,250',
#   'KSh 12,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/mika-mmwdgpb2074mr-20l-digital-microwave-with-grill700w-silver2years-warranty-293419530.html'),
#  ('VON VAMS-21DGK, 700W Digital Microwave Oven- 20L',
#   'KSh 17,500',
#   'KSh 12,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/von-20l-digital-microwave-with-grill-156970960.html'),
#  ('Nunix Microwave Oven 20L WITH GRILL',
#   'KSh 2,350',
#   'KSh 9,670',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-adjustable-microwave-organizer-stand-quite-elegant-153432262.html'),
#  ('20L Digital Microwave Oven H20MOMWS11',
#   'KSh 10,000',
#   'KSh 24,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/syinix-microwave-manual-oven-20l-mw720-03m-270996828.html'),
#  ('VON 20L  ANALOG MICROWAVE',
#   'KSh 5,871',
#   'KSh 20,000',
#   '1 out of 5',
#   'https://www.jumia.co.ke/generic-metallic-2-layers-microwave-standorganizer-279421316.html'),
#  ('Microwave Dust Cover',
#   'KSh 800',
#   'KSh 3,400',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-microwaves-food-cover-58993220.html'),
#  ('Nunix 20L DIGITAL MICROWAVE WITH GRILL',
#   'KSh 1,075',
#   'KSh 18,000',
#   '3 out of 5',
#   'https://www.jumia.co.ke/cake-turntable-revolving-rotating-cake-decorating-stand-generic-mpg5810255.html'),
#  ('Microwave Oven Cover Storage Bag- Oil/Dust-Proof',
#   'KSh 10,999',
#   'KSh 15,999',
#   '3 out of 5',
#   'https://www.jumia.co.ke/mika-700w-digital-microwave-1-yr-wrty-288330025.html'),
#  ('Synix 700w 20L Microwave Oven,Manual',
#   'KSh 11,300',
#   'KSh 11,999',
#   '3 out of 5',
#   'https://www.jumia.co.ke/rock-digital-microwave-20lts-260343181.html'),
#  ('20L Digital Multi Purpose Microwave Oven With Grill',
#   'KSh 900',
#   'KSh 10,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-microwave-dust-cover-188869317.html'),
#  ('Mika 700W, 20L Manual Microwave - Black',
#   'KSh 700',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-gloves-heat-insulationsuper-quality-115384294.html'),
#  ('Metal Microwave Oven Rack Stand-Heavy Duty',
#   'KSh 8,599',
#   'KSh 12,999',
#   '2 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-manual-setting-microwave-oven-295570929.html'),
#  ('VON Von, Microwave 20Litres Digital with GRILL',
#   'KSh 9,999',
#   'KSh 2,600',
#   '5 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-microwave-oven-127475851.html'),
#  ('Nunix 20 Liters Electric Rotisserie Oven',
#   'KSh 15,389',
#   'KSh 15,000',
#   '3 out of 5',
#   'https://www.jumia.co.ke/hisense-20-litre-microwave-oven-for-quick-and-efficient-cooking-digital-control-panel-294304727.html'),
#  ('ICONA Microwave oven 25L With Manual Setting  ILMO-2550XW',
#   'KSh 13,899',
#   'KSh 39,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/von-vams-21dgk-700w-digital-microwave-oven-20l-267870623.html'),
#  ('Microwave Dust Cover',
#   'KSh 10,950',
#   'KSh 22,000',
#   '1 out of 5',
#   'https://www.jumia.co.ke/nunix-microwave-oven-20l-with-grill-157347634.html'),
#  ('Synix 5.5L Air Fryer',
#   'KSh 10,299',
#   'KSh 16,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-20l-digital-microwave-oven-h20momws11-279499569.html'),
#  ('1Pc Non slip kitchen Silicon insulated oven gloves',
#   'KSh 13,300',
#   'KSh 18,750',
#   '4.5 out of 5',
#   'https://www.jumia.co.ke/von-20l-analog-microwave-156970951.html'),
#  ('cake turntable rotates 360 degrees//',
#   'KSh 900',
#   'KSh 16,000',
#   '3.7 out of 5',
#   'https://www.jumia.co.ke/generic-microwave-dust-cover-188869318.html'),
#  ('High Voltage Diode Rectifier For GE Hotpoint Microwave Oven WB27X10597 11QBP023',
#   'KSh 11,900',
#   'KSh 19,900',
#   '4 out of 5',
#   'https://www.jumia.co.ke/nunix-20l-digital-microwave-with-grill-157530016.html'),
#  ('Armco Microwave Digital Oven 20L; AM-DS2033(BK) 700W; Black.',
#   'KSh 600',
#   'KSh 36,000',
#   '2.7 out of 5',
#   'https://www.jumia.co.ke/generic-microwave-oven-cover-storage-bag-oildust-proof-296576322.html'),
#  ('Cake Decorating Rotating Revolving Turn Table Cake Stand',
#   'KSh 8,699',
#   'KSh 23,999',
#   '4 out of 5',
#   'https://www.jumia.co.ke/synix-700w-20l-microwave-ovenmanual-275785336.html'),
#  ('Syinix Microwave Manual Oven 20L MW720-03M',
#   'KSh 12,999',
#   'KSh 15,500',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-20l-digital-multi-purpose-microwave-oven-with-grill-152949882.html'),
#  ('Microwave Food Cover-multicolor',
#   'KSh 9,999',
#   'KSh 12,999',
#   '4.4 out of 5',
#   'https://www.jumia.co.ke/mika-700w-20l-manual-microwave-black-288330245.html'),
#  ('Nunix 20L DIGITAL MICROWAVE WITH GRILL',
#   'KSh 4,577',
#   'KSh 17,800',
#   '3.5 out of 5',
#   'https://www.jumia.co.ke/metal-microwave-oven-rack-stand-heavy-duty-generic-mpg6505637.html'),
#  ('VON /VAMS-20DGS Digital Solo Microwave Oven - 20L',
#   'KSh 14,900',
#   'KSh 15,000',
#   '4 out of 5',
#   'https://www.jumia.co.ke/von-von-microwave-20litres-digital-with-grill-286782275.html'),
#  ('Midea Microwave Oven Manual 20L , 700W - Black  MMO-MM7P012MZE(BK)',
#   'KSh 6,960',
#   'KSh 15,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/20-liters-electric-rotisserie-oven-nunix-mpg6297851.html'),
#  ('Hisense 20L, Black, Digital Microwave (2 YRS WARRANTY)',
#   'KSh 14,998',
#   'KSh 12,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/icona-microwave-oven-25l-with-manual-setting-ilmo-2550xw-279500384.html'),
#  ('Nunix 20l Microwave with Grill',
#   'KSh 900',
#   'KSh 12,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-microwave-dust-cover-188869316.html'),
#  ('Roch Manual Microwave Oven 700W, 20L – RMW-20L8M-B (B)',
#   'KSh 7,999',
#   'KSh 16,999',
#   '5 out of 5',
#   'https://www.jumia.co.ke/synix-5.5l-air-fryer-288741093.html'),
#  ('Synix Syinix 20l microwave oven',
#   'KSh 1,250',
#   'KSh 3,000',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-1pc-non-slip-kitchen-silicon-insulated-oven-gloves-203842538.html'),
#  ('Nunix 20L Electric Microwave Oven',
#   'KSh 1,080',
#   'KSh 12,500',
#   '4 out of 5',
#   'https://www.jumia.co.ke/generic-cake-turntable-rotates-360-degrees-171315599.html'),
#  ('HANMAC microwave  20l manual',
#   'KSh 2,149',
#   'KSh 9,500',
#   '5 out of 5',
#   'https://www.jumia.co.ke/generic-high-voltage-diode-rectifier-for-ge-hotpoint-microwave-oven-wb27x10597-11qbp023-227110764.html')]

# %%
collect_data_microwaves()
# Out:
# Fetching data from https://www.jumia.co.ke/small-appliances-microwave/ Status <Response [200]>
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=2#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=3#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=4#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=5#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=6#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=7#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=8#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=9#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=10#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=11#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=12#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=13#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=14#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=15#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=16#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=17#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=18#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=19#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=20#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=21#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=22#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=23#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=24#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=25#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=26#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=27#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=28#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=29#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=30#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=31#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=32#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=33#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=34#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=35#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=36#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=37#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=38#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=39#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=40#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=41#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=42#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=43#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=44#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=45#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=46#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=47#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=48#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=49#catalog-listing - Status: 200
# Fetching data from: https://www.jumia.co.ke/catalog/?q=microwaves&page=50#catalog-listing - Status: 200
# Failed to fetch data from https://www.jumia.co.ke/catalog/?q=microwaves&page=50#catalog-listing

# %%
data = pd.read_csv(r"..\data\scraped_data\jumia_scraped_microwaves.csv")
data.head(14)
# Out:
#                                          descriptions       price   old_price  \
# 0   Ramtons RM/458 - Digital Glass Microwave, 700W...  KSh 19,999  KSh 11,800
# 1         Nunix Digital Microwave Oven 20L WITH GRILL   KSh 9,999  KSh 11,080
# 2        Nunix 20L Electric Oven With Grill (3 Knobs)  KSh 15,200   KSh 9,999
# 3   Nunix  3 IN 1 BREAKFAST MAKER, TOASTER,OVEN, C...   KSh 7,799  KSh 12,000
# 4   Ramtons RM/684-25 LITERS MICROWAVE+GRILL (1YR ...   KSh 8,199  KSh 19,999
# 5   Mika MMWMSKH2012B - Microwave, 20L, Manual - B...   KSh 8,999  KSh 15,999
# 6             Nunix Digital Microwave with Grill, 20L   KSh 7,428  KSh 20,000
# 7                 Hisense  20L Digital Microwave oven  KSh 14,650  KSh 13,999
# 8   Mika MMWMSKH2011W - Microwave, 20L, Manual - W...  KSh 10,599  KSh 16,000
# 9                  Hisense 20L Digital Microwave oven  KSh 18,130  KSh 18,999
# 10  Mika MMWDSTH2342BF - Flat Bed 23L Microwave Ov...  KSh 11,450   KSh 8,000
# 11                Hisense  20L Digital Microwave oven  KSh 14,995  KSh 14,999
# 12                         Nunix manual microwave 20l   KSh 7,499  KSh 14,999
# 13  Nunix 20L Digital Electric Microwave Oven WITH...  KSh 10,599  KSh 18,999
#
#          ratings                                               urls
# 0   4.6 out of 5  https://www.jumia.co.ke/hisense-30l-microwave-...
# 1   4.3 out of 5  https://www.jumia.co.ke/haier-hmw20dbm-digital...
# 2   4.2 out of 5  https://www.jumia.co.ke/hisense-h25moms7hg-25l...
# 3     2 out of 5  https://www.jumia.co.ke/smart-pro-20l-digital-...
# 4   4.5 out of 5  https://www.jumia.co.ke/haier-hmw20mb-analog-m...
# 5   4.8 out of 5  https://www.jumia.co.ke/hisense-h20moms11-20-l...
# 6   3.5 out of 5  https://www.jumia.co.ke/roch-rmw-20px7p-b-b-mi...
# 7   3.5 out of 5  https://www.jumia.co.ke/ramtons-rm589-microwav...
# 8   4.3 out of 5  https://www.jumia.co.ke/ramtons-rm458-digital-...
# 9     1 out of 5  https://www.jumia.co.ke/ramtons-rm326-25l-micr...
# 10    5 out of 5  https://www.jumia.co.ke/ramtons-rm459-20l-manu...
# 11  4.3 out of 5  https://www.jumia.co.ke/ramtons-rm550-23-litre...
# 12  4.4 out of 5  https://www.jumia.co.ke/midea-mmo-mm7p012mzebk...
# 13  4.5 out of 5  https://www.jumia.co.ke/ramtons-rm458-digital-...

# %%
def jumia_microwaves_cleaning(csv_path):
    data = pd.read_csv(csv_path)
    data.head()
    data["Price"] = data["price"].str.replace("KSh", "").str.replace(",","")
    data["Reviews"] = data["ratings"].str.replace(" out of 5", "")
    data["Old_price"] = data["old_price"].str.replace("KSh ", "").str.replace(",", "")
    data["Price"] = data["Price"].astype(int)
    data["Reviews"] = data["Reviews"].astype(float)
    data["Old_price"] = data["Old_price"].astype(int)
    pattern = r"^[a-zA-Z]+"
    data["brand"] = data["descriptions"].str.extract(f"({pattern})")
    pattern_cap = r'(\d+)\s*(?=litres|l|L)'
    result = data["descriptions"].str.extract(f"({pattern_cap})")
    data["capacity"] = result[0]
    data["capacity"] = data["capacity"].str.strip().astype(float)
    id = [i for i in range(1, len(data) + 1)]
    data["id"] = id
    data["id"] - data["id"].astype(int)
    data["source"] = ["Jumia"] * len(data)
    data = data.drop(columns = ["price", "ratings", "old_price"])
    columns = ["id", "descriptions", "brand", "Price", "Old_price", "capacity", "Reviews", "source", "urls"]
    data = data[columns]
    data.rename(columns = {"descriptions" : "description", "Price" : "price", "Old_price" : "old_price", "Reviews" :  "reviews"})
    data = data[columns]
    data.to_csv(r"..\data\clean_data\jumia_clean_microwaves.csv", index=False)

    return data

# %%
jumia_microwaves_cleaning(r"..\data\scraped_data\jumia_scraped_microwaves.csv")
# Out:
#       id                                       descriptions    brand  Price  \
# 0      1  Ramtons RM/458 - Digital Glass Microwave, 700W...  Ramtons  19999
# 1      2        Nunix Digital Microwave Oven 20L WITH GRILL    Nunix   9999
# 2      3       Nunix 20L Electric Oven With Grill (3 Knobs)    Nunix  15200
# 3      4  Nunix  3 IN 1 BREAKFAST MAKER, TOASTER,OVEN, C...    Nunix   7799
# 4      5  Ramtons RM/684-25 LITERS MICROWAVE+GRILL (1YR ...  Ramtons   8199
# ..   ...                                                ...      ...    ...
# 191  192                     Nunix 20l Microwave with Grill    Nunix    900
# 192  193  Roch Manual Microwave Oven 700W, 20L – RMW-20L...     Roch   7999
# 193  194                    Synix Syinix 20l microwave oven    Synix   1250
# 194  195                  Nunix 20L Electric Microwave Oven    Nunix   1080
# 195  196                       HANMAC microwave  20l manual   HANMAC   2149
#
#      Old_price  capacity  Reviews source  \
# 0        11800      20.0      4.6  Jumia
# 1        11080      20.0      4.3  Jumia
# 2         9999      20.0      4.2  Jumia
# 3        12000       NaN      2.0  Jumia
# 4        19999      25.0      4.5  Jumia
# ..         ...       ...      ...    ...
# 191      12000      20.0      5.0  Jumia
# 192      16999      20.0      5.0  Jumia
# 193       3000      20.0      5.0  Jumia
# 194      12500      20.0      4.0  Jumia
# 195       9500      20.0      5.0  Jumia
#
#                                                   urls
# 0    https://www.jumia.co.ke/hisense-30l-microwave-...
# 1    https://www.jumia.co.ke/haier-hmw20dbm-digital...
# 2    https://www.jumia.co.ke/hisense-h25moms7hg-25l...
# 3    https://www.jumia.co.ke/smart-pro-20l-digital-...
# 4    https://www.jumia.co.ke/haier-hmw20mb-analog-m...
# ..                                                 ...
# 191  https://www.jumia.co.ke/generic-microwave-dust...
# 192  https://www.jumia.co.ke/synix-5.5l-air-fryer-2...
# 193  https://www.jumia.co.ke/generic-1pc-non-slip-k...
# 194  https://www.jumia.co.ke/generic-cake-turntable...
# 195  https://www.jumia.co.ke/generic-high-voltage-d...
#
# [196 rows x 9 columns]
