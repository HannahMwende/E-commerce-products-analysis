# %%
import pandas as pd
import re

# %%
df = pd.read_csv(r"C:\Users\Vivian.Obino1\Desktop\e-commerce analysis\kilimall_microwaves_no_rating.csv")

# %%
print(df)
# Out:
#                                         microwaves_name microwaves_reviews  \
# 0     Hisense Microwave Oven H20MOWS11 700W 20L Digi...              (366)
# 1     Roch 20Ltrs Digital Microwave Oven High Qualit...               (46)
# 2     SmartPro 20Ltrs Digital Microwave Oven High Qu...                (2)
# 3     CLEARANCE SALE!! Hisense 20L Digital Microwave...                (0)
# 4     Hisense Microwave Oven H20MOMS11 700W 20L Digi...               (31)
# ...                                                 ...                ...
# 1435  CLEARANCE OFFER Nunix Full gas free Standing c...                (0)
# 1436  CLEARANCE OFFER Eurochef 3+1 Free Stand Glass ...                (0)
# 1437  CLEARANCE OFFER Eurochef Full gas Free Standin...                (0)
# 1438  CLEARANCE OFFER Eurochef EGT55-3G1E-E 55*50 3 ...                (0)
# 1439  CLEARANCE OFFER Nunix 60x60 3+1 Electric Free ...                (0)
#
#      microwaves_price
# 0           KSh 8,899
# 1           KSh 8,499
# 2           KSh 8,199
# 3           KSh 8,790
# 4          KSh 10,299
# ...               ...
# 1435       KSh 20,999
# 1436       KSh 25,999
# 1437       KSh 19,499
# 1438       KSh 25,999
# 1439       KSh 25,999
#
# [1440 rows x 3 columns]

# %%
df_cleaned = df.dropna()

# %%
df_cleaned = df.drop_duplicates()
print(df_cleaned.head())
# Out:
#                                      microwaves_name microwaves_reviews  \
# 0  Hisense Microwave Oven H20MOWS11 700W 20L Digi...              (366)
# 1  Roch 20Ltrs Digital Microwave Oven High Qualit...               (46)
# 2  SmartPro 20Ltrs Digital Microwave Oven High Qu...                (2)
# 3  CLEARANCE SALE!! Hisense 20L Digital Microwave...                (0)
# 4  Hisense Microwave Oven H20MOMS11 700W 20L Digi...               (31)
#
#   microwaves_price
# 0        KSh 8,899
# 1        KSh 8,499
# 2        KSh 8,199
# 3        KSh 8,790
# 4       KSh 10,299

# %%
df.shape
# Out:
# (1440, 3)

# %%
df['microwaves_price']= df['microwaves_price'].str.strip('KSh,')
df
# Out:
#                                         microwaves_name microwaves_reviews  \
# 0     Hisense Microwave Oven H20MOWS11 700W 20L Digi...              (366)
# 1     Roch 20Ltrs Digital Microwave Oven High Qualit...               (46)
# 2     SmartPro 20Ltrs Digital Microwave Oven High Qu...                (2)
# 3     CLEARANCE SALE!! Hisense 20L Digital Microwave...                (0)
# 4     Hisense Microwave Oven H20MOMS11 700W 20L Digi...               (31)
# ...                                                 ...                ...
# 1435  CLEARANCE OFFER Nunix Full gas free Standing c...                (0)
# 1436  CLEARANCE OFFER Eurochef 3+1 Free Stand Glass ...                (0)
# 1437  CLEARANCE OFFER Eurochef Full gas Free Standin...                (0)
# 1438  CLEARANCE OFFER Eurochef EGT55-3G1E-E 55*50 3 ...                (0)
# 1439  CLEARANCE OFFER Nunix 60x60 3+1 Electric Free ...                (0)
#
#      microwaves_price
# 0               8,899
# 1               8,499
# 2               8,199
# 3               8,790
# 4              10,299
# ...               ...
# 1435           20,999
# 1436           25,999
# 1437           19,499
# 1438           25,999
# 1439           25,999
#
# [1440 rows x 3 columns]

# %%
df['microwaves_reviews'] = df['microwaves_reviews'].str.extract(r'(\d+)').astype(int)
df
# Out:
#                                         microwaves_name  microwaves_reviews  \
# 0     Hisense Microwave Oven H20MOWS11 700W 20L Digi...                 366
# 1     Roch 20Ltrs Digital Microwave Oven High Qualit...                  46
# 2     SmartPro 20Ltrs Digital Microwave Oven High Qu...                   2
# 3     CLEARANCE SALE!! Hisense 20L Digital Microwave...                   0
# 4     Hisense Microwave Oven H20MOMS11 700W 20L Digi...                  31
# ...                                                 ...                 ...
# 1435  CLEARANCE OFFER Nunix Full gas free Standing c...                   0
# 1436  CLEARANCE OFFER Eurochef 3+1 Free Stand Glass ...                   0
# 1437  CLEARANCE OFFER Eurochef Full gas Free Standin...                   0
# 1438  CLEARANCE OFFER Eurochef EGT55-3G1E-E 55*50 3 ...                   0
# 1439  CLEARANCE OFFER Nunix 60x60 3+1 Electric Free ...                   0
#
#      microwaves_price
# 0               8,899
# 1               8,499
# 2               8,199
# 3               8,790
# 4              10,299
# ...               ...
# 1435           20,999
# 1436           25,999
# 1437           19,499
# 1438           25,999
# 1439           25,999
#
# [1440 rows x 3 columns]

# %%
# List of unwanted words (make sure all variations are included)
unwanted_words = ['clearance', 'CLEARANCE', 'SALE', 'OFFER', 'Best', 'CHOOSE', 'Offers', 'QUALITY', 'THE', 'FUTURE',
                  'EMBRACE', 'LATEST', 'TREND', 'MEGASALE', 'Buy', 'NOW', 'AND', 'ENJOY', 'UPTO', 'NEW', 'IMPROVED', 
                  'STAY', 'LOCKED', 'WITH', 'STOCK', 'kilimall', 'special', 'MAKE', 'YOUR', 'HOUSE', 'FEEL', 'LIKE', 
                  'Super', 'deal', 'quality', 'RESTOCKED', 'Share', 'this', 'product', 'Best', 'ARRIVALS', 'HURRY', 
                  'AND', 'PICK', 'YOURS', 'LIMITED', 'AN', 'NO', 'OTHER', 'PRICE', 'REDUCED', 'NOWBLACK', 'Angry', 
                  'mama', 'kitchen','EXPERIENCE', 'New', 'Arrival', 'Classy', 'sale', 'offer', 'best', 'discount', 
                  'cheap', 'deal']

# Convert the unwanted_words list to lowercase for case-insensitive comparison
unwanted_words = set(word.lower() for word in unwanted_words)

# Function to remove unwanted words from a text
def remove_unwanted_words(text):
    if not isinstance(text, str):
        return text  # Return as is if not a string
    words = text.split()  # Split the text into individual words
    cleaned_words = [word for word in words if word.lower() not in unwanted_words]  # Filter out unwanted words
    return ' '.join(cleaned_words)  # Join the cleaned words back into a string

file_path =(r"C:\Users\Vivian.Obino1\Desktop\e-commerce analysis\kilimall_microwaves_no_rating.csv") # Replace with your actual file path
df = pd.read_csv(file_path)

# Apply the function to the relevant column (e.g., 'microwaves_name')
df['microwaves_name'] = df['microwaves_name'].apply(remove_unwanted_words)

# Save the updated DataFrame to a new CSV file
output_file_path = 'cleanedmicrowaves_file.csv'
df.to_csv(output_file_path, index=False)

print(f"Cleaned data saved to {output_file_path}")
# Out:
# Cleaned data saved to cleanedmicrowaves_file.csv

# %%
# Load the CSV file into a DataFrame
file_path = 'kilimall_microwaves_no_rating.csv'  # Replace with your CSV file path
df = pd.read_csv(file_path)

# Function to clean text
def clean_text(text):
    # Remove punctuation, emojis, and parentheses
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s*\([^)]*\)\s*', '', text)  # Remove parentheses and their content
    text = re.sub(r'[^\x00-\x7F]+', '', text)  # Remove emojis and non-ASCII characters
    return text.strip()
  
# Extract brand name and clean it
def extract_brand_name(text):
    words = clean_text(text).split()[:5]  # Get first five words
    return ' '.join(words)
def extract_capacity(text):
    if not isinstance(text, str):
        return None
    match = re.search(r'\b\d+\.?\d*\s*(L|Ltrs|Liters|Litres)\b', text, re.IGNORECASE)
    return match.group(0) if match else None
def remove_parentheses(text):
    if not isinstance(text, str):
        return text
    return re.sub(r'\s*\([^)]*\)\s*', '', text)

# Apply the function to the 'microwave_reviews' column


# Apply the brand name extraction
df['microwaves_name'] = df['microwaves_name'].apply(extract_brand_name)  # Replace 'ColumnName' with the relevant column name
df['Capacity'] = df['microwaves_name'].apply(extract_capacity) 
# Lines to remove
lines_to_remove = [*range(12, 19), 83, 84, 127, 128, 131, *range(155, 160), *range(608, 624), 
                   *range(652, 658), *range(675, 683), *range(686, 692), 461, 463, *range(187, 197), 
                   *range(257, 267), 275, 342, 343, *range(769, 806), *range(832, 839)]

# Drop specified rows (subtract 1 to account for zero-based index in Python)
df.drop(index=[i-1 for i in lines_to_remove], inplace=True, errors='ignore')
# Rename the columns
df.columns = ['brand', 'reviews', 'price', 'capacity']   
# Save the cleaned DataFrame to a new CSV file
output_file_path = 'cleanedmicrowaves_file.csv'
df.to_csv(output_file_path, index=False)

print("Data processing complete. Cleaned file saved as:", output_file_path)
# Out:
# Data processing complete. Cleaned file saved as: cleanedmicrowaves_file.csv

# %%
df
# Out:
#                                          brand reviews       price capacity
# 0        Hisense Microwave Oven H20MOWS11 700W   (366)   KSh 8,899     None
# 1           Roch 20Ltrs Digital Microwave Oven    (46)   KSh 8,499   20Ltrs
# 2       SmartPro 20Ltrs Digital Microwave Oven     (2)   KSh 8,199   20Ltrs
# 3           CLEARANCE SALE Hisense 20L Digital     (0)   KSh 8,790      20L
# 4        Hisense Microwave Oven H20MOMS11 700W    (31)  KSh 10,299     None
# ...                                        ...     ...         ...      ...
# 1435            CLEARANCE OFFER Nunix Full gas     (0)  KSh 20,999     None
# 1436          CLEARANCE OFFER Eurochef 31 Free     (0)  KSh 25,999     None
# 1437         CLEARANCE OFFER Eurochef Full gas     (0)  KSh 19,499     None
# 1438  CLEARANCE OFFER Eurochef EGT553G1EE 5550     (0)  KSh 25,999     None
# 1439            CLEARANCE OFFER Nunix 60x60 31     (0)  KSh 25,999     None
#
# [1318 rows x 4 columns]

# %%
df['price']= df['price'].str.strip('KSh,')
df
# Out:
#                                          brand reviews    price capacity
# 0        Hisense Microwave Oven H20MOWS11 700W   (366)    8,899     None
# 1           Roch 20Ltrs Digital Microwave Oven    (46)    8,499   20Ltrs
# 2       SmartPro 20Ltrs Digital Microwave Oven     (2)    8,199   20Ltrs
# 3           CLEARANCE SALE Hisense 20L Digital     (0)    8,790      20L
# 4        Hisense Microwave Oven H20MOMS11 700W    (31)   10,299     None
# ...                                        ...     ...      ...      ...
# 1435            CLEARANCE OFFER Nunix Full gas     (0)   20,999     None
# 1436          CLEARANCE OFFER Eurochef 31 Free     (0)   25,999     None
# 1437         CLEARANCE OFFER Eurochef Full gas     (0)   19,499     None
# 1438  CLEARANCE OFFER Eurochef EGT553G1EE 5550     (0)   25,999     None
# 1439            CLEARANCE OFFER Nunix 60x60 31     (0)   25,999     None
#
# [1318 rows x 4 columns]

# %%
def retain_text_in_parentheses(text):
    if not isinstance(text, str):
        return text  # Return as is if not a string
    return re.sub(r'[()]', '', text)  # Remove only parentheses

# Apply the function to the desired column
df['reviews'] = df['reviews'].apply(retain_text_in_parentheses)
df
# Out:
#                                          brand reviews    price capacity
# 0        Hisense Microwave Oven H20MOWS11 700W     366    8,899     None
# 1           Roch 20Ltrs Digital Microwave Oven      46    8,499   20Ltrs
# 2       SmartPro 20Ltrs Digital Microwave Oven       2    8,199   20Ltrs
# 3           CLEARANCE SALE Hisense 20L Digital       0    8,790      20L
# 4        Hisense Microwave Oven H20MOMS11 700W      31   10,299     None
# ...                                        ...     ...      ...      ...
# 1435            CLEARANCE OFFER Nunix Full gas       0   20,999     None
# 1436          CLEARANCE OFFER Eurochef 31 Free       0   25,999     None
# 1437         CLEARANCE OFFER Eurochef Full gas       0   19,499     None
# 1438  CLEARANCE OFFER Eurochef EGT553G1EE 5550       0   25,999     None
# 1439            CLEARANCE OFFER Nunix 60x60 31       0   25,999     None
#
# [1318 rows x 4 columns]

# %%
df['price'] = df['price'].replace({',': ''}, regex=True)

df['price'] = pd.to_numeric(df['price'])

# %%
df.to_csv(r'C:\Users\Vivian.Obino1\Desktop\e-commerce analysis\cleanedmicrowaves_file.csv', sep=',', index=False, encoding='utf-8')
