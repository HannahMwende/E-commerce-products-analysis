# %% [markdown]
# # Webscraping

# %%
# Import necessary libraries
import requests # make HTTP requests to fetch web pages content
from bs4 import BeautifulSoup # parse HTML and XML docs for easier data extraction
import csv # write scraped data into CSV file
import time # introduce delays between requests to avoid server overload
import re #regular expression
import random # vary time delays to simulate human-like behaviour
import psycopg2 #py package to interact with PostgreSQL
from psycopg2 import sql
import logging
import json

# %% [markdown]
# # Configure logging
# logging.basicConfig(
#     level=logging.INFO,
#     format='%(asctime)s - %(levelname)s - %(message)s',
#     handlers=[
#         logging.FileHandler('jumia_scraping.log'),
#         logging.StreamHandler()  # Also show logs in console
#     ]
# )

# %%
# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('jumia_scraping.log'),
        logging.StreamHandler()  # Also show logs in console
    ]
)

# %% [markdown]
# **Webscraping Page: Jumia**
#
# _Products to scrape:_
# 1. Tvs
#     * Smart
#     * Digital
# 2. Cookers

# %%
# request url
url1 = 'https://www.jumia.co.ke/televisions/#catalog-listing' # TVs url
url2 = 'https://www.jumia.co.ke/home-cooking-appliances-cookers/#catalog-listing' # Cookers url

# User-Agent headers for automating requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %% [markdown]
# Check url status

# %%
# Sending GET requests to each URL and check response
def check_response(urls, headers):
    # Output the status code of each response
    for url in urls:
        try:
            response =requests.get(url, headers=headers)
            print(f"url: {response.url} - status: { response.status_code}")

            if response.status_code != 200:
                print(f"Failed to retrieve page. Status code: {response.status_code}")
                return 1  # Return 1 if the request fails
        except requests.exceptions.RequestException as e:
            # Handle GET request exceptions (timeout, connection/http errors etc.)
            print(f"An error occured: {e}")
            return 1  # Return 1 if an error occurs during the request
        
    return 0  # Return 0 if no error

# List of urls
urls = [url1, url2]
responses = check_response(urls, headers=headers) # Check all url GET requests responses

# Check result
if responses == 0:
    print("All pages retrieved successfully.")
else:
    print("Some pages failed to load.")
# Out:
# url: https://www.jumia.co.ke/televisions/#catalog-listing - status: 200
# url: https://www.jumia.co.ke/home-cooking-appliances-cookers/#catalog-listing - status: 200
# All pages retrieved successfully.

# %% [markdown]
# Considering that the webpages are paginated, there is need to navigatethrough, and retrieve data from each page.
# The last page in the page numbers is identified, then all pages are iterated.
#
# The pagination URL parameters...

# %%
# Define function to get the last page number
def get_last_page_number(urls, headers):
    """
    get the last page number in a catalog listing for pagination iteration

    args:
        urls: webpage URL or URLs
        headers: User-Agent headers
    """
    # Parse webpage content with BeautifulSoup
    #for url in urls:
    response =requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find link for last page using its aria-label attribute
    last_page_link = soup.find('a', attrs={'aria-label': 'Last Page'})

    if last_page_link and 'href' in last_page_link.attrs:
        last_page_url =last_page_link['href']
        try:
            page_number = last_page_url.split('?page=')[1].split('#')[0]
            return int(page_number)
        except Exception as e:
            print(f"Error extracting last page number: {e}")
            return 1  # Default to 1 if error occurs

# %%
def scrape_product_details(url, headers):
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        # Find all product articles
        product_articles = soup.find_all('article', {'class': 'prd _fb col c-prd'})
        
        logging.info(f"Found {len(product_articles)} products on {url}")
        
        products = []
        for article in product_articles:
            try:
                # Find the core link which contains most product data
                core_link = article.find('a', {'class': 'core'})
                if not core_link:
                    continue

                # Extract data from data-ga4 attributes which contain the most reliable info
                item_id = core_link.get('data-ga4-item_id', "N/A")
                name = core_link.get('data-ga4-item_name', "N/A")
                brand = core_link.get('data-ga4-item_brand', "N/A")
                price = core_link.get('data-ga4-price', "N/A")
                discount = core_link.get('data-ga4-discount', "N/A")
                category = core_link.get('data-ga4-item_category', "N/A")
                subcategory = core_link.get('data-ga4-item_category2', "N/A")
                
                # Get product URL
                product_url = core_link.get('href')
                if product_url:
                    product_url = f"https://www.jumia.co.ke{product_url}"
                else:
                    product_url = "N/A"

                # Extract displayed price and old price
                price_elem = article.find('div', {'class': 'prc'})
                displayed_price = price_elem.text.strip() if price_elem else "N/A"
                
                old_price_elem = article.find('div', {'class': 'old'})
                old_price = old_price_elem.text.strip() if old_price_elem else "N/A"

                # Extract rating information
                stars_elem = article.find('div', {'class': 'stars _s'})
                reviews_count = "0"
                rating = "N/A"
                
                if stars_elem:
                    rating_text = stars_elem.text.strip()
                    if 'out of 5' in rating_text:
                        rating = rating_text.split('out of 5')[0].strip()
                    
                    # Find review count
                    rev_elem = article.find('div', {'class': 'rev'})
                    if rev_elem:
                        reviews_text = rev_elem.text
                        reviews_count = reviews_text.strip('()') if '(' in reviews_text else "0"

                # Check if it's from official store
                is_official = bool(article.find('div', {'class': 'bdg _mall _xs'}))

                # Check if express shipping is available
                has_express = bool(article.find('svg', {'class': 'ic xprss'}))

                if item_id != "N/A":  # Only add products with valid IDs
                    products.append({
                        "product_name": name,
                        "price": displayed_price,
                        "price_value": price,  # Numerical price value
                        "old_price": old_price,
                        "discount_percentage": discount,
                        "rating": rating,
                        "reviews_count": reviews_count,
                        "item_id": item_id,
                        "item_brand": brand,
                        "product_url": product_url,
                        "category": category,
                        "subcategory": subcategory,
                        "is_official_store": is_official,
                        "has_express_shipping": has_express
                    })
                    
            except Exception as e:
                logging.warning(f"Error extracting product details: {str(e)}")
                continue
                
        logging.info(f"Successfully extracted {len(products)} valid products")
        return products
        
    except requests.exceptions.RequestException as e:
        logging.error(f"Request failed for {url}: {str(e)}")
        return []
    except Exception as e:
        logging.error(f"Unexpected error scraping {url}: {str(e)}")
        return []

# %%
# Function to get the last page number from the website using the 'Last Page' link
def get_last_page_number(url, headers):
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the 'Last Page' link using its aria-label attribute
    last_page_link = soup.find('a', attrs={'aria-label': 'Last Page'})
    
    if last_page_link and 'href' in last_page_link.attrs:
        last_page_url = last_page_link['href']
        try:
            page_number = last_page_url.split('?page=')[1].split('#')[0]
            return int(page_number)
        except Exception as e:
            print(f"Error extracting last page number: {e}")
            return 1  # Default to 1 if error occurs
    else:
        print("Last page link not found.")
        return 1  # Default to 1 page if no last page is found

# %%
def save_to_postgresql(products, db_params, table_name):
    try:
        # Connect to PostgreSQL database
        conn = psycopg2.connect(**db_params)
        cursor = conn.cursor()
        
        logging.info(f"Attempting to insert {len(products)} products into {table_name}")
        
        # Create temporary table matching exact schema
        temp_table = f"temp_{table_name}_{int(time.time())}"
        cursor.execute(f"""
            CREATE TEMP TABLE {temp_table} (
                product_name text,
                price text,
                old_price text,
                discount text,
                rating text,
                item_id text,
                item_brand text,
                product_url text
            )
        """)
        
        # Prepare data for insertion
        insert_data = []
        for product in products:
            # Format data to match schema exactly
            row = (
                product["product_name"],
                product["price"],
                product["old_price"],
                product["discount_percentage"],
                f"{product['rating']} ({product['reviews_count']} reviews)",
                product["item_id"],
                product["item_brand"],
                product["product_url"]
            )
            insert_data.append(row)
        
        # Batch insert into temp table
        cursor.executemany(f"""
            INSERT INTO {temp_table} 
            (product_name, price, old_price, discount, rating, item_id, item_brand, product_url)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        """, insert_data)
        
        # Insert only new records from temp table to target table
        insert_query = f"""
            INSERT INTO {table_name}
            SELECT t.*
            FROM {temp_table} t
            LEFT JOIN {table_name} m ON m.item_id = t.item_id
            WHERE m.item_id IS NULL
        """
        cursor.execute(insert_query)
        
        # Get counts for logging
        cursor.execute(f"SELECT COUNT(*) FROM {temp_table}")
        temp_count = cursor.fetchone()[0]
        
        cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
        final_count = cursor.fetchone()[0]
        
        # Get count of newly inserted records
        cursor.execute(f"""
            SELECT COUNT(*) FROM {table_name} m
            WHERE EXISTS (
                SELECT 1 FROM {temp_table} t
                WHERE t.item_id = m.item_id
            )
        """)
        new_records = cursor.fetchone()[0]
        
        conn.commit()
        logging.info(f"Processed {temp_count} products for {table_name}")
        logging.info(f"Inserted {new_records} new records into {table_name}")
        logging.info(f"Table {table_name} now has {final_count} total records")
        
    except Exception as e:
        logging.error(f"Database error while processing {table_name}: {str(e)}")
        if conn:
            conn.rollback()
        raise
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()

# %%
def scrape_and_save(url, headers, db_params, table_name):
    print(f"\nStarting scrape for {table_name}")
    
    try:
        # Get last page number
        last_page = get_last_page_number(url, headers)
        print(f"Found {last_page} pages to scrape")
        
        # Initialize products list
        all_products = []
        
        # Scrape each page
        for page_num in range(1, last_page + 1):
            page_url = f"{url}?page={page_num}#catalog-listing"
            print(f"Scraping page {page_num}/{last_page}")
            
            # Scrape products from current page
            page_products = scrape_product_details(page_url, headers)
            print(f"Found {len(page_products)} products on page {page_num}")
            all_products.extend(page_products)
            
            # Random delay
            time.sleep(random.uniform(1, 3))
        
        print(f"Total products scraped: {len(all_products)}")
        
        # Verify first product data before saving
        if all_products:
            print("\nSample of first product data:")
            print(json.dumps(all_products[0], indent=2))
        
        # Save products to database
        if all_products:
            print(f"\nAttempting to save {len(all_products)} products to {table_name}")
            save_to_postgresql(all_products, db_params, table_name)
        else:
            print("No products found to save!")
            
    except Exception as e:
        print(f"Error in scrape_and_save: {str(e)}")
        raise

def save_to_postgresql(products, db_params, table_name):
    conn = None
    cursor = None
    try:
        # Connect to PostgreSQL database
        print("Connecting to database...")
        conn = psycopg2.connect(**db_params)
        cursor = conn.cursor()
        
        print(f"Connected successfully. Inserting {len(products)} products...")
        
        # Simple insert query
        insert_query = f"""
            INSERT INTO {table_name} 
            (product_name, price, old_price, discount, rating, item_id, item_brand, product_url)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        """
        
        # Insert each product and commit after each successful insert
        for i, product in enumerate(products, 1):
            try:
                row = (
                    product["product_name"],
                    product["price"],
                    product["old_price"],
                    product["discount_percentage"],
                    f"{product['rating']} ({product['reviews_count']} reviews)",
                    product["item_id"],
                    product["item_brand"],
                    product["product_url"]
                )
                
                cursor.execute(insert_query, row)
                conn.commit()  # Commit after each insert
                
                if i % 100 == 0:
                    print(f"Inserted {i} products...")
                
            except Exception as e:
                print(f"Error inserting product {i}: {str(e)}")
                print(f"Problem product data: {json.dumps(product, indent=2)}")
                continue
        
        # Verify final count
        cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
        final_count = cursor.fetchone()[0]
        print(f"\nFinal count in {table_name}: {final_count}")
        
        # Show sample of inserted data
        print("\nVerifying inserted data...")
        cursor.execute(f"SELECT * FROM {table_name} LIMIT 1")
        sample = cursor.fetchone()
        if sample:
            print("Sample record:", sample)
        else:
            print("No records found in database!")
        
    except Exception as e:
        print(f"Database error: {str(e)}")
        if conn:
            conn.rollback()
        raise
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()
        print("Database connection closed.")

# Main execution
if __name__ == "__main__":
    try:
        # Your headers and db_params here
        
        # Test database connection first
        print("Testing database connection...")
        conn = psycopg2.connect(**db_params)
        conn.close()
        print("Database connection successful!")
        
        # URLs
        url1 = "https://www.jumia.co.ke/televisions/"
        url2 = "https://www.jumia.co.ke/home-cooking-appliances-cookers/"
        
        # Scrape and save data for both URLs
        scrape_and_save(url1, headers, db_params, "jumia_televisions")
        scrape_and_save(url2, headers, db_params, "jumia_cookers")
        
    except Exception as e:
        print(f"Main execution error: {str(e)}")
# Out:
# Testing database connection...
# Database connection successful!
#
# Starting scrape for jumia_televisions
# Found 50 pages to scrape
# Scraping page 1/50
# 2025-01-10 20:25:48,041 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=1#catalog-listing
# 2025-01-10 20:25:48,047 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 1
# Scraping page 2/50
# 2025-01-10 20:25:50,412 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=2#catalog-listing
# 2025-01-10 20:25:50,422 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 2
# Scraping page 3/50
# 2025-01-10 20:25:52,180 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=3#catalog-listing
# 2025-01-10 20:25:52,190 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 3
# Scraping page 4/50
# 2025-01-10 20:25:54,364 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=4#catalog-listing
# 2025-01-10 20:25:54,384 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 4
# Scraping page 5/50
# 2025-01-10 20:25:56,885 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=5#catalog-listing
# 2025-01-10 20:25:56,902 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 5
# Scraping page 6/50
# 2025-01-10 20:26:04,116 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=6#catalog-listing
# 2025-01-10 20:26:04,136 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 6
# Scraping page 7/50
# 2025-01-10 20:26:07,585 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=7#catalog-listing
# 2025-01-10 20:26:07,604 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 7
# Scraping page 8/50
# 2025-01-10 20:26:11,254 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=8#catalog-listing
# 2025-01-10 20:26:11,273 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 8
# Scraping page 9/50
# 2025-01-10 20:26:14,338 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=9#catalog-listing
# 2025-01-10 20:26:14,356 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 9
# Scraping page 10/50
# 2025-01-10 20:26:48,184 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=10#catalog-listing
# 2025-01-10 20:26:48,191 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 10
# Scraping page 11/50
# 2025-01-10 20:26:50,172 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=11#catalog-listing
# 2025-01-10 20:26:50,180 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 11
# Scraping page 12/50
# 2025-01-10 20:26:51,953 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=12#catalog-listing
# 2025-01-10 20:26:51,953 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 12
# Scraping page 13/50
# 2025-01-10 20:26:55,168 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=13#catalog-listing
# 2025-01-10 20:26:55,178 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 13
# Scraping page 14/50
# 2025-01-10 20:26:57,106 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=14#catalog-listing
# 2025-01-10 20:26:57,113 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 14
# Scraping page 15/50
# 2025-01-10 20:26:58,799 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=15#catalog-listing
# 2025-01-10 20:26:58,806 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 15
# Scraping page 16/50
# 2025-01-10 20:27:01,461 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=16#catalog-listing
# 2025-01-10 20:27:01,470 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 16
# Scraping page 17/50
# 2025-01-10 20:27:04,541 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=17#catalog-listing
# 2025-01-10 20:27:04,564 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 17
# Scraping page 18/50
# 2025-01-10 20:27:09,073 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=18#catalog-listing
# 2025-01-10 20:27:09,081 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 18
# Scraping page 19/50
# 2025-01-10 20:27:12,217 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=19#catalog-listing
# 2025-01-10 20:27:12,224 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 19
# Scraping page 20/50
# 2025-01-10 20:27:14,230 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=20#catalog-listing
# 2025-01-10 20:27:14,233 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 20
# Scraping page 21/50
# 2025-01-10 20:27:17,667 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=21#catalog-listing
# 2025-01-10 20:27:17,673 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 21
# Scraping page 22/50
# 2025-01-10 20:27:19,669 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=22#catalog-listing
# 2025-01-10 20:27:19,683 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 22
# Scraping page 23/50
# 2025-01-10 20:27:23,403 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=23#catalog-listing
# 2025-01-10 20:27:23,413 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 23
# Scraping page 24/50
# 2025-01-10 20:27:25,988 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=24#catalog-listing
# 2025-01-10 20:27:26,000 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 24
# Scraping page 25/50
# 2025-01-10 20:27:28,909 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=25#catalog-listing
# 2025-01-10 20:27:28,918 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 25
# Scraping page 26/50
# 2025-01-10 20:27:31,119 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=26#catalog-listing
# 2025-01-10 20:27:31,123 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 26
# Scraping page 27/50
# 2025-01-10 20:27:33,237 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=27#catalog-listing
# 2025-01-10 20:27:33,243 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 27
# Scraping page 28/50
# 2025-01-10 20:28:00,135 - INFO - Found 0 products on https://www.jumia.co.ke/televisions/?page=28#catalog-listing
# 2025-01-10 20:28:00,135 - INFO - Successfully extracted 0 valid products
# Found 0 products on page 28
# Scraping page 29/50
# 2025-01-10 20:28:02,369 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=29#catalog-listing
# 2025-01-10 20:28:02,383 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 29
# Scraping page 30/50
# 2025-01-10 20:28:05,383 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=30#catalog-listing
# 2025-01-10 20:28:05,392 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 30
# Scraping page 31/50
# 2025-01-10 20:28:07,386 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=31#catalog-listing
# 2025-01-10 20:28:07,393 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 31
# Scraping page 32/50
# 2025-01-10 20:28:10,903 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=32#catalog-listing
# 2025-01-10 20:28:10,912 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 32
# Scraping page 33/50
# 2025-01-10 20:28:13,314 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=33#catalog-listing
# 2025-01-10 20:28:13,320 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 33
# Scraping page 34/50
# 2025-01-10 20:28:16,811 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=34#catalog-listing
# 2025-01-10 20:28:16,820 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 34
# Scraping page 35/50
# 2025-01-10 20:28:19,064 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=35#catalog-listing
# 2025-01-10 20:28:19,071 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 35
# Scraping page 36/50
# 2025-01-10 20:28:21,187 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=36#catalog-listing
# 2025-01-10 20:28:21,195 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 36
# Scraping page 37/50
# 2025-01-10 20:28:23,221 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=37#catalog-listing
# 2025-01-10 20:28:23,227 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 37
# Scraping page 38/50
# 2025-01-10 20:28:25,259 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=38#catalog-listing
# 2025-01-10 20:28:25,267 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 38
# Scraping page 39/50
# 2025-01-10 20:28:28,492 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=39#catalog-listing
# 2025-01-10 20:28:28,498 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 39
# Scraping page 40/50
# 2025-01-10 20:28:32,084 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=40#catalog-listing
# 2025-01-10 20:28:32,093 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 40
# Scraping page 41/50
# 2025-01-10 20:28:34,908 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=41#catalog-listing
# 2025-01-10 20:28:34,914 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 41
# Scraping page 42/50
# 2025-01-10 20:28:37,988 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=42#catalog-listing
# 2025-01-10 20:28:37,997 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 42
# Scraping page 43/50
# 2025-01-10 20:28:39,869 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=43#catalog-listing
# 2025-01-10 20:28:39,873 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 43
# Scraping page 44/50
# 2025-01-10 20:28:43,298 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=44#catalog-listing
# 2025-01-10 20:28:43,306 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 44
# Scraping page 45/50
# 2025-01-10 20:28:46,431 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=45#catalog-listing
# 2025-01-10 20:28:46,439 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 45
# Scraping page 46/50
# 2025-01-10 20:28:49,965 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=46#catalog-listing
# 2025-01-10 20:28:49,972 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 46
# Scraping page 47/50
# 2025-01-10 20:28:52,274 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=47#catalog-listing
# 2025-01-10 20:28:52,281 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 47
# Scraping page 48/50
# 2025-01-10 20:28:55,984 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=48#catalog-listing
# 2025-01-10 20:28:55,994 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 48
# Scraping page 49/50
# 2025-01-10 20:28:58,076 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=49#catalog-listing
# 2025-01-10 20:28:58,088 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 49
# Scraping page 50/50
# 2025-01-10 20:29:00,279 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=50#catalog-listing
# 2025-01-10 20:29:00,284 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 50
# Total products scraped: 1960
#
# Sample of first product data:
# {
#   "product_name": "HTC4388FS - 43\" Smart  Android Frameless TV - Black (1YR WRTY)",
#   "price": "KSh 19,459",
#   "price_value": "145.87",
#   "old_price": "KSh 28,599",
#   "discount_percentage": "68.52",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(2436",
#   "item_id": "VI505EA0KTU37NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc4388fs-43-smart-android-frameless-tv-black-1yr-wrty-93348943.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
#
# Attempting to save 1960 products to jumia_televisions
# Connecting to database...
# Connected successfully. Inserting 1960 products...
# Error inserting product 1: duplicate key value violates unique constraint "jumia_televisions_item_id_key"
# DETAIL:  Key (item_id)=(VI505EA0KTU37NAFAMZ) already exists.
#
# Problem product data: {
#   "product_name": "HTC4388FS - 43\" Smart  Android Frameless TV - Black (1YR WRTY)",
#   "price": "KSh 19,459",
#   "price_value": "145.87",
#   "old_price": "KSh 28,599",
#   "discount_percentage": "68.52",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(2436",
#   "item_id": "VI505EA0KTU37NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc4388fs-43-smart-android-frameless-tv-black-1yr-wrty-93348943.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 2: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)",
#   "price": "KSh 9,799",
#   "price_value": "73.46",
#   "old_price": "KSh 15,995",
#   "discount_percentage": "46.45",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(851",
#   "item_id": "VI799EA1QMSQ4NAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-32-digital-hd-frameless-tv-dvbt2s2-black-2yrs-wrty-125899150.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 3: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32R1S, 32\" Inch Smart Android TV 1GB DDR,8GB ROM,4-CORE LED TV (1YR WRTY)",
#   "price": "KSh 11,099",
#   "price_value": "83.20",
#   "old_price": "KSh 19,000",
#   "discount_percentage": "59.23",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(245",
#   "item_id": "AM617EA0HFVIJNAFAMZ",
#   "item_brand": "Amtec",
#   "product_url": "https://www.jumia.co.ke/amtec-32r1s-32-inch-smart-android-tv-1gb-ddr8gb-rom4-core-led-tv-1yr-wrty-55149292.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 4: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC6588USWO, 65\" 4K Smart Frameless TV, Wi-Fi/Netflix, 1YR WRTY",
#   "price": "KSh 63,999",
#   "price_value": "479.76",
#   "old_price": "KSh 99,999",
#   "discount_percentage": "269.87",
#   "rating": "4.7",
#   "reviews_count": "4.7 out of 5(20",
#   "item_id": "VI505EA0K42QFNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc6588uswo-65-4k-smart-frameless-tv-wi-finetflix-1yr-wrty-78428733.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 5: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S, 32\" Smart Frameless Android LED TV, With Bluetooth, (1YR WRTY)",
#   "price": "KSh 11,413",
#   "price_value": "85.56",
#   "old_price": "KSh 15,000",
#   "discount_percentage": "26.89",
#   "rating": "4",
#   "reviews_count": "4 out of 5(598",
#   "item_id": "VI505EA3X4HB8NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s-32-smart-frameless-android-led-tv-with-bluetooth-1yr-wrty-261943073.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 6: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S,32\"Inch Bluetooth Enabled Frameless Smart Android TV Inbuilt Decoder NetflixYoutube Appstor",
#   "price": "KSh 13,285",
#   "price_value": "99.59",
#   "old_price": "KSh 16,500",
#   "discount_percentage": "24.10",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(1502",
#   "item_id": "VI505EA1AUSHINAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s32inch-bluetooth-enabled-frameless-smart-android-tv-inbuilt-decoder-netflixyoutube-appstore-1-year-warrantyfree-tvguardbracket-43989687.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 7: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32'' Inch Frameless Android Smart HD LED TV With Bluetooth - Black",
#   "price": "KSh 10,669",
#   "price_value": "79.98",
#   "old_price": "KSh 21,947",
#   "discount_percentage": "84.54",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(58",
#   "item_id": "HI137EA3DYZHINAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-32-inch-frameless-android-smart-hd-led-tv-with-bluetooth-black-203856840.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 8: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "LES4304W 43\u201d 2K FHD Frameless Android Smart TV With Bluetooth - Black (1YR WRTY)",
#   "price": "KSh 18,699",
#   "price_value": "140.18",
#   "old_price": "KSh 34,999",
#   "discount_percentage": "122.19",
#   "rating": "4.3",
#   "reviews_count": "4.3 out of 5(145",
#   "item_id": "LY007EA4F5BQWNAFAMZ",
#   "item_brand": "Lyons",
#   "product_url": "https://www.jumia.co.ke/lyons-les4304w-43-2k-fhd-frameless-android-smart-tv-with-bluetooth-black-1yr-wrty-284470376.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 9: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43S5400 S Series, 43\" Full HD Smart TV - Black\u00a0(1YR WRTY)",
#   "price": "KSh 26,099",
#   "price_value": "195.65",
#   "old_price": "KSh 39,999",
#   "discount_percentage": "104.20",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(393",
#   "item_id": "TC187EA25W1RONAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43s5400-s-series-43-full-hd-smart-tv-black1yr-wrty-161752803.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 10: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "Hikers 32'' Inch Frameless Android Smart HD LED TV - Black (1YR WRTY)",
#   "price": "KSh 11,899",
#   "price_value": "89.20",
#   "old_price": "KSh 20,168",
#   "discount_percentage": "61.99",
#   "rating": "3.8",
#   "reviews_count": "3.8 out of 5(1148",
#   "item_id": "GE840EA2R97VRNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-hikers-32-inch-frameless-android-smart-hd-led-tv-black-1yr-wrty-130121766.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 11: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32'' Digital Frameless HD LED TV-Black",
#   "price": "KSh 9,999",
#   "price_value": "74.96",
#   "old_price": "KSh 15,950",
#   "discount_percentage": "44.61",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(657",
#   "item_id": "GE840EA2A5EWFNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-32-digital-frameless-hd-led-tv-black-130118973.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 12: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC4388FS 43\"inch Full HD Frameless BLUETOOTH ENABLED Smart/Android TV InbuiltDecoder/(1 YEAR WARRAN",
#   "price": "KSh 21,885",
#   "price_value": "164.06",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "30.85",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(392",
#   "item_id": "VI505EA01T4Z0NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc4388fs-43inch-full-hd-frameless-bluetooth-enabled-smartandroid-tv-inbuiltdecoder1-year-warrantytvguardbracket-48093030.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 13: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43'' Inch Frameless Android Smart FHD LED TV - Black",
#   "price": "KSh 18,499",
#   "price_value": "138.68",
#   "old_price": "KSh 26,322",
#   "discount_percentage": "58.64",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(529",
#   "item_id": "GE840EA2IZAKNNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-43-inch-frameless-android-smart-fhd-led-tv-black-130121825.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 14: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Inches Android &Smart  TV,BLUETOOTH,Netflix,HDMI,Decoder+TV-Guard+Wall Mount",
#   "price": "KSh 13,290",
#   "price_value": "99.63",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "95.28",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(156",
#   "item_id": "VI505EA2YBKINNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/32-inches-android-smart-tvnetflixhdmidecoderwall-mount-brackettv-guard-vitron-mpg1440812.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 15: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" HD Frameless Smart TV, DVB-T2/S2, Android +Free Wall Mount (2YRs WRTY)",
#   "price": "KSh 12,199",
#   "price_value": "91.45",
#   "old_price": "KSh 20,995",
#   "discount_percentage": "65.94",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(233",
#   "item_id": "VI799EA1VZP64NAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-32-hd-frameless-smart-tv-dvb-t2s2-android-free-wall-mount-2yrs-wrty-125899141.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 16: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "3200S,32\" Inch Smart Android TV,NetflixYoutube, Appstore+FREE Extension+BRACKET",
#   "price": "KSh 13,195",
#   "price_value": "98.92",
#   "old_price": "KSh 17,500",
#   "discount_percentage": "32.27",
#   "rating": "4",
#   "reviews_count": "4 out of 5(341",
#   "item_id": "VI505EA0FTFTQNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/3200s32-inch-smart-android-tvnetflixyoutube-appstorefree-extensionbracket-vitron-mpg1662667.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 17: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43L12, 43\" FHD Smart Android TV, Netfix, Youtube, Bluetooth - Black (1YR WRTY)",
#   "price": "KSh 18,799",
#   "price_value": "140.93",
#   "old_price": "KSh 28,000",
#   "discount_percentage": "68.97",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(301",
#   "item_id": "AM617EA1K3NOJNAFAMZ",
#   "item_brand": "Amtec",
#   "product_url": "https://www.jumia.co.ke/amtec-43l12-43-fhd-smart-android-tv-netfix-youtube-bluetooth-black-1yr-wrty-55192249.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 18: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "LES3211W 32\u201d Frameless Android Smart TV - Black (1YR WRTY)",
#   "price": "KSh 10,999",
#   "price_value": "82.45",
#   "old_price": "KSh 17,599",
#   "discount_percentage": "49.48",
#   "rating": "4",
#   "reviews_count": "4 out of 5(25",
#   "item_id": "LY007EA4JY9TSNAFAMZ",
#   "item_brand": "Lyons",
#   "product_url": "https://www.jumia.co.ke/lyons-les3211w-32-frameless-android-smart-tv-black-1yr-wrty-284467357.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 19: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "FRAMELESS 43 Inch SMART TV,DECODER,YOUTUBE, BLUETOOTH-ENABLED +GIFTS",
#   "price": "KSh 21,890",
#   "price_value": "164.10",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "135.76",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(178",
#   "item_id": "VI505EA0UHR23NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-frameless-43-inch-smart-tvdecoderyoutube-bluetooth-enabled-gifts-99661215.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 20: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "50\" 4K Frameless, Netflix Official Smart Content TV +Free Wall Mount(2YRs WRTY)",
#   "price": "KSh 33,999",
#   "price_value": "254.87",
#   "old_price": "KSh 49,995",
#   "discount_percentage": "119.91",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(83",
#   "item_id": "VI799EA2938H8NAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-50-4k-frameless-netflix-official-smart-content-tv-free-wall-mount2yrs-wrty-125899163.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 21: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S,32\"Inch Bluetooth Enabled Frameless Smart Android TV Netflix Youtube Inbuilt Decoder App St",
#   "price": "KSh 12,895",
#   "price_value": "96.67",
#   "old_price": "KSh 16,500",
#   "discount_percentage": "27.02",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(77",
#   "item_id": "VI505EA1R8C39NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s32inch-bluetooth-enabled-frameless-smart-android-tv-netflix-youtube-inbuilt-decoder-app-store-1-year-warranty-152740260.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 22: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43 Inch Frameless Smart Android TV, FULL HD Netflix Youtube With Bluetooth 1G+8G",
#   "price": "KSh 18,499",
#   "price_value": "138.68",
#   "old_price": "KSh 25,999",
#   "discount_percentage": "56.22",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(44",
#   "item_id": "AR850EA4FJ2BANAFAMZ",
#   "item_brand": "Artel",
#   "product_url": "https://www.jumia.co.ke/artel-43-inch-frameless-smart-android-tv-full-hd-netflix-youtube-with-bluetooth-1g8g-260484976.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 23: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch Full HD Frameless Smart Android TV BLUETOOTH ENABLED, NETFLIX YOUTUBE,APP STORE, INBUILT DE",
#   "price": "KSh 21,592",
#   "price_value": "161.86",
#   "old_price": "KSh 25,900",
#   "discount_percentage": "32.29",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(681",
#   "item_id": "VI505EA0SM39ENAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/43-inch-fhd-frameless-smart-android-tv-inbuilt-decoderfree-bracketextension-vitron-mpg1987077.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 24: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S Bluetooth Enabled 32\" Inch Television Smart Android TV With Inbuilt Decoder(1 YEAR WARRANTY",
#   "price": "KSh 13,289",
#   "price_value": "99.62",
#   "old_price": "KSh 16,500",
#   "discount_percentage": "24.07",
#   "rating": "4",
#   "reviews_count": "4 out of 5(451",
#   "item_id": "VI505EA04Y5PQNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s-bluetooth-enabled-32-inch-television-smart-android-tv-with-inbuilt-decoder1-year-warranty-free-tv-guardbracket-47121380.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 25: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Inches-,BLUETOOTH,HD Smart LED Android 11-TV,Appstore-Netflix+Flash-32GB+Wall Bracket",
#   "price": "KSh 13,299",
#   "price_value": "99.69",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "95.21",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(36",
#   "item_id": "VI505EA2T1A49NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-32-inches-bluetoothhd-smart-led-android-11-tvappstore-netflixflash-32gbwall-bracket-158900796.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 26: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": " 43\" inch Full HD,Dolby Audio/Google TV,Bluetooth-enabled,Android OS+Free Extension+TVGuard",
#   "price": "KSh 28,999",
#   "price_value": "217.39",
#   "old_price": "KSh 54,000",
#   "discount_percentage": "187.42",
#   "rating": "4.8",
#   "reviews_count": "4.8 out of 5(12",
#   "item_id": "TC187EA46NFD1NAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43-inch-full-hddolby-audiogoogle-tvbluetooth-enabledandroid-osfree-extensiontvguard-279353035.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 27: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch-FHD Smart Android TV With GooglePlay,BLUETOOTH-ENABLED+Wall Bracket+TVGuard",
#   "price": "KSh 21,895",
#   "price_value": "164.13",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "135.72",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(40",
#   "item_id": "VI505EA1E5HHONAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/43-inch-fhd-smart-android-tv-with-googleplaywall-brackettvguard-vitron-mpg604428.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 28: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S,32\"inch Framelss BLUEOOTH ENABLED Television Smart Android TV,Netflix,Youtube (1 YEAR WARRA",
#   "price": "KSh 12,894",
#   "price_value": "96.66",
#   "old_price": "KSh 16,500",
#   "discount_percentage": "27.03",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(1530",
#   "item_id": "VI505EA1MJRTGNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/htc3200s32-inch-frameless-smart-android-tv-inbuilt-decoder-netflix-appstore-vitron-mpg1987078.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 29: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3218,Frameless 32\" Inch Digital LED Television USB HDMI INBUILT DECODER (1 YEAR WARRANTY)+FREE Wa",
#   "price": "KSh 11,795",
#   "price_value": "88.42",
#   "old_price": "KSh 14,500",
#   "discount_percentage": "20.28",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(627",
#   "item_id": "VI505EA0HC3ALNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/htc3218frameless-32-inch-digital-led-television-usb-hdmi-free-wall-bracket-vitron-mpg1987079.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 30: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "VP8855KV - 55\" 4K Frameless V+ OS Smart TV (2YRS WRTY)",
#   "price": "KSh 39,999",
#   "price_value": "299.85",
#   "old_price": "KSh 54,995",
#   "discount_percentage": "112.42",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(71",
#   "item_id": "VI799EA2KEGZ0NAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-vp8855kv-55-4k-frameless-v-os-smart-tv-2yrs-wrty-125899155.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 31: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "4388FS,43\" Inch FRAMELESS Smart Android TV Netflix INBUILT DECODER, Bluetooth Enabled Television (1 ",
#   "price": "KSh 20,999",
#   "price_value": "157.42",
#   "old_price": "KSh 28,000",
#   "discount_percentage": "52.48",
#   "rating": "4.3",
#   "reviews_count": "4.3 out of 5(490",
#   "item_id": "VI505EA0IZJALNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-4388fs43-inch-frameless-smart-android-tv-netflix-inbuilt-decoder-bluetooth-enabled-television-1-year-warrantyfree-bracket-35019813.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 32: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" M6 Digital LED TV DVBt2 HD AC (1YR WRTY)",
#   "price": "KSh 9,799",
#   "price_value": "73.46",
#   "old_price": "KSh 12,000",
#   "discount_percentage": "16.50",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(27",
#   "item_id": "AM617EA2AT60QNAFAMZ",
#   "item_brand": "Amtec",
#   "product_url": "https://www.jumia.co.ke/amtec-32-m6-digital-led-tv-dvbt2-hd-ac-1yr-wrty-183398093.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 33: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3218F - 32\" HD Frameless LED Digital TV (StarTimes Inbuilt Decoder) 1YR WRTY",
#   "price": "KSh 10,799",
#   "price_value": "80.95",
#   "old_price": "KSh 15,514",
#   "discount_percentage": "35.35",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(220",
#   "item_id": "VI505EA1Q0QMQNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3218f-32-hd-frameless-led-digital-tv-startimes-inbuilt-decoder-1yr-wrty-160707140.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 34: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HD Frameless 32 Inch Digital LED TV WithInbuilt Decoder+BRACKET+GUARD",
#   "price": "KSh 12,289",
#   "price_value": "92.12",
#   "old_price": "KSh 24,000",
#   "discount_percentage": "87.79",
#   "rating": "3.6",
#   "reviews_count": "3.6 out of 5(48",
#   "item_id": "VI505EA213FRENAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/hd-frameless-32-inch-digital-led-tv-withinbuilt-decoderbracketguard-vitron-mpg1522039.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 35: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC4388FS 43\" Inch Full HD Frameless Smart Android TV, 8GBROM, BLUETOOTH ENABLED, NETFLIX, YOUTUBE I",
#   "price": "KSh 21,887",
#   "price_value": "164.07",
#   "old_price": "KSh 26,500",
#   "discount_percentage": "34.58",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(375",
#   "item_id": "VI505EA0QJMIZNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc4388fs-43-inch-full-hd-frameless-smart-android-tv-8gbrom-bluetooth-enabled-netflix-youtube-inbuilt-decoder-1-yr-warranty-free-tvguardextension-57658544.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 36: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "50'' Inch Frameless Android Smart 4K LED TV - Black (1YR WRTY)",
#   "price": "KSh 31,390",
#   "price_value": "235.31",
#   "old_price": "KSh 49,999",
#   "discount_percentage": "139.50",
#   "rating": "4",
#   "reviews_count": "4 out of 5(87",
#   "item_id": "HI137EA31IF5XNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-50-inch-frameless-android-smart-4k-led-tv-black-1yr-wrty-150673938.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 37: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" P635 4K HDR Google TV - Black",
#   "price": "KSh 39,999",
#   "price_value": "299.85",
#   "old_price": "N/A",
#   "discount_percentage": "N/A",
#   "rating": "4.6",
#   "reviews_count": "4.6 out of 5(164",
#   "item_id": "TC187EA2I1514NAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43-p635-4k-hdr-google-tv-black-161681215.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 38: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "55'' Frameless Android Smart 4K LED TV - Black",
#   "price": "KSh 34,411",
#   "price_value": "257.96",
#   "old_price": "KSh 60,999",
#   "discount_percentage": "199.31",
#   "rating": "3.6",
#   "reviews_count": "3.6 out of 5(32",
#   "item_id": "HI137EA2XA9JHNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-55-frameless-android-smart-4k-led-tv-black-150683867.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 39: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "4068FS, 40\" Smart Android TV, Netflix, Youtube - Black (1YR WRTY)",
#   "price": "KSh 17,199",
#   "price_value": "128.93",
#   "old_price": "KSh 20,449",
#   "discount_percentage": "24.36",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(306",
#   "item_id": "VI505EA07D3P6NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-4068fs-40-smart-android-tv-netflix-youtube-black-1yr-wrty-43686321.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 40: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" inch FHD Frameless Smart/Android TV,BLUETOOTH, InbuiltDecoder/+Extension+Bracket",
#   "price": "KSh 20,999",
#   "price_value": "157.42",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "142.44",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(27",
#   "item_id": "GL585EA1PMEQVNAFAMZ",
#   "item_brand": "Gld",
#   "product_url": "https://www.jumia.co.ke/gld-43-inch-fhd-frameless-smartandroid-tvbluetooth-inbuiltdecoderextensionbracket-191120530.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 41: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43UK64 , 43INCH Smart Android TV, Netflix, Youtube - Black",
#   "price": "KSh 18,116",
#   "price_value": "135.81",
#   "old_price": "KSh 26,880",
#   "discount_percentage": "65.70",
#   "rating": "4",
#   "reviews_count": "4 out of 5(1",
#   "item_id": "GL111EA4E5LRNNAFAMZ",
#   "item_brand": "Globalstar",
#   "product_url": "https://www.jumia.co.ke/globalstar-43uk64-43inch-smart-android-tv-netflix-youtube-black-291804656.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 42: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" inch-Frameless /Smart & Android TV,1GB RAM ,NETFLIX,APPSTORE+BRACKET+EXTENSION",
#   "price": "KSh 12,999",
#   "price_value": "97.45",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "97.46",
#   "rating": "3.6",
#   "reviews_count": "3.6 out of 5(16",
#   "item_id": "VI505EA40MSU8NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-32-inch-frameless-smart-android-tv1gb-ram-netflixappstorebracketextension-221582924.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 43: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Frameless  Smart Android TV Netflix Youtube  With Bluetooth 1G+8G",
#   "price": "KSh 11,669",
#   "price_value": "87.48",
#   "old_price": "KSh 14,999",
#   "discount_percentage": "24.96",
#   "rating": "4.5",
#   "reviews_count": "4.5 out of 5(13",
#   "item_id": "AR850EA47SO89NAFAMZ",
#   "item_brand": "Artel",
#   "product_url": "https://www.jumia.co.ke/artel-32-frameless-smart-android-tv-netflix-youtube-with-bluetooth-1g8g-258795945.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 44: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch,  4K Ultra HD Smart LED Google/Android TV,Bluetooth-Enabled+2 YEARS WARRANTY",
#   "price": "KSh 32,999",
#   "price_value": "247.37",
#   "old_price": "KSh 60,000",
#   "discount_percentage": "202.41",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(33",
#   "item_id": "TC187EA4FZGLZNAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43-inch-4k-ultra-hd-smart-led-googleandroid-tvbluetooth-enabled2-years-warranty-213431786.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 45: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch  4K ULTRA HD,Smart GOOGLE TV,NETFLIX,APPSTORE+GIFTS",
#   "price": "KSh 32,999",
#   "price_value": "247.37",
#   "old_price": "KSh 60,000",
#   "discount_percentage": "202.41",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(22",
#   "item_id": "TC187EA285UW4NAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43-inch-4k-ultra-hdsmart-google-tvnetflixappstoregifts-169524643.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 46: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S 32\" Inch Smart Android 11.0 TV Bluetooth Enabled Television Netflix,Youtube App Store Inbui",
#   "price": "KSh 13,285",
#   "price_value": "99.59",
#   "old_price": "KSh 16,000",
#   "discount_percentage": "20.35",
#   "rating": "4",
#   "reviews_count": "4 out of 5(41",
#   "item_id": "VI505EA4T9P72NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s-32-inch-smart-android-11.0-tv-bluetooth-enabled-television-netflixyoutube-app-store-inbuilt-wifi-inbuilt-sound-bar-inbuilt-decoder-1-yr-warantyfree-tv-guard-wall-bracket-262162019.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 47: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC2446D - 24\u201d HD Digital LED TV - Black (1YR WRTY)",
#   "price": "KSh 8,299",
#   "price_value": "62.21",
#   "old_price": "KSh 11,999",
#   "discount_percentage": "27.74",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(90",
#   "item_id": "VI505EA0H21VRNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc2446d-24-hd-digital-led-tv-black-1yr-wrty-32294682.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 48: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Inch Frameless FHD SMART TV,Netflix,WIFI,INBUILT DECODER+TV GUARD+BRACKET",
#   "price": "KSh 20,999",
#   "price_value": "157.42",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "142.44",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(17",
#   "item_id": "HI200EA1XZ3PGNAFAMZ",
#   "item_brand": "Hisense",
#   "product_url": "https://www.jumia.co.ke/hisense-32-inch-frameless-fhd-smart-tvnetflixwifiinbuilt-decodertv-guardbracket-186213571.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
# ...
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1939: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "Digital LED TV, 32\" Inch, Frameless, Inbuilt Decoder,HDMI/USB+FREE EXTENSION+TV GUARD",
#   "price": "KSh 12,899",
#   "price_value": "96.70",
#   "old_price": "KSh 24,000",
#   "discount_percentage": "83.22",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "VI799EA3P0EHYNAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-digital-led-tv-32-inch-frameless-inbuilt-decoderhdmiusbfree-extensiontv-guard-281770432.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1940: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "75 Inch Smart TV Android TV LED,HD 4K WIFI ,Youtube , Netflix ,Inbuilt Decoder",
#   "price": "KSh 110,999",
#   "price_value": "832.09",
#   "old_price": "KSh 220,000",
#   "discount_percentage": "817.12",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "PR367EA2FQKTDNAFAMZ",
#   "item_brand": "Premier",
#   "product_url": "https://www.jumia.co.ke/65-inches-smart-android-tv-ledhd-4k-wifi-youtube-netflix-inbuilt-decoder-premier-mpg1521682.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1941: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "P635 ,55\" Inches- FRAMELESS,ULTRA HD 4K,BLUETOOTH-ENABLED+GIFTS+2YRS WARRANTY",
#   "price": "KSh 52,999",
#   "price_value": "397.30",
#   "old_price": "KSh 100,000",
#   "discount_percentage": "352.34",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "TC187EA4D6OGVNAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-p635-55-inches-framelessultra-hd-4kbluetooth-enabledgifts2yrs-warranty-295311046.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1942: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "55CU8000, 55 Inch Crystal UHD 4K Smart TV (2023) - Black",
#   "price": "KSh 76,500",
#   "price_value": "573.48",
#   "old_price": "KSh 98,000",
#   "discount_percentage": "161.17",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SA948EA4J2B8WNAFAMZ",
#   "item_brand": "Samsung",
#   "product_url": "https://www.jumia.co.ke/samsung-55cu8000-55-inch-crystal-uhd-4k-smart-tv-2023-black-269258837.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1943: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Smart  Android TV -  Black",
#   "price": "KSh 18,799",
#   "price_value": "140.93",
#   "old_price": "KSh 21,299",
#   "discount_percentage": "18.74",
#   "rating": "4",
#   "reviews_count": "4 out of 5(1",
#   "item_id": "SK493EA141E0ZNAFAMZ",
#   "item_brand": "Skyworth",
#   "product_url": "https://www.jumia.co.ke/32-smart-android-tv-black-skyworth-mpg353037.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1944: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32 Inch Smart Android Google TV 32S5400 Frameless HDR10 Bluetooth YouTube & Netflix",
#   "price": "KSh 29,999",
#   "price_value": "224.89",
#   "old_price": "KSh 35,000",
#   "discount_percentage": "37.49",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "TC187EA4LH3TPNAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-32-inch-smart-android-google-tv-32s5400-frameless-hdr10-bluetooth-youtube-netflix-294743977.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1945: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "Frameless 32\" Inch Digital LED Television USB HDMI +FREE Wall Bracket",
#   "price": "KSh 13,200",
#   "price_value": "98.95",
#   "old_price": "KSh 15,000",
#   "discount_percentage": "13.49",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SY450EA3GC1MJNAFAMZ",
#   "item_brand": "Synix",
#   "product_url": "https://www.jumia.co.ke/synix-frameless-32-inch-digital-led-television-usb-hdmi-free-wall-bracket-236343880.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1946: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\"Inch Bluetooth Enabled Frameless Smart Android TV Netflix Youtube ",
#   "price": "KSh 13,494",
#   "price_value": "101.16",
#   "old_price": "KSh 15,900",
#   "discount_percentage": "18.04",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "VI505EA4RJ7DHNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-32inch-bluetooth-enabled-frameless-smart-android-tv-netflix-youtube-275301188.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1947: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch Smart & Digital TV Android Bluetooth-Enabled TV,NETFLIX+BRACKET+32GB FLASH DISK",
#   "price": "KSh 24,499",
#   "price_value": "183.65",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "116.20",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "VI799EA3XOTJXNAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-43-inch-smart-digital-tv-android-bluetooth-enabled-tvnetflixbracket32gb-flash-disk-210938973.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1948: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" FRAMELESS 4K ULTRA HD GOOGLE TV, VOICE CONTROL, BLUETOOTH, NETFLIX, YOUTUBE 43X85L + WALL BRACKE",
#   "price": "KSh 89,389",
#   "price_value": "670.10",
#   "old_price": "KSh 120,000",
#   "discount_percentage": "229.47",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SO521EA4WX1BDNAFAMZ",
#   "item_brand": "Sony",
#   "product_url": "https://www.jumia.co.ke/sony-43-frameless-4k-ultra-hd-google-tv-voice-control-bluetooth-netflix-youtube-43x85l-wall-bracket-tv-guard-296735179.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1949: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "65\" NANO77 NANOCELL 4K Active HDR WebOS22 65NANO776QA",
#   "price": "KSh 154,995",
#   "price_value": "1161.91",
#   "old_price": "KSh 195,995",
#   "discount_percentage": "307.35",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "LG835EA1V7VZKNAFAMZ",
#   "item_brand": "LG",
#   "product_url": "https://www.jumia.co.ke/lg-65-nano77-nanocell-4k-active-hdr-webos22-65nano776qa-102320921.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1950: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "55\" Inch,55A6K, SMART TV,NETFLIX,UHD 4K,BLUETOOTH 5.0-2024+TV GUARD",
#   "price": "KSh 57,500",
#   "price_value": "431.04",
#   "old_price": "KSh 75,000",
#   "discount_percentage": "131.19",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "HI200EA49GB73NAFAMZ",
#   "item_brand": "Hisense",
#   "product_url": "https://www.jumia.co.ke/hisense-55-inch55a6k-smart-tvnetflixuhd-4kbluetooth-5.0-2024tv-guard-255224775.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1951: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "65U7N Mini-LED ULED 4K VIDAA Smart TV",
#   "price": "KSh 103,999",
#   "price_value": "779.62",
#   "old_price": "KSh 110,000",
#   "discount_percentage": "44.99",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "HI200EA4HYSPBNAFAMZ",
#   "item_brand": "Hisense",
#   "product_url": "https://www.jumia.co.ke/hisense-65u7n-mini-led-uled-4k-vidaa-smart-tv-297614027.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1952: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32 \" Digital LED TV HDMI\\USB Port /FREE TO AIR CHANNELS.",
#   "price": "KSh 11,947",
#   "price_value": "89.56",
#   "old_price": "KSh 16,000",
#   "discount_percentage": "30.38",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "IT910EA0FIPRDNAFAMZ",
#   "item_brand": "Amtec",
#   "product_url": "https://www.jumia.co.ke/amtec-32-digital-led-tv-hdmiusb-port-free-to-air-channels.-33476062.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1953: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "23 INCHES DIGITAL LED TV INBUILT DECORDER HD TV",
#   "price": "KSh 6,999",
#   "price_value": "52.47",
#   "old_price": "KSh 10,000",
#   "discount_percentage": "22.50",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "CT303EA12DXPNNAFAMZ",
#   "item_brand": "CTC",
#   "product_url": "https://www.jumia.co.ke/ctc-23-inches-digital-led-tv-inbuilt-decorder-hd-tv-72657446.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1954: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Inch-HD Ready-Frameless Smart Android 11 TV Inbuilt Decoder Neflix +FREE WALL BRACKET",
#   "price": "KSh 13,390",
#   "price_value": "100.38",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "94.53",
#   "rating": "4",
#   "reviews_count": "4 out of 5(1",
#   "item_id": "GL585EA21J3LXNAFAMZ",
#   "item_brand": "Gld",
#   "product_url": "https://www.jumia.co.ke/gld-32-inch-hd-ready-frameless-smart-android-11-tv-inbuilt-decoder-neflix-free-wall-bracket-190130532.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1955: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43P635 2022 LATEST 4K UHD GOOGLE TV,VOICE CONTROL,WI-FI,NETFLIX,4K HDR",
#   "price": "KSh 34,199",
#   "price_value": "256.37",
#   "old_price": "KSh 50,000",
#   "discount_percentage": "118.45",
#   "rating": "4.3",
#   "reviews_count": "4.3 out of 5(6",
#   "item_id": "TC187EA0OOCOWNAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43p635-2022-latest-4k-uhd-google-tvvoice-controlwi-finetflix4k-hdr-67964414.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1956: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "55\" Inch,FRAMELESS/BLUETOOTH, ULTRA HD 4K HDR ,NETFLIX/YOUTUBE+WALL BRACKET+32GB FLASH DISK",
#   "price": "KSh 53,999",
#   "price_value": "404.80",
#   "old_price": "KSh 100,000",
#   "discount_percentage": "344.84",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "HI200EA3PXPJGNAFAMZ",
#   "item_brand": "Hisense",
#   "product_url": "https://www.jumia.co.ke/hisense-55-inchframelessbluetooth-ultra-hd-4k-hdr-netflixyoutubewall-bracket32gb-flash-disk-267616942.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1957: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43 Inch FHD Smart Tv 43T5300",
#   "price": "KSh 42,500",
#   "price_value": "318.60",
#   "old_price": "N/A",
#   "discount_percentage": "N/A",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SA948EA3PJF8INAFAMZ",
#   "item_brand": "Samsung",
#   "product_url": "https://www.jumia.co.ke/samsung-43-inch-fhd-smart-tv-43t5300-283159242.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1958: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "FRAMELESS //BLUETOOTH-ENABLED-4K ULTRA HD GOOGLE/ANDROID TV",
#   "price": "KSh 85,999",
#   "price_value": "644.68",
#   "old_price": "N/A",
#   "discount_percentage": "N/A",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "TC187EA3NJT41NAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-frameless-bluetooth-enabled-4k-ultra-hd-googleandroid-tv-298835902.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1959: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch -4388FS-Smart /Digital Android TV,FRAMELESS/BLUETOOTH,Netflix+TILT BRACKET+POWER GUARD",
#   "price": "KSh 21,999",
#   "price_value": "164.91",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "134.94",
#   "rating": "5",
#   "reviews_count": "5 out of 5(1",
#   "item_id": "VI505EA485VBWNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-43-inch-4388fs-smart-digital-android-tvframelessbluetoothnetflixtilt-bracketpower-guard-261557555.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1960: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\u201d Inch Digital TV With Inbuilt Decoder Black 32 inch .",
#   "price": "KSh 12,997",
#   "price_value": "97.43",
#   "old_price": "KSh 14,000",
#   "discount_percentage": "7.52",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SY450EA4QJ7WINAFAMZ",
#   "item_brand": "Synix",
#   "product_url": "https://www.jumia.co.ke/synix-32-inch-digital-tv-with-inbuilt-decoder-black-32-inch-.-262413468.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Database error: current transaction is aborted, commands ignored until end of transaction block
#
# Database connection closed.
# Error in scrape_and_save: current transaction is aborted, commands ignored until end of transaction block
#
# Main execution error: current transaction is aborted, commands ignored until end of transaction block

# %%
import requests
from bs4 import BeautifulSoup
import psycopg2
import time
import random
import logging
import json  # Add this import

def scrape_and_save(url, headers, db_params, table_name):
    print(f"\nStarting scrape for {table_name}")
    
    try:
        # Get last page number
        last_page = get_last_page_number(url, headers)
        print(f"Found {last_page} pages to scrape")
        
        # Initialize products list
        all_products = []
        
        # Scrape each page
        for page_num in range(1, last_page + 1):
            page_url = f"{url}?page={page_num}#catalog-listing"
            print(f"Scraping page {page_num}/{last_page}")
            
            # Scrape products from current page
            page_products = scrape_product_details(page_url, headers)
            print(f"Found {len(page_products)} products on page {page_num}")
            all_products.extend(page_products)
            
            # Random delay
            time.sleep(random.uniform(1, 3))
        
        print(f"Total products scraped: {len(all_products)}")
        
        # Save products to database
        if all_products:
            print(f"\nFirst product data (sample):")
            first_product = all_products[0]
            for key, value in first_product.items():
                print(f"{key}: {value}")
                
            print(f"\nAttempting to save {len(all_products)} products to {table_name}")
            save_to_postgresql(all_products, db_params, table_name)
        else:
            print("No products found to save!")
            
    except Exception as e:
        print(f"Error in scrape_and_save: {str(e)}")
        raise

# %%
def save_to_postgresql(products, db_params, table_name):
    conn = None
    cursor = None
    try:
        # Connect to PostgreSQL database
        print("Connecting to database...")
        conn = psycopg2.connect(**db_params)
        cursor = conn.cursor()
        
        # Create table if it doesn't exist
        create_table_query = f"""
            CREATE TABLE IF NOT EXISTS {table_name} (
                id SERIAL PRIMARY KEY,
                product_name TEXT,
                price TEXT,
                old_price TEXT,
                discount TEXT,
                rating TEXT,
                reviews_count TEXT,
                category TEXT,
                subcategory TEXT,
                is_official_store BOOLEAN,
                has_express_shipping BOOLEAN,
                item_id TEXT UNIQUE,
                item_brand TEXT,
                product_url TEXT,
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """
        cursor.execute(create_table_query)
        conn.commit()
        print(f"Table {table_name} created or verified")
        
        print(f"Connected successfully. Inserting {len(products)} products...")
        
        # Simple insert query
        insert_query = f"""
            INSERT INTO {table_name} 
            (product_name, price, old_price, discount, rating, reviews_count, 
             category, subcategory, is_official_store, has_express_shipping,
             item_id, item_brand, product_url)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            ON CONFLICT (item_id) DO NOTHING
        """
        
        # Insert each product and commit after each successful insert
        for i, product in enumerate(products, 1):
            try:
                row = (
                    product["product_name"],
                    product["price"],
                    product["old_price"],
                    product["discount_percentage"],
                    product["rating"],
                    product["reviews_count"],
                    product.get("category", "N/A"),  # New fields with default values
                    product.get("subcategory", "N/A"),
                    product.get("is_official_store", False),
                    product.get("has_express_shipping", False),
                    product["item_id"],
                    product["item_brand"],
                    product["product_url"]
                )
                
                cursor.execute(insert_query, row)
                conn.commit()  # Commit after each insert
                
                if i % 100 == 0:
                    print(f"Inserted {i} products...")
                
            except Exception as e:
                print(f"Error inserting product {i}: {str(e)}")
                print(f"Problem product data: {json.dumps(product, indent=2)}")
                continue
        
        # Verify final count
        cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
        final_count = cursor.fetchone()[0]
        print(f"\nFinal count in {table_name}: {final_count}")
        
        # Show sample of inserted data
        print("\nVerifying inserted data...")
        cursor.execute(f"SELECT * FROM {table_name} LIMIT 1")
        sample = cursor.fetchone()
        if sample:
            print("Sample record:", sample)
        else:
            print("No records found in database!")
        
    except Exception as e:
        print(f"Database error: {str(e)}")
        if conn:
            conn.rollback()
        raise
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()
        print("Database connection closed.")

# %%
# Main execution
if __name__ == "__main__":
    try:
        # Test database connection first
        print("Testing database connection...")
        conn = psycopg2.connect(**db_params)
        conn.close()
        print("Database connection successful!")
        
        # URLs
        url1 = "https://www.jumia.co.ke/televisions/"
        url2 = "https://www.jumia.co.ke/home-cooking-appliances-cookers/"
        
        # Scrape and save data for both URLs
        scrape_and_save(url1, headers, db_params, "jumia_televisions")
        scrape_and_save(url2, headers, db_params, "jumia_cookers")
        
    except Exception as e:
        print(f"Main execution error: {str(e)}")
# Out:
# Testing database connection...
# Database connection successful!
#
# Starting scrape for jumia_televisions
# Found 50 pages to scrape
# Scraping page 1/50
# 2025-01-10 20:29:06,165 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=1#catalog-listing
# 2025-01-10 20:29:06,175 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 1
# Scraping page 2/50
# 2025-01-10 20:29:08,190 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=2#catalog-listing
# 2025-01-10 20:29:08,198 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 2
# Scraping page 3/50
# 2025-01-10 20:29:11,448 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=3#catalog-listing
# 2025-01-10 20:29:11,459 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 3
# Scraping page 4/50
# 2025-01-10 20:29:14,651 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=4#catalog-listing
# 2025-01-10 20:29:14,660 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 4
# Scraping page 5/50
# 2025-01-10 20:29:18,434 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=5#catalog-listing
# 2025-01-10 20:29:18,444 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 5
# Scraping page 6/50
# 2025-01-10 20:29:21,716 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=6#catalog-listing
# 2025-01-10 20:29:21,723 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 6
# Scraping page 7/50
# 2025-01-10 20:29:25,637 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=7#catalog-listing
# 2025-01-10 20:29:25,648 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 7
# Scraping page 8/50
# 2025-01-10 20:29:27,999 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=8#catalog-listing
# 2025-01-10 20:29:28,004 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 8
# Scraping page 9/50
# 2025-01-10 20:29:29,750 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=9#catalog-listing
# 2025-01-10 20:29:29,754 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 9
# Scraping page 10/50
# 2025-01-10 20:29:32,350 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=10#catalog-listing
# 2025-01-10 20:29:32,359 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 10
# Scraping page 11/50
# 2025-01-10 20:29:34,559 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=11#catalog-listing
# 2025-01-10 20:29:34,568 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 11
# Scraping page 12/50
# 2025-01-10 20:29:36,542 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=12#catalog-listing
# 2025-01-10 20:29:36,549 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 12
# Scraping page 13/50
# 2025-01-10 20:29:39,257 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=13#catalog-listing
# 2025-01-10 20:29:39,264 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 13
# Scraping page 14/50
# 2025-01-10 20:29:42,074 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=14#catalog-listing
# 2025-01-10 20:29:42,084 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 14
# Scraping page 15/50
# 2025-01-10 20:29:45,559 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=15#catalog-listing
# 2025-01-10 20:29:45,567 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 15
# Scraping page 16/50
# 2025-01-10 20:29:48,060 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=16#catalog-listing
# 2025-01-10 20:29:48,068 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 16
# Scraping page 17/50
# 2025-01-10 20:29:51,355 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=17#catalog-listing
# 2025-01-10 20:29:51,366 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 17
# Scraping page 18/50
# 2025-01-10 20:29:53,034 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=18#catalog-listing
# 2025-01-10 20:29:53,043 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 18
# Scraping page 19/50
# 2025-01-10 20:29:55,094 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=19#catalog-listing
# 2025-01-10 20:29:55,104 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 19
# Scraping page 20/50
# 2025-01-10 20:29:58,545 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=20#catalog-listing
# 2025-01-10 20:29:58,556 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 20
# Scraping page 21/50
# 2025-01-10 20:30:01,105 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=21#catalog-listing
# 2025-01-10 20:30:01,113 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 21
# Scraping page 22/50
# 2025-01-10 20:30:02,824 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=22#catalog-listing
# 2025-01-10 20:30:02,837 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 22
# Scraping page 23/50
# 2025-01-10 20:30:23,068 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=23#catalog-listing
# 2025-01-10 20:30:23,081 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 23
# Scraping page 24/50
# 2025-01-10 20:30:26,431 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=24#catalog-listing
# 2025-01-10 20:30:26,445 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 24
# Scraping page 25/50
# 2025-01-10 20:30:29,024 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=25#catalog-listing
# 2025-01-10 20:30:29,046 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 25
# Scraping page 26/50
# 2025-01-10 20:30:32,604 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=26#catalog-listing
# 2025-01-10 20:30:32,619 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 26
# Scraping page 27/50
# 2025-01-10 20:30:35,844 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=27#catalog-listing
# 2025-01-10 20:30:35,864 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 27
# Scraping page 28/50
# 2025-01-10 20:30:38,799 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=28#catalog-listing
# 2025-01-10 20:30:38,824 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 28
# Scraping page 29/50
# 2025-01-10 20:30:41,115 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=29#catalog-listing
# 2025-01-10 20:30:41,131 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 29
# Scraping page 30/50
# 2025-01-10 20:30:44,299 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=30#catalog-listing
# 2025-01-10 20:30:44,318 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 30
# Scraping page 31/50
# 2025-01-10 20:30:46,753 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=31#catalog-listing
# 2025-01-10 20:30:46,770 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 31
# Scraping page 32/50
# 2025-01-10 20:31:12,771 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=32#catalog-listing
# 2025-01-10 20:31:12,794 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 32
# Scraping page 33/50
# 2025-01-10 20:31:15,694 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=33#catalog-listing
# 2025-01-10 20:31:15,710 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 33
# Scraping page 34/50
# 2025-01-10 20:31:18,644 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=34#catalog-listing
# 2025-01-10 20:31:18,659 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 34
# Scraping page 35/50
# 2025-01-10 20:31:20,820 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=35#catalog-listing
# 2025-01-10 20:31:20,838 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 35
# Scraping page 36/50
# 2025-01-10 20:31:23,534 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=36#catalog-listing
# 2025-01-10 20:31:23,561 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 36
# Scraping page 37/50
# 2025-01-10 20:31:25,905 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=37#catalog-listing
# 2025-01-10 20:31:25,925 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 37
# Scraping page 38/50
# 2025-01-10 20:31:28,920 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=38#catalog-listing
# 2025-01-10 20:31:28,935 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 38
# Scraping page 39/50
# 2025-01-10 20:31:31,549 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=39#catalog-listing
# 2025-01-10 20:31:31,568 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 39
# Scraping page 40/50
# 2025-01-10 20:31:35,204 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=40#catalog-listing
# 2025-01-10 20:31:35,220 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 40
# Scraping page 41/50
# 2025-01-10 20:31:38,893 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=41#catalog-listing
# 2025-01-10 20:31:38,925 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 41
# Scraping page 42/50
# 2025-01-10 20:31:41,849 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=42#catalog-listing
# 2025-01-10 20:31:41,860 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 42
# Scraping page 43/50
# 2025-01-10 20:31:44,835 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=43#catalog-listing
# 2025-01-10 20:31:44,849 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 43
# Scraping page 44/50
# 2025-01-10 20:31:48,217 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=44#catalog-listing
# 2025-01-10 20:31:48,236 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 44
# Scraping page 45/50
# 2025-01-10 20:31:51,287 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=45#catalog-listing
# 2025-01-10 20:31:51,309 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 45
# Scraping page 46/50
# 2025-01-10 20:31:53,955 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=46#catalog-listing
# 2025-01-10 20:31:53,970 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 46
# Scraping page 47/50
# 2025-01-10 20:31:56,891 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=47#catalog-listing
# 2025-01-10 20:31:56,906 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 47
# Scraping page 48/50
# 2025-01-10 20:32:00,436 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=48#catalog-listing
# 2025-01-10 20:32:00,455 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 48
# Scraping page 49/50
# 2025-01-10 20:32:04,135 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=49#catalog-listing
# 2025-01-10 20:32:04,155 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 49
# Scraping page 50/50
# 2025-01-10 20:32:06,240 - INFO - Found 40 products on https://www.jumia.co.ke/televisions/?page=50#catalog-listing
# 2025-01-10 20:32:06,256 - INFO - Successfully extracted 40 valid products
# Found 40 products on page 50
# Total products scraped: 2000
#
# First product data (sample):
# product_name: HTC4388FS - 43" Smart  Android Frameless TV - Black (1YR WRTY)
# price: KSh 19,459
# price_value: 145.87
# old_price: KSh 28,599
# discount_percentage: 68.52
# rating: 3.9
# reviews_count: 3.9 out of 5(2436
# item_id: VI505EA0KTU37NAFAMZ
# item_brand: Vitron
# product_url: https://www.jumia.co.ke/vitron-htc4388fs-43-smart-android-frameless-tv-black-1yr-wrty-93348943.html
# category: Electronics
# subcategory: Television & Video
# is_official_store: True
# has_express_shipping: True
#
# Attempting to save 2000 products to jumia_televisions
# Connecting to database...
# Table jumia_televisions created or verified
# Connected successfully. Inserting 2000 products...
# Error inserting product 1: column "reviews_count" of relation "jumia_televisions" does not exist
# LINE 3: ...product_name, price, old_price, discount, rating, reviews_co...
#                                                              ^
#
# Problem product data: {
#   "product_name": "HTC4388FS - 43\" Smart  Android Frameless TV - Black (1YR WRTY)",
#   "price": "KSh 19,459",
#   "price_value": "145.87",
#   "old_price": "KSh 28,599",
#   "discount_percentage": "68.52",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(2436",
#   "item_id": "VI505EA0KTU37NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc4388fs-43-smart-android-frameless-tv-black-1yr-wrty-93348943.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 2: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)",
#   "price": "KSh 9,799",
#   "price_value": "73.46",
#   "old_price": "KSh 15,995",
#   "discount_percentage": "46.45",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(851",
#   "item_id": "VI799EA1QMSQ4NAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-32-digital-hd-frameless-tv-dvbt2s2-black-2yrs-wrty-125899150.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 3: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32R1S, 32\" Inch Smart Android TV 1GB DDR,8GB ROM,4-CORE LED TV (1YR WRTY)",
#   "price": "KSh 11,099",
#   "price_value": "83.20",
#   "old_price": "KSh 19,000",
#   "discount_percentage": "59.23",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(245",
#   "item_id": "AM617EA0HFVIJNAFAMZ",
#   "item_brand": "Amtec",
#   "product_url": "https://www.jumia.co.ke/amtec-32r1s-32-inch-smart-android-tv-1gb-ddr8gb-rom4-core-led-tv-1yr-wrty-55149292.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 4: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC6588USWO, 65\" 4K Smart Frameless TV, Wi-Fi/Netflix, 1YR WRTY",
#   "price": "KSh 63,999",
#   "price_value": "479.76",
#   "old_price": "KSh 99,999",
#   "discount_percentage": "269.87",
#   "rating": "4.7",
#   "reviews_count": "4.7 out of 5(20",
#   "item_id": "VI505EA0K42QFNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc6588uswo-65-4k-smart-frameless-tv-wi-finetflix-1yr-wrty-78428733.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 5: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S, 32\" Smart Frameless Android LED TV, With Bluetooth, (1YR WRTY)",
#   "price": "KSh 11,413",
#   "price_value": "85.56",
#   "old_price": "KSh 15,000",
#   "discount_percentage": "26.89",
#   "rating": "4",
#   "reviews_count": "4 out of 5(598",
#   "item_id": "VI505EA3X4HB8NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s-32-smart-frameless-android-led-tv-with-bluetooth-1yr-wrty-261943073.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 6: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S,32\"Inch Bluetooth Enabled Frameless Smart Android TV Inbuilt Decoder NetflixYoutube Appstor",
#   "price": "KSh 13,285",
#   "price_value": "99.59",
#   "old_price": "KSh 16,500",
#   "discount_percentage": "24.10",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(1502",
#   "item_id": "VI505EA1AUSHINAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s32inch-bluetooth-enabled-frameless-smart-android-tv-inbuilt-decoder-netflixyoutube-appstore-1-year-warrantyfree-tvguardbracket-43989687.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 7: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32'' Inch Frameless Android Smart HD LED TV With Bluetooth - Black",
#   "price": "KSh 10,669",
#   "price_value": "79.98",
#   "old_price": "KSh 21,947",
#   "discount_percentage": "84.54",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(58",
#   "item_id": "HI137EA3DYZHINAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-32-inch-frameless-android-smart-hd-led-tv-with-bluetooth-black-203856840.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 8: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "LES4304W 43\u201d 2K FHD Frameless Android Smart TV With Bluetooth - Black (1YR WRTY)",
#   "price": "KSh 18,699",
#   "price_value": "140.18",
#   "old_price": "KSh 34,999",
#   "discount_percentage": "122.19",
#   "rating": "4.3",
#   "reviews_count": "4.3 out of 5(145",
#   "item_id": "LY007EA4F5BQWNAFAMZ",
#   "item_brand": "Lyons",
#   "product_url": "https://www.jumia.co.ke/lyons-les4304w-43-2k-fhd-frameless-android-smart-tv-with-bluetooth-black-1yr-wrty-284470376.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 9: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43S5400 S Series, 43\" Full HD Smart TV - Black\u00a0(1YR WRTY)",
#   "price": "KSh 26,099",
#   "price_value": "195.65",
#   "old_price": "KSh 39,999",
#   "discount_percentage": "104.20",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(393",
#   "item_id": "TC187EA25W1RONAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43s5400-s-series-43-full-hd-smart-tv-black1yr-wrty-161752803.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 10: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "Hikers 32'' Inch Frameless Android Smart HD LED TV - Black (1YR WRTY)",
#   "price": "KSh 11,899",
#   "price_value": "89.20",
#   "old_price": "KSh 20,168",
#   "discount_percentage": "61.99",
#   "rating": "3.8",
#   "reviews_count": "3.8 out of 5(1148",
#   "item_id": "GE840EA2R97VRNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-hikers-32-inch-frameless-android-smart-hd-led-tv-black-1yr-wrty-130121766.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 11: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32'' Digital Frameless HD LED TV-Black",
#   "price": "KSh 9,999",
#   "price_value": "74.96",
#   "old_price": "KSh 15,950",
#   "discount_percentage": "44.61",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(657",
#   "item_id": "GE840EA2A5EWFNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-32-digital-frameless-hd-led-tv-black-130118973.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 12: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC4388FS 43\"inch Full HD Frameless BLUETOOTH ENABLED Smart/Android TV InbuiltDecoder/(1 YEAR WARRAN",
#   "price": "KSh 21,885",
#   "price_value": "164.06",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "30.85",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(392",
#   "item_id": "VI505EA01T4Z0NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc4388fs-43inch-full-hd-frameless-bluetooth-enabled-smartandroid-tv-inbuiltdecoder1-year-warrantytvguardbracket-48093030.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 13: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43'' Inch Frameless Android Smart FHD LED TV - Black",
#   "price": "KSh 18,499",
#   "price_value": "138.68",
#   "old_price": "KSh 26,322",
#   "discount_percentage": "58.64",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(529",
#   "item_id": "GE840EA2IZAKNNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-43-inch-frameless-android-smart-fhd-led-tv-black-130121825.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 14: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Inches Android &Smart  TV,BLUETOOTH,Netflix,HDMI,Decoder+TV-Guard+Wall Mount",
#   "price": "KSh 13,290",
#   "price_value": "99.63",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "95.28",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(156",
#   "item_id": "VI505EA2YBKINNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/32-inches-android-smart-tvnetflixhdmidecoderwall-mount-brackettv-guard-vitron-mpg1440812.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 15: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" HD Frameless Smart TV, DVB-T2/S2, Android +Free Wall Mount (2YRs WRTY)",
#   "price": "KSh 12,199",
#   "price_value": "91.45",
#   "old_price": "KSh 20,995",
#   "discount_percentage": "65.94",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(233",
#   "item_id": "VI799EA1VZP64NAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-32-hd-frameless-smart-tv-dvb-t2s2-android-free-wall-mount-2yrs-wrty-125899141.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 16: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "3200S,32\" Inch Smart Android TV,NetflixYoutube, Appstore+FREE Extension+BRACKET",
#   "price": "KSh 13,195",
#   "price_value": "98.92",
#   "old_price": "KSh 17,500",
#   "discount_percentage": "32.27",
#   "rating": "4",
#   "reviews_count": "4 out of 5(341",
#   "item_id": "VI505EA0FTFTQNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/3200s32-inch-smart-android-tvnetflixyoutube-appstorefree-extensionbracket-vitron-mpg1662667.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 17: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43L12, 43\" FHD Smart Android TV, Netfix, Youtube, Bluetooth - Black (1YR WRTY)",
#   "price": "KSh 18,799",
#   "price_value": "140.93",
#   "old_price": "KSh 28,000",
#   "discount_percentage": "68.97",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(301",
#   "item_id": "AM617EA1K3NOJNAFAMZ",
#   "item_brand": "Amtec",
#   "product_url": "https://www.jumia.co.ke/amtec-43l12-43-fhd-smart-android-tv-netfix-youtube-bluetooth-black-1yr-wrty-55192249.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 18: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "LES3211W 32\u201d Frameless Android Smart TV - Black (1YR WRTY)",
#   "price": "KSh 10,999",
#   "price_value": "82.45",
#   "old_price": "KSh 17,599",
#   "discount_percentage": "49.48",
#   "rating": "4",
#   "reviews_count": "4 out of 5(25",
#   "item_id": "LY007EA4JY9TSNAFAMZ",
#   "item_brand": "Lyons",
#   "product_url": "https://www.jumia.co.ke/lyons-les3211w-32-frameless-android-smart-tv-black-1yr-wrty-284467357.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 19: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "FRAMELESS 43 Inch SMART TV,DECODER,YOUTUBE, BLUETOOTH-ENABLED +GIFTS",
#   "price": "KSh 21,890",
#   "price_value": "164.10",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "135.76",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(178",
#   "item_id": "VI505EA0UHR23NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-frameless-43-inch-smart-tvdecoderyoutube-bluetooth-enabled-gifts-99661215.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 20: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "50\" 4K Frameless, Netflix Official Smart Content TV +Free Wall Mount(2YRs WRTY)",
#   "price": "KSh 33,999",
#   "price_value": "254.87",
#   "old_price": "KSh 49,995",
#   "discount_percentage": "119.91",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(83",
#   "item_id": "VI799EA2938H8NAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-50-4k-frameless-netflix-official-smart-content-tv-free-wall-mount2yrs-wrty-125899163.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 21: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S,32\"Inch Bluetooth Enabled Frameless Smart Android TV Netflix Youtube Inbuilt Decoder App St",
#   "price": "KSh 12,895",
#   "price_value": "96.67",
#   "old_price": "KSh 16,500",
#   "discount_percentage": "27.02",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(77",
#   "item_id": "VI505EA1R8C39NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s32inch-bluetooth-enabled-frameless-smart-android-tv-netflix-youtube-inbuilt-decoder-app-store-1-year-warranty-152740260.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 22: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43 Inch Frameless Smart Android TV, FULL HD Netflix Youtube With Bluetooth 1G+8G",
#   "price": "KSh 18,499",
#   "price_value": "138.68",
#   "old_price": "KSh 25,999",
#   "discount_percentage": "56.22",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(44",
#   "item_id": "AR850EA4FJ2BANAFAMZ",
#   "item_brand": "Artel",
#   "product_url": "https://www.jumia.co.ke/artel-43-inch-frameless-smart-android-tv-full-hd-netflix-youtube-with-bluetooth-1g8g-260484976.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 23: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch Full HD Frameless Smart Android TV BLUETOOTH ENABLED, NETFLIX YOUTUBE,APP STORE, INBUILT DE",
#   "price": "KSh 21,592",
#   "price_value": "161.86",
#   "old_price": "KSh 25,900",
#   "discount_percentage": "32.29",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(681",
#   "item_id": "VI505EA0SM39ENAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/43-inch-fhd-frameless-smart-android-tv-inbuilt-decoderfree-bracketextension-vitron-mpg1987077.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 24: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S Bluetooth Enabled 32\" Inch Television Smart Android TV With Inbuilt Decoder(1 YEAR WARRANTY",
#   "price": "KSh 13,289",
#   "price_value": "99.62",
#   "old_price": "KSh 16,500",
#   "discount_percentage": "24.07",
#   "rating": "4",
#   "reviews_count": "4 out of 5(451",
#   "item_id": "VI505EA04Y5PQNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s-bluetooth-enabled-32-inch-television-smart-android-tv-with-inbuilt-decoder1-year-warranty-free-tv-guardbracket-47121380.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 25: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Inches-,BLUETOOTH,HD Smart LED Android 11-TV,Appstore-Netflix+Flash-32GB+Wall Bracket",
#   "price": "KSh 13,299",
#   "price_value": "99.69",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "95.21",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(36",
#   "item_id": "VI505EA2T1A49NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-32-inches-bluetoothhd-smart-led-android-11-tvappstore-netflixflash-32gbwall-bracket-158900796.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 26: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": " 43\" inch Full HD,Dolby Audio/Google TV,Bluetooth-enabled,Android OS+Free Extension+TVGuard",
#   "price": "KSh 28,999",
#   "price_value": "217.39",
#   "old_price": "KSh 54,000",
#   "discount_percentage": "187.42",
#   "rating": "4.8",
#   "reviews_count": "4.8 out of 5(12",
#   "item_id": "TC187EA46NFD1NAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43-inch-full-hddolby-audiogoogle-tvbluetooth-enabledandroid-osfree-extensiontvguard-279353035.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 27: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch-FHD Smart Android TV With GooglePlay,BLUETOOTH-ENABLED+Wall Bracket+TVGuard",
#   "price": "KSh 21,895",
#   "price_value": "164.13",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "135.72",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(40",
#   "item_id": "VI505EA1E5HHONAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/43-inch-fhd-smart-android-tv-with-googleplaywall-brackettvguard-vitron-mpg604428.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 28: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S,32\"inch Framelss BLUEOOTH ENABLED Television Smart Android TV,Netflix,Youtube (1 YEAR WARRA",
#   "price": "KSh 12,894",
#   "price_value": "96.66",
#   "old_price": "KSh 16,500",
#   "discount_percentage": "27.03",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(1530",
#   "item_id": "VI505EA1MJRTGNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/htc3200s32-inch-frameless-smart-android-tv-inbuilt-decoder-netflix-appstore-vitron-mpg1987078.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 29: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3218,Frameless 32\" Inch Digital LED Television USB HDMI INBUILT DECODER (1 YEAR WARRANTY)+FREE Wa",
#   "price": "KSh 11,795",
#   "price_value": "88.42",
#   "old_price": "KSh 14,500",
#   "discount_percentage": "20.28",
#   "rating": "4.2",
#   "reviews_count": "4.2 out of 5(627",
#   "item_id": "VI505EA0HC3ALNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/htc3218frameless-32-inch-digital-led-television-usb-hdmi-free-wall-bracket-vitron-mpg1987079.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 30: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "VP8855KV - 55\" 4K Frameless V+ OS Smart TV (2YRS WRTY)",
#   "price": "KSh 39,999",
#   "price_value": "299.85",
#   "old_price": "KSh 54,995",
#   "discount_percentage": "112.42",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(71",
#   "item_id": "VI799EA2KEGZ0NAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-vp8855kv-55-4k-frameless-v-os-smart-tv-2yrs-wrty-125899155.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 31: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "4388FS,43\" Inch FRAMELESS Smart Android TV Netflix INBUILT DECODER, Bluetooth Enabled Television (1 ",
#   "price": "KSh 20,999",
#   "price_value": "157.42",
#   "old_price": "KSh 28,000",
#   "discount_percentage": "52.48",
#   "rating": "4.3",
#   "reviews_count": "4.3 out of 5(490",
#   "item_id": "VI505EA0IZJALNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-4388fs43-inch-frameless-smart-android-tv-netflix-inbuilt-decoder-bluetooth-enabled-television-1-year-warrantyfree-bracket-35019813.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 32: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" M6 Digital LED TV DVBt2 HD AC (1YR WRTY)",
#   "price": "KSh 9,799",
#   "price_value": "73.46",
#   "old_price": "KSh 12,000",
#   "discount_percentage": "16.50",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(27",
#   "item_id": "AM617EA2AT60QNAFAMZ",
#   "item_brand": "Amtec",
#   "product_url": "https://www.jumia.co.ke/amtec-32-m6-digital-led-tv-dvbt2-hd-ac-1yr-wrty-183398093.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 33: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3218F - 32\" HD Frameless LED Digital TV (StarTimes Inbuilt Decoder) 1YR WRTY",
#   "price": "KSh 10,799",
#   "price_value": "80.95",
#   "old_price": "KSh 15,514",
#   "discount_percentage": "35.35",
#   "rating": "3.9",
#   "reviews_count": "3.9 out of 5(220",
#   "item_id": "VI505EA1Q0QMQNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3218f-32-hd-frameless-led-digital-tv-startimes-inbuilt-decoder-1yr-wrty-160707140.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 34: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HD Frameless 32 Inch Digital LED TV WithInbuilt Decoder+BRACKET+GUARD",
#   "price": "KSh 12,289",
#   "price_value": "92.12",
#   "old_price": "KSh 24,000",
#   "discount_percentage": "87.79",
#   "rating": "3.6",
#   "reviews_count": "3.6 out of 5(48",
#   "item_id": "VI505EA213FRENAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/hd-frameless-32-inch-digital-led-tv-withinbuilt-decoderbracketguard-vitron-mpg1522039.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 35: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC4388FS 43\" Inch Full HD Frameless Smart Android TV, 8GBROM, BLUETOOTH ENABLED, NETFLIX, YOUTUBE I",
#   "price": "KSh 21,887",
#   "price_value": "164.07",
#   "old_price": "KSh 26,500",
#   "discount_percentage": "34.58",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(375",
#   "item_id": "VI505EA0QJMIZNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc4388fs-43-inch-full-hd-frameless-smart-android-tv-8gbrom-bluetooth-enabled-netflix-youtube-inbuilt-decoder-1-yr-warranty-free-tvguardextension-57658544.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 36: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "50'' Inch Frameless Android Smart 4K LED TV - Black (1YR WRTY)",
#   "price": "KSh 31,390",
#   "price_value": "235.31",
#   "old_price": "KSh 49,999",
#   "discount_percentage": "139.50",
#   "rating": "4",
#   "reviews_count": "4 out of 5(87",
#   "item_id": "HI137EA31IF5XNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-50-inch-frameless-android-smart-4k-led-tv-black-1yr-wrty-150673938.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 37: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" P635 4K HDR Google TV - Black",
#   "price": "KSh 39,999",
#   "price_value": "299.85",
#   "old_price": "N/A",
#   "discount_percentage": "N/A",
#   "rating": "4.6",
#   "reviews_count": "4.6 out of 5(164",
#   "item_id": "TC187EA2I1514NAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43-p635-4k-hdr-google-tv-black-161681215.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 38: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "55'' Frameless Android Smart 4K LED TV - Black",
#   "price": "KSh 34,411",
#   "price_value": "257.96",
#   "old_price": "KSh 60,999",
#   "discount_percentage": "199.31",
#   "rating": "3.6",
#   "reviews_count": "3.6 out of 5(32",
#   "item_id": "HI137EA2XA9JHNAFAMZ",
#   "item_brand": "Hikers",
#   "product_url": "https://www.jumia.co.ke/hikers-55-frameless-android-smart-4k-led-tv-black-150683867.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 39: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "4068FS, 40\" Smart Android TV, Netflix, Youtube - Black (1YR WRTY)",
#   "price": "KSh 17,199",
#   "price_value": "128.93",
#   "old_price": "KSh 20,449",
#   "discount_percentage": "24.36",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(306",
#   "item_id": "VI505EA07D3P6NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-4068fs-40-smart-android-tv-netflix-youtube-black-1yr-wrty-43686321.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 40: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" inch FHD Frameless Smart/Android TV,BLUETOOTH, InbuiltDecoder/+Extension+Bracket",
#   "price": "KSh 20,999",
#   "price_value": "157.42",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "142.44",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(27",
#   "item_id": "GL585EA1PMEQVNAFAMZ",
#   "item_brand": "Gld",
#   "product_url": "https://www.jumia.co.ke/gld-43-inch-fhd-frameless-smartandroid-tvbluetooth-inbuiltdecoderextensionbracket-191120530.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 41: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43UK64 , 43INCH Smart Android TV, Netflix, Youtube - Black",
#   "price": "KSh 18,116",
#   "price_value": "135.81",
#   "old_price": "KSh 26,880",
#   "discount_percentage": "65.70",
#   "rating": "4",
#   "reviews_count": "4 out of 5(1",
#   "item_id": "GL111EA4E5LRNNAFAMZ",
#   "item_brand": "Globalstar",
#   "product_url": "https://www.jumia.co.ke/globalstar-43uk64-43inch-smart-android-tv-netflix-youtube-black-291804656.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 42: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" inch-Frameless /Smart & Android TV,1GB RAM ,NETFLIX,APPSTORE+BRACKET+EXTENSION",
#   "price": "KSh 12,999",
#   "price_value": "97.45",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "97.46",
#   "rating": "3.6",
#   "reviews_count": "3.6 out of 5(16",
#   "item_id": "VI505EA40MSU8NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-32-inch-frameless-smart-android-tv1gb-ram-netflixappstorebracketextension-221582924.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 43: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Frameless  Smart Android TV Netflix Youtube  With Bluetooth 1G+8G",
#   "price": "KSh 11,669",
#   "price_value": "87.48",
#   "old_price": "KSh 14,999",
#   "discount_percentage": "24.96",
#   "rating": "4.5",
#   "reviews_count": "4.5 out of 5(13",
#   "item_id": "AR850EA47SO89NAFAMZ",
#   "item_brand": "Artel",
#   "product_url": "https://www.jumia.co.ke/artel-32-frameless-smart-android-tv-netflix-youtube-with-bluetooth-1g8g-258795945.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 44: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch,  4K Ultra HD Smart LED Google/Android TV,Bluetooth-Enabled+2 YEARS WARRANTY",
#   "price": "KSh 32,999",
#   "price_value": "247.37",
#   "old_price": "KSh 60,000",
#   "discount_percentage": "202.41",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(33",
#   "item_id": "TC187EA4FZGLZNAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43-inch-4k-ultra-hd-smart-led-googleandroid-tvbluetooth-enabled2-years-warranty-213431786.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 45: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch  4K ULTRA HD,Smart GOOGLE TV,NETFLIX,APPSTORE+GIFTS",
#   "price": "KSh 32,999",
#   "price_value": "247.37",
#   "old_price": "KSh 60,000",
#   "discount_percentage": "202.41",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(22",
#   "item_id": "TC187EA285UW4NAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43-inch-4k-ultra-hdsmart-google-tvnetflixappstoregifts-169524643.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 46: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC3200S 32\" Inch Smart Android 11.0 TV Bluetooth Enabled Television Netflix,Youtube App Store Inbui",
#   "price": "KSh 13,285",
#   "price_value": "99.59",
#   "old_price": "KSh 16,000",
#   "discount_percentage": "20.35",
#   "rating": "4",
#   "reviews_count": "4 out of 5(41",
#   "item_id": "VI505EA4T9P72NAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc3200s-32-inch-smart-android-11.0-tv-bluetooth-enabled-television-netflixyoutube-app-store-inbuilt-wifi-inbuilt-sound-bar-inbuilt-decoder-1-yr-warantyfree-tv-guard-wall-bracket-262162019.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": true
# }
# Error inserting product 47: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "HTC2446D - 24\u201d HD Digital LED TV - Black (1YR WRTY)",
#   "price": "KSh 8,299",
#   "price_value": "62.21",
#   "old_price": "KSh 11,999",
#   "discount_percentage": "27.74",
#   "rating": "4.1",
#   "reviews_count": "4.1 out of 5(90",
#   "item_id": "VI505EA0H21VRNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-htc2446d-24-hd-digital-led-tv-black-1yr-wrty-32294682.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": true,
#   "has_express_shipping": true
# }
# Error inserting product 48: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Inch Frameless FHD SMART TV,Netflix,WIFI,INBUILT DECODER+TV GUARD+BRACKET",
#   "price": "KSh 20,999",
#   "price_value": "157.42",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "142.44",
#   "rating": "4.4",
#   "reviews_count": "4.4 out of 5(17",
#   "item_id": "HI200EA1XZ3PGNAFAMZ",
#   "item_brand": "Hisense",
#   "product_url": "https://www.jumia.co.ke/hisense-32-inch-frameless-fhd-smart-tvnetflixwifiinbuilt-decodertv-guardbracket-186213571.html",
#   "category": "Electronics",
# ...
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1979: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "Digital LED TV, 32\" Inch, Frameless, Inbuilt Decoder,HDMI/USB+FREE EXTENSION+TV GUARD",
#   "price": "KSh 12,899",
#   "price_value": "96.70",
#   "old_price": "KSh 24,000",
#   "discount_percentage": "83.22",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "VI799EA3P0EHYNAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-digital-led-tv-32-inch-frameless-inbuilt-decoderhdmiusbfree-extensiontv-guard-281770432.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1980: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "75 Inch Smart TV Android TV LED,HD 4K WIFI ,Youtube , Netflix ,Inbuilt Decoder",
#   "price": "KSh 110,999",
#   "price_value": "832.09",
#   "old_price": "KSh 220,000",
#   "discount_percentage": "817.12",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "PR367EA2FQKTDNAFAMZ",
#   "item_brand": "Premier",
#   "product_url": "https://www.jumia.co.ke/65-inches-smart-android-tv-ledhd-4k-wifi-youtube-netflix-inbuilt-decoder-premier-mpg1521682.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1981: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "P635 ,55\" Inches- FRAMELESS,ULTRA HD 4K,BLUETOOTH-ENABLED+GIFTS+2YRS WARRANTY",
#   "price": "KSh 52,999",
#   "price_value": "397.30",
#   "old_price": "KSh 100,000",
#   "discount_percentage": "352.34",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "TC187EA4D6OGVNAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-p635-55-inches-framelessultra-hd-4kbluetooth-enabledgifts2yrs-warranty-295311046.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1982: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "55CU8000, 55 Inch Crystal UHD 4K Smart TV (2023) - Black",
#   "price": "KSh 76,500",
#   "price_value": "573.48",
#   "old_price": "KSh 98,000",
#   "discount_percentage": "161.17",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SA948EA4J2B8WNAFAMZ",
#   "item_brand": "Samsung",
#   "product_url": "https://www.jumia.co.ke/samsung-55cu8000-55-inch-crystal-uhd-4k-smart-tv-2023-black-269258837.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1983: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Smart  Android TV -  Black",
#   "price": "KSh 18,799",
#   "price_value": "140.93",
#   "old_price": "KSh 21,299",
#   "discount_percentage": "18.74",
#   "rating": "4",
#   "reviews_count": "4 out of 5(1",
#   "item_id": "SK493EA141E0ZNAFAMZ",
#   "item_brand": "Skyworth",
#   "product_url": "https://www.jumia.co.ke/32-smart-android-tv-black-skyworth-mpg353037.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1984: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32 Inch Smart Android Google TV 32S5400 Frameless HDR10 Bluetooth YouTube & Netflix",
#   "price": "KSh 29,999",
#   "price_value": "224.89",
#   "old_price": "KSh 35,000",
#   "discount_percentage": "37.49",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "TC187EA4LH3TPNAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-32-inch-smart-android-google-tv-32s5400-frameless-hdr10-bluetooth-youtube-netflix-294743977.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1985: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "Frameless 32\" Inch Digital LED Television USB HDMI +FREE Wall Bracket",
#   "price": "KSh 13,200",
#   "price_value": "98.95",
#   "old_price": "KSh 15,000",
#   "discount_percentage": "13.49",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SY450EA3GC1MJNAFAMZ",
#   "item_brand": "Synix",
#   "product_url": "https://www.jumia.co.ke/synix-frameless-32-inch-digital-led-television-usb-hdmi-free-wall-bracket-236343880.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1986: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\"Inch Bluetooth Enabled Frameless Smart Android TV Netflix Youtube ",
#   "price": "KSh 13,494",
#   "price_value": "101.16",
#   "old_price": "KSh 15,900",
#   "discount_percentage": "18.04",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "VI505EA4RJ7DHNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-32inch-bluetooth-enabled-frameless-smart-android-tv-netflix-youtube-275301188.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1987: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch Smart & Digital TV Android Bluetooth-Enabled TV,NETFLIX+BRACKET+32GB FLASH DISK",
#   "price": "KSh 24,499",
#   "price_value": "183.65",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "116.20",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "VI799EA3XOTJXNAFAMZ",
#   "item_brand": "Vision Plus",
#   "product_url": "https://www.jumia.co.ke/vision-plus-43-inch-smart-digital-tv-android-bluetooth-enabled-tvnetflixbracket32gb-flash-disk-210938973.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1988: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" FRAMELESS 4K ULTRA HD GOOGLE TV, VOICE CONTROL, BLUETOOTH, NETFLIX, YOUTUBE 43X85L + WALL BRACKE",
#   "price": "KSh 89,389",
#   "price_value": "670.10",
#   "old_price": "KSh 120,000",
#   "discount_percentage": "229.47",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SO521EA4WX1BDNAFAMZ",
#   "item_brand": "Sony",
#   "product_url": "https://www.jumia.co.ke/sony-43-frameless-4k-ultra-hd-google-tv-voice-control-bluetooth-netflix-youtube-43x85l-wall-bracket-tv-guard-296735179.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1989: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "65\" NANO77 NANOCELL 4K Active HDR WebOS22 65NANO776QA",
#   "price": "KSh 154,995",
#   "price_value": "1161.91",
#   "old_price": "KSh 195,995",
#   "discount_percentage": "307.35",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "LG835EA1V7VZKNAFAMZ",
#   "item_brand": "LG",
#   "product_url": "https://www.jumia.co.ke/lg-65-nano77-nanocell-4k-active-hdr-webos22-65nano776qa-102320921.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1990: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "55\" Inch,55A6K, SMART TV,NETFLIX,UHD 4K,BLUETOOTH 5.0-2024+TV GUARD",
#   "price": "KSh 57,500",
#   "price_value": "431.04",
#   "old_price": "KSh 75,000",
#   "discount_percentage": "131.19",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "HI200EA49GB73NAFAMZ",
#   "item_brand": "Hisense",
#   "product_url": "https://www.jumia.co.ke/hisense-55-inch55a6k-smart-tvnetflixuhd-4kbluetooth-5.0-2024tv-guard-255224775.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1991: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "65U7N Mini-LED ULED 4K VIDAA Smart TV",
#   "price": "KSh 103,999",
#   "price_value": "779.62",
#   "old_price": "KSh 110,000",
#   "discount_percentage": "44.99",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "HI200EA4HYSPBNAFAMZ",
#   "item_brand": "Hisense",
#   "product_url": "https://www.jumia.co.ke/hisense-65u7n-mini-led-uled-4k-vidaa-smart-tv-297614027.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1992: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32 \" Digital LED TV HDMI\\USB Port /FREE TO AIR CHANNELS.",
#   "price": "KSh 11,947",
#   "price_value": "89.56",
#   "old_price": "KSh 16,000",
#   "discount_percentage": "30.38",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "IT910EA0FIPRDNAFAMZ",
#   "item_brand": "Amtec",
#   "product_url": "https://www.jumia.co.ke/amtec-32-digital-led-tv-hdmiusb-port-free-to-air-channels.-33476062.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1993: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "23 INCHES DIGITAL LED TV INBUILT DECORDER HD TV",
#   "price": "KSh 6,999",
#   "price_value": "52.47",
#   "old_price": "KSh 10,000",
#   "discount_percentage": "22.50",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "CT303EA12DXPNNAFAMZ",
#   "item_brand": "CTC",
#   "product_url": "https://www.jumia.co.ke/ctc-23-inches-digital-led-tv-inbuilt-decorder-hd-tv-72657446.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1994: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\" Inch-HD Ready-Frameless Smart Android 11 TV Inbuilt Decoder Neflix +FREE WALL BRACKET",
#   "price": "KSh 13,390",
#   "price_value": "100.38",
#   "old_price": "KSh 26,000",
#   "discount_percentage": "94.53",
#   "rating": "4",
#   "reviews_count": "4 out of 5(1",
#   "item_id": "GL585EA21J3LXNAFAMZ",
#   "item_brand": "Gld",
#   "product_url": "https://www.jumia.co.ke/gld-32-inch-hd-ready-frameless-smart-android-11-tv-inbuilt-decoder-neflix-free-wall-bracket-190130532.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1995: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43P635 2022 LATEST 4K UHD GOOGLE TV,VOICE CONTROL,WI-FI,NETFLIX,4K HDR",
#   "price": "KSh 34,199",
#   "price_value": "256.37",
#   "old_price": "KSh 50,000",
#   "discount_percentage": "118.45",
#   "rating": "4.3",
#   "reviews_count": "4.3 out of 5(6",
#   "item_id": "TC187EA0OOCOWNAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-43p635-2022-latest-4k-uhd-google-tvvoice-controlwi-finetflix4k-hdr-67964414.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1996: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "55\" Inch,FRAMELESS/BLUETOOTH, ULTRA HD 4K HDR ,NETFLIX/YOUTUBE+WALL BRACKET+32GB FLASH DISK",
#   "price": "KSh 53,999",
#   "price_value": "404.80",
#   "old_price": "KSh 100,000",
#   "discount_percentage": "344.84",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "HI200EA3PXPJGNAFAMZ",
#   "item_brand": "Hisense",
#   "product_url": "https://www.jumia.co.ke/hisense-55-inchframelessbluetooth-ultra-hd-4k-hdr-netflixyoutubewall-bracket32gb-flash-disk-267616942.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1997: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43 Inch FHD Smart Tv 43T5300",
#   "price": "KSh 42,500",
#   "price_value": "318.60",
#   "old_price": "N/A",
#   "discount_percentage": "N/A",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SA948EA3PJF8INAFAMZ",
#   "item_brand": "Samsung",
#   "product_url": "https://www.jumia.co.ke/samsung-43-inch-fhd-smart-tv-43t5300-283159242.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1998: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "FRAMELESS //BLUETOOTH-ENABLED-4K ULTRA HD GOOGLE/ANDROID TV",
#   "price": "KSh 85,999",
#   "price_value": "644.68",
#   "old_price": "N/A",
#   "discount_percentage": "N/A",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "TC187EA3NJT41NAFAMZ",
#   "item_brand": "TCL",
#   "product_url": "https://www.jumia.co.ke/tcl-frameless-bluetooth-enabled-4k-ultra-hd-googleandroid-tv-298835902.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 1999: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "43\" Inch -4388FS-Smart /Digital Android TV,FRAMELESS/BLUETOOTH,Netflix+TILT BRACKET+POWER GUARD",
#   "price": "KSh 21,999",
#   "price_value": "164.91",
#   "old_price": "KSh 40,000",
#   "discount_percentage": "134.94",
#   "rating": "5",
#   "reviews_count": "5 out of 5(1",
#   "item_id": "VI505EA485VBWNAFAMZ",
#   "item_brand": "Vitron",
#   "product_url": "https://www.jumia.co.ke/vitron-43-inch-4388fs-smart-digital-android-tvframelessbluetoothnetflixtilt-bracketpower-guard-261557555.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Error inserting product 2000: current transaction is aborted, commands ignored until end of transaction block
#
# Problem product data: {
#   "product_name": "32\u201d Inch Digital TV With Inbuilt Decoder Black 32 inch .",
#   "price": "KSh 12,997",
#   "price_value": "97.43",
#   "old_price": "KSh 14,000",
#   "discount_percentage": "7.52",
#   "rating": "N/A",
#   "reviews_count": "0",
#   "item_id": "SY450EA4QJ7WINAFAMZ",
#   "item_brand": "Synix",
#   "product_url": "https://www.jumia.co.ke/synix-32-inch-digital-tv-with-inbuilt-decoder-black-32-inch-.-262413468.html",
#   "category": "Electronics",
#   "subcategory": "Television & Video",
#   "is_official_store": false,
#   "has_express_shipping": false
# }
# Database error: current transaction is aborted, commands ignored until end of transaction block
#
# Database connection closed.
# Error in scrape_and_save: current transaction is aborted, commands ignored until end of transaction block
#
# Main execution error: current transaction is aborted, commands ignored until end of transaction block
