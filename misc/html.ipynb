# %%
# Import necessary libraries
import requests # make HTTP requests to fetch web pages content
from bs4 import BeautifulSoup # parse HTML and XML docs for easier data extraction
import csv # write scraped data into CSV file
import time # introduce delays between requests to avoid server overload
import re #regular expression
import random # vary time delays to simulate human-like behaviour

# %%
url1 = 'https://www.jumia.co.ke/televisions/#catalog-listing' # TVs url
url2 = 'https://www.jumia.co.ke/home-cooking-appliances-cookers/#catalog-listing' # Cookers url

urls = [url1, url2]

response =requests.get(url1)
soup = BeautifulSoup(response.content, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Television - Buy TVs at Discounted Prices Online | Jumia Kenya
#   </title>
#   <meta content="product" property="og:type"/>
#   <meta content="Jumia Kenya" property="og:site_name"/>
#   <meta content="Television - Buy TVs at Discounted Prices Online | Jumia Kenya" property="og:title"/>
#   <meta content="Order TV on Jumia Kenya at exclusive prices. Shop online the latest  smart TVs, digital TV, Flat screen TV at discounted prices! Buy now pay on delivery!" property="og:description"/>
#   <meta content="/televisions/" property="og:url"/>
#   <meta content="https://ke.jumia.is/cms/icons/jumialogo-x-4.png" property="og:image"/>
#   <meta content="en_KE" property="og:locale"/>
#   <meta content="Television - Buy TVs at Discounted Prices Online | Jumia Kenya" name="title"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="Order TV on Jumia Kenya at exclusive prices. Shop online the latest  smart TVs, digital TV, Flat screen TV at discounted prices! Buy now pay on delivery!" name="description"/>
#   <link href="android-app://com.jumia.android/JUMIA/KE/c/televisions?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.co.ke%2Ftelevisions%2F" rel="alternate"/>
#   <link href="https://www.jumia.co.ke/televisions/" rel="canonical"/>
#   <link href="https://www.jumia.co.ke/televisions/?page=2" rel="next"/>
#   <meta content="2099414773624117" property="fb:app_id"/>
#   <meta content="395103207248808" property="fb:pages"/>
#   <meta content="n_VPq2qj81eefHQXQuWUQcpCjf22dILtzJ-5fqwv3cY" name="google-site-verification"/>
#   <meta content="oPpguRNQpgJeq2_7FfJhfy4zTSNTJBX_LLPgB_SUq9g" name="google-site-verification"/>
#   <meta content="18D4C7784A54CEB370A0B89D0634A096" name="msvalidate.01"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Jumia" name="application-name"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link crossorigin="use-credentials" href="https://www.jumia.co.ke/assets_he/manifest/jumia/ke.4f33d8aa.json" rel="manifest"/>
#   <link href="https://www.jumia.co.ke/assets_he/css/main.90c53fdb.css" rel="stylesheet"/>
#   <link href="https://www.jumia.co.ke/assets_he/favicon.87f00114.ico" rel="icon" sizes="any" type="image/ico"/>
#   <link href="https://www.jumia.co.ke/assets_he/favicon.adbd556a.svg" rel="icon" type="image/svg+xml"/>
#   <link href="//bam.nr-data.net" rel="preconnect dns-prefetch"/>
#   <link href="//js-agent.newrelic.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.facebook.com" rel="preconnect dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="preconnect dns-prefetch"/>
#   <link href="//static.criteo.net" rel="preconnect dns-prefetch"/>
#   <link href="//sslwidget.criteo.com" rel="preconnect dns-prefetch"/>
#   <link href="//dis.eu.criteo.com" rel="preconnect dns-prefetch"/>
#   <link href="//creativecdn.com" rel="preconnect dns-prefetch"/>
#   <link href="https://ke.jumia.is" rel="dns-prefetch"/>
#  </head>
#  <body>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"697464566","agentToken":null,"applicationTime":113.625424,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFnVUFgMOVlIWHUY0LWpi","queueTime":0,"ttGuid":"9f255650065333e8"}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"718362546",accountID:"67325",trustKey:"1300143",xpid:"UgEEU1NADgoHUFdWAgcB",licenseKey:"b76de0635f",applicationID:"697464566"};;/*! For license information please see nr-loader-spa-1.277.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={8122:(e,t,r)=>{"use strict";r.d(t,{a:()=>i});var n=r(944);function i(e,t){try{if(!e||"object"!=typeof e)return(0,n.R)(3);if(!t||"object"!=typeof t)return(0,n.R)(4);const r=Object.create(Object.getPrototypeOf(t),Object.getOwnPropertyDescriptors(t)),o=0===Object.keys(r).length?e:r;for(let a in o)if(void 0!==e[a])try{if(null===e[a]){r[a]=null;continue}Array.isArray(e[a])&&Array.isArray(t[a])?r[a]=Array.from(new Set([...e[a],...t[a]])):"object"==typeof e[a]&&"object"==typeof t[a]?r[a]=i(e[a],t[a]):r[a]=e[a]}catch(e){(0,n.R)(1,e)}return r}catch(e){(0,n.R)(2,e)}}},2555:(e,t,r)=>{"use strict";r.d(t,{Vp:()=>c,fn:()=>s,x1:()=>u});var n=r(384),i=r(8122);const o={beacon:n.NT.beacon,errorBeacon:n.NT.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){try{const t=c(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}function c(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function u(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.a)(t,o);const r=(0,n.nY)(e);r&&(r.info=a[e])}},9417:(e,t,r)=>{"use strict";r.d(t,{D0:()=>p,gD:()=>m,xN:()=>g});var n=r(3333),i=r(993);const o=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var a=r(2614),s=r(944),c=r(384),u=r(8122);const d="[data-nr-mask]",l=()=>{const e={feature_flags:[],experimental:{marks:!1,measures:!1,resources:!1},mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},get feature_flags(){return e.feature_flags},set feature_flags(t){e.feature_flags=t},generic_events:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},harvest:{tooManyRequestsDelay:60},jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},logging:{enabled:!0,harvestTimeSeconds:10,autoStart:!0,level:i.p_.INFO},metrics:{enabled:!0,autoStart:!0},obfuscate:void 0,page_action:{enabled:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},performance:{get capture_marks(){return e.feature_flags.includes(n.$v.MARKS)||e.experimental.marks},set capture_marks(t){e.experimental.marks=t},get capture_measures(){return e.feature_flags.includes(n.$v.MEASURES)||e.experimental.measures},set capture_measures(t){e.experimental.measures=t},resources:{get enabled(){return e.feature_flags.includes(n.$v.RESOURCES)||e.experimental.resources},set enabled(t){e.experimental.resources=t},asset_types:[],first_party_domains:[],ignore_newrelic:!0}},privacy:{cookies_enabled:!0},proxy:{assets:void 0,beacon:void 0},session:{expiresMs:a.wk,inactiveMs:a.BB},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,preload:!1,sampling_rate:10,error_sampling_rate:100,collect_fonts:!1,inline_images:!1,fix_stylesheets:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){o(t)?e.mask_selector="".concat(t,",").concat(d):""===t||null===t?e.mask_selector=d:(0,s.R)(5,t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){o(t)?e.block_selector+=",".concat(t):""!==t&&(0,s.R)(6,t)},get mask_input_options(){return e.mask_input_options},set mask_input ...
#   </script>
#   <div id="jm">
#    <div class="vb row -i-ctr -j-ctr _head -bg-gy05">
#     <div class="col3 -df -j-start">
#      <a class="_link -df -i-ctr -or5 -m -fs12" href="https://www.jumia.co.ke/sp-sell/" rel="noopener" target="_blank">
#       <svg class="ic -f-or5 -maxs" height="16" viewbox="0 0 24 24" width="16">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-services">
#        </use>
#       </svg>
#       Sell on Jumia
#      </a>
#     </div>
#     <div class="col10 -df -j-ctr -fs0">
#      <span class="vent-link" href="" title="Jumia">
#       <svg class="ic" height="24" viewbox="0 0 67 24" width="67">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.2771d4ef.svg#venture-jumia">
#        </use>
#       </svg>
#      </span>
#      <a class="vent-link" href="https://pay.jumia.co.ke/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=Venturebar" rel="nofollow noopener" target="_blank" title="Jumia Pay">
#       <svg class="ic" height="24" viewbox="0 0 60 24" width="60">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.2771d4ef.svg#venture-pay">
#        </use>
#       </svg>
#      </a>
#     </div>
#     <div class="col3 -df -j-end -wt -mla -gy5">
#     </div>
#    </div>
#    <header class="header">
#     <section class="row -i-ctr -fw-nw -pvm">
#      <div class="col3 -df -i-ctr">
#       <div class="dpdw _tail _auto-w _hov _pleft -df -i-ctr -prs -mra" data-dpdw="true">
#        <input aria-controls="dpdw-flyout-box" aria-haspopup="true" aria-label="Navigate Categories" class="tgl" id="dpdw-flyout" type="checkbox"/>
#        <label class="trig -df -pan" for="dpdw-flyout">
#         <span class="-fsh0">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#menu">
#           </use>
#          </svg>
#         </span>
#        </label>
#        <div aria-labelledby="dpdw-flyout" class="box" id="dpdw-flyout-box" role="menu">
#         <div class="inbox">
#          <div class="flyout" role="menu">
#           <a class="itm" href="https://www.jumia.co.ke/mlp-jumia-official-stores/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-mall">
#             </use>
#            </svg>
#            <span class="text">
#             Official Stores
#            </span>
#           </a>
#           <a class="itm" href="/phones-tablets/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-mobile">
#             </use>
#            </svg>
#            <span class="text">
#             Phones &amp; Tablets
#            </span>
#           </a>
#           <a class="itm" href="https://www.jumia.co.ke/electronics/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-tv">
#             </use>
#            </svg>
#            <span class="text">
#             TVs &amp; Audio
#            </span>
#           </a>
#           <a class="itm" href="https://www.jumia.co.ke/home-office-appliances/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-appliance">
#             </use>
#            </svg>
#            <span class="text">
#             Appliances
#            </span>
#           </a>
#           <a class="itm" href="/health-beauty/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-beauty">
#             </use>
#            </svg>
#            <span class="text">
#             Health &amp; Beauty
#            </span>
#           </a>
#           <a class="itm" href="/home-office/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-appliance">
#             </use>
#            </svg>
#            <span class="text">
#             Home &amp; Office
#            </span>
#           </a>
#           <a class="itm" href="/category-fashion-by-jumia/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-fashion">
#             </use>
#            </svg>
#            <span class="text">
#             Fashion
#            </span>
#           </a>
#           <a class="itm" href="/computing/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-computing">
#             </use>
#            </svg>
#            <span class="text">
#             Computing
#            </span>
#           </a>
#           <a class="itm" href="https://www.jumia.co.ke/groceries/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-groceries">
#             </use>
#            </svg>
#            <span class="text">
#             Supermarket
#            </span>
#           </a>
#           <a class="itm" href="/baby-products/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-baby">
#             </use>
#            </svg>
#            <span class="text">
#             Baby Products
#            </span>
#           </a>
#           <a class="itm" href="/sporting-goods/" role="menuitem">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-fitness">
#             </use>
#            </svg>
#            <span class="text">
#             Sporting Goods
#            </span>
#           </a>
#           <span class="itm" role="menuitem" tabindex="0">
#            <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#cat-othercategories">
#             </use>
#            </svg>
#            <span class="text">
#             Other categories
#            </span>
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#       <a class="-df -i-ctr -mra" href="/">
#        <svg aria-label="Jumia Kenya - Online Shopping for TVs, Electronics, Phones, Fashion &amp; more" class="ic" height="30" role="img" viewbox="0 0 172 30" width="134">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-shop-jumia.9dea3b69.svg#logo">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <form action="/catalog/" class="cola -df" data-track-onsubmit="search" id="search" method="get">
#       <div class="find">
#        <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#search">
#         </use>
#        </svg>
#        <input aria-label="Search" autocomplete="off" id="fi-q" name="q" placeholder="Search products, brands and categories" required="" type="text" value=""/>
#        <button aria-label="Reset" class="rst" type="button">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#close">
#          </use>
#         </svg>
#        </button>
#        <div class="sug">
#        </div>
#       </div>
#       <button class="btn _prim _md -mls -fsh0">
#        Search
#       </button>
#      </form>
#      <div class="col -df -j-bet -m -phn -i-ctr">
#       <div class="dpdw _pcent" data-dpdw="true">
#        <input aria-controls="dpdw-login-box" aria-haspopup="true" aria-label="Account" class="tgl" id="dpdw-login" type="checkbox"/>
#        <label class="trig -df -i-ctr -fs16" for="dpdw-login">
#         <span class="-fsh0 -mrs">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#person">
#           </use>
#          </svg>
#         </span>
#         Account
#         <svg class="ic -fsh0 -mls" height="18" viewbox="0 0 24 24" width="18">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#arrow-down">
#          </use>
#         </svg>
#        </label>
#        <div aria-labelledby="dpdw-login" class="box -r" id="dpdw-login-box" role="menu">
#         <div class="inbox">
#          <div class="-pam -hr-bb">
#           <a class="btn _prim -fw _md" href="/customer/account/login/?return=%2Ftelevisions%2F" rel="nofollow">
#            Sign In
#           </a>
#          </div>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/account/index/" rel="nofollow">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#person">
#            </use>
#           </svg>
#           My Account
#          </a>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/order/index/" rel="nofollow">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#orders">
#            </use>
#           </svg>
#           Orders
#          </a>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/wishlist/index/" rel="nofollow">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#favorite-border">
#            </use>
#           </svg>
#           Saved Items
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="dpdw _pcent" data-dpdw="true">
#        <input aria-controls="dpdw-help-box" aria-haspopup="true" aria-label="Help" class="tgl" id="dpdw-help" type="checkbox"/>
#        <label class="trig -df -i-ctr -fs16" for="dpdw-help">
#         <span class="-fsh0 -mrs">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#help-outline">
#           </use>
#          </svg>
#         </span>
#         Help
#         <svg class="ic -fsh0 -mls" height="18" viewbox="0 0 24 24" width="18">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#arrow-down">
#          </use>
#         </svg>
#        </label>
#        <div aria-labelledby="dpdw-help" class="box -r" id="dpdw-help-box" role="menu">
#         <div class="inbox">
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-help/">
#           Help Center
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-help/?page=place+an+order">
#           Place your Order
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-help/?page=pay+for+your+order">
#           Payment Options
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-help/?page=track+your+order">
#           Delivery Timelines &amp; Track your Order
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-help/?page=create+a+return">
#           Returns &amp; Refunds
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-warranty-cp">
#           Warranty
#          </a>
#          <div class="-tac -hr _hx2 -fs0 -pam">
#           <button class="btn _prim _md _i -fw" data-btn-lc="true" data-eventaction="open" data-eventcategory="LiveChat" data-eventname="live_chat_open" data-track-onclick="true">
#            <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#chat">
#             </use>
#            </svg>
#            <span>
#             Live Chat
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <a class="-df -i-ctr -gy9 -hov-or5 -phs -fs16" href="/cart/">
#        <span class="-mrs -fs0" id="ci">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#shopping-cart">
#          </use>
#         </svg>
#        </span>
#        Cart
#       </a>
#      </div>
#     </section>
#    </header>
#    <article class="banner-pop _pp" data-ppb-rev="v1.0">
#     <h2 class="-fs20 -m">
#      This website uses cookies
#     </h2>
#     <p class="-pts -pbl">
#      This website uses cookies. For further information on how we use cookies you can read our
#      <a class="_more -di" href="/sp-privacy/" rel="noopener" target="_blank">
#       Privacy and Cookie notice
#      </a>
#     </p>
#     <button class="btn _prim -df -mla">
#      Accept cookies
#     </button>
#    </article>
#    <main class="has-b2top -pts">
#     <style>
#      .c-prd{order:16;}.c-prd._spn:nth-last-of-type(1){order: 0;}.c-prd._spn:nth-last-of-type(2){order: 1;}.c-prd._spn:nth-last-of-type(3){order: 2;}.c-prd._spn:nth-last-of-type(4){order: 3;}.c-prd:nth-child(n+0):nth-child(-n+4):not(._spn),.c-prd._spn:nth-last-of-type(5){order: 4;}.c-prd:nth-child(n+5):nth-child(-n+8):not(._spn),.c-prd._spn:nth-last-of-type(6){order: 5;}.c-prd:nth-child(n+9):nth-child(-n+12):not(._spn),.c-prd._spn:nth-last-of-type(7){order: 6;}.c-prd:nth-child(n+13):nth-child(-n+16):not(._spn),.c-prd._spn:nth-last-of-type(8){order: 7;}.c-prd:nth-child(n+17):nth-child(-n+20):not(._spn),.c-prd._spn:nth-last-of-type(9){order: 8;}.c-prd:nth-child(n+21):nth-child(-n+24):not(._spn),.c-prd._spn:nth-last-of-type(10){order: 9;}.c-prd:nth-child(n+25):nth-child(-n+28):not(._spn),.c-prd._spn:nth-last-of-type(11){order: 10;}.c-prd:nth-child(n+29):nth-child(-n+32):not(._spn),.c-prd._spn:nth-last-of-type(12){order: 11;}.c-prd:nth-child(n+33):nth-child(-n+36):not(._spn),.c-prd._spn:nth-last-of-type(13){order: 12;}.c-prd:nth-child(n+37):nth-child(-n+40):not(._spn),.c-prd._spn:nth-last-of-type(14){order: 13;}.c-prd:nth-child(n+41):nth-child(-n+44):not(._spn),.c-prd._spn:nth-last-of-type(15){order: 14;}.c-prd:nth-child(n+45):nth-child(-n+48):not(._spn),.c-prd._spn:nth-last-of-type(16){order: 15;}
#     </style>
#     <div class="row">
#      <div class="brcbs col16 -pvs">
#       <a class="cbs" href="/">
#        Home
#       </a>
#       <a class="cbs" href="/electronics/">
#        Electronics
#       </a>
#       <a class="cbs" href="/electronic-television-video/">
#        Television &amp; Video
#       </a>
#       <span class="cbs">
#        Televisions
#       </span>
#      </div>
#      <div class="col16">
#       <div class="-rad4 -oh -mvs -mxh-250px" data-ad="true" id="catalog_top">
#       </div>
#      </div>
#     </div>
#     <section id="ctlg">
#      <div class="row">
#       <div class="col16 -pvs">
#        <div class="cms -phm -pvs markup">
#         <div style="padding: 8px 16px; text-align: center; border-radius: 4px; background-color: #000000; width: 103%; transform: translateX(-1.5%); margin-bottom: -8px; font-weight: 500; font-size: 1.4em;color:white;">
#          Electronics
#         </div>
#        </div>
#       </div>
#       <div class="col16 -pvs">
#        <section class="card -oh _fw -rad4">
#         <header class="row _no-g -fw-nw -j-bet -i-ctr -phm -mh-48px" style="background:#FF9900;">
#          <div class="cola -df -i-ctr -oh">
#           <h2 class="-m -fs20 -elli">
#            Top Deals On Televisions
#           </h2>
#          </div>
#         </header>
#         <div class="row _no-g _6cl-4cm-shs -paxs">
#          <article class="prd _box col _hvr">
#           <a class="core" data-ga4-discount="45.03" data-ga4-index="1" data-ga4-item_brand="Vision Plus" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Digital TVs" data-ga4-item_id="VI799EA1QMSQ4NAFAMZ" data-ga4-item_name='32" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)' data-ga4-list="productfloor_1_category:Televisions_2313_en_KE" data-ga4-price="75.10" data-ga4-tags="APP30|BLF|BLF_04|BLF_10|CFS|CP_2|CP_MT31|CP_UN104|CP_UN105|CP_UN132|CP_UN157|JA|JF|JMALL|TBOOST|WRNTY_2|ZF_90" data-gtm-brand="Vision Plus" data-gtm-category="Electronics/Television &amp; Video/Televisions/Digital TVs" data-gtm-dimension23="132291" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="APP30|BLF|BLF_04|BLF_10|CFS|CP_2|CP_MT31|CP_UN104|CP_UN105|CP_UN132|CP_UN157|JA|JF|JMALL|TBOOST|WRNTY_2|ZF_90" data-gtm-dimension44="0" data-gtm-id="VI799EA1QMSQ4NAFAMZ" data-gtm-list="productfloor_1_category:Televisions_2313_en_KE" data-gtm-name='32" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)' data-gtm-position="1" data-gtm-price="75.10" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vision-plus-32-digital-hd-frameless-tv-dvbt2s2-black-2yrs-wrty-125899150.html">
#            <img alt='Vision Plus 32" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/05/1998521/1.jpg?3014" height="185" src="..." width="185"/>
#            <div class="name">
#             Vision Plus 32" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)
#            </div>
#            <div class="prc" data-oprc="KSh 15,995">
#             KSh 9,999
#            </div>
#            <div class="bdg _dsct">
#             37%
#            </div>
#           </a>
#          </article>
#          <article class="prd _box col _hvr">
#           <a class="core" data-ga4-discount="36.71" data-ga4-index="2" data-ga4-item_brand="Vitron" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Large screen TV" data-ga4-item_id="VI505EA0ZN799NAFAMZ" data-ga4-item_name="HTC5068US 50” Smart Android 4K UHD LED TV - Black (1YR WRTY)" data-ga4-list="productfloor_1_category:Televisions_2313_en_KE" data-ga4-price="263.69" data-ga4-tags="BLF|BLF_04|CFS|COL_249|CP_2|CP_23|CP_26|CP_MT31|CP_MT60|CP_MT67|CP_UN132|CP_UN256|CP_UN262|CP_UN263|CP_UN264|CP_UN265|JA|JF|JMALL|WRNTY_1" data-gtm-brand="Vitron" data-gtm-category="Electronics/Television &amp; Video/Televisions/Large screen TV" data-gtm-dimension23="44909" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="BLF|BLF_04|CFS|COL_249|CP_2|CP_23|CP_26|CP_MT31|CP_MT60|CP_MT67|CP_UN132|CP_UN256|CP_UN262|CP_UN263|CP_UN264|CP_UN265|JA|JF|JMALL|WRNTY_1" data-gtm-dimension44="0" data-gtm-id="VI505EA0ZN799NAFAMZ" data-gtm-list="productfloor_1_category:Televisions_2313_en_KE" data-gtm-name="HTC5068US 50” Smart Android 4K UHD LED TV - Black (1YR WRTY)" data-gtm-position="2" data-gtm-price="263.69" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vitron-htc5068us-50-smart-android-4k-uhd-led-tv-black-1yr-wrty-35096895.html">
#            <img alt="Vitron HTC5068US 50” Smart Android 4K UHD LED TV - Black (1YR WRTY)" class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/59/869053/1.jpg?7469" height="185" src="..." width="185"/>
#            <div class="name">
#             Vitron HTC5068US 50” Smart Android 4K UHD LED TV - Black (1YR WRTY)
#            </div>
#            <div class="prc" data-oprc="KSh 39,999">
#             KSh 35,111
#            </div>
#            <div class="bdg _dsct">
#             12%
#            </div>
#           </a>
#          </article>
#          <article class="prd _box col _hvr">
#           <a class="core" data-ga4-discount="14.19" data-ga4-index="3" data-ga4-item_brand="Amtec" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Digital TVs" data-ga4-item_id="AM617EA2AT60QNAFAMZ" data-ga4-item_name='32" M6 Digital LED TV DVBt2 HD AC (1YR WRTY)' data-ga4-list="productfloor_1_category:Televisions_2313_en_KE" data-ga4-price="75.93" data-ga4-tags="CFS|CP_2|JF|JMALL|WRNTY_1|ZF_90" data-gtm-brand="Amtec" data-gtm-category="Electronics/Television &amp; Video/Televisions/Digital TVs" data-gtm-dimension23="100934" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="CFS|CP_2|JF|JMALL|WRNTY_1|ZF_90" data-gtm-dimension44="0" data-gtm-id="AM617EA2AT60QNAFAMZ" data-gtm-list="productfloor_1_category:Televisions_2313_en_KE" data-gtm-name='32" M6 Digital LED TV DVBt2 HD AC (1YR WRTY)' data-gtm-position="3" data-gtm-price="75.93" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/amtec-32-m6-digital-led-tv-dvbt2-hd-ac-1yr-wrty-183398093.html">
#            <img alt='Amtec 32" M6 Digital LED TV DVBt2 HD AC (1YR WRTY)' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/39/0893381/1.jpg?5171" height="185" src="..." width="185"/>
#            <div class="name">
#             Amtec 32" M6 Digital LED TV DVBt2 HD AC (1YR WRTY)
#            </div>
#            <div class="prc" data-oprc="KSh 12,000">
#             KSh 10,110
#            </div>
#            <div class="bdg _dsct">
#             16%
#            </div>
#           </a>
#          </article>
#          <article class="prd _box col _hvr">
#           <a class="core" data-ga4-discount="64.96" data-ga4-index="4" data-ga4-item_brand="Amtec" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Smart TVs" data-ga4-item_id="AM617EA1K3NOJNAFAMZ" data-ga4-item_name='43L12, 43" FHD Smart Android TV, Netfix, Youtube, Bluetooth - Black (1YR WRTY)' data-ga4-list="productfloor_1_category:Televisions_2313_en_KE" data-ga4-price="145.32" data-ga4-tags="CFS|CP_2|CP_23|CP_26|CP_UN132|CP_UN246|CP_UN255|CP_UN256|JA|JF|JMALL|WRNTY_1|ZF_90" data-gtm-brand="Amtec" data-gtm-category="Electronics/Television &amp; Video/Televisions/Smart TVs" data-gtm-dimension23="100934" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="CFS|CP_2|CP_23|CP_26|CP_UN132|CP_UN246|CP_UN255|CP_UN256|JA|JF|JMALL|WRNTY_1|ZF_90" data-gtm-dimension44="0" data-gtm-id="AM617EA1K3NOJNAFAMZ" data-gtm-list="productfloor_1_category:Televisions_2313_en_KE" data-gtm-name='43L12, 43" FHD Smart Android TV, Netfix, Youtube, Bluetooth - Black (1YR WRTY)' data-gtm-position="4" data-gtm-price="145.32" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/amtec-43l12-43-fhd-smart-android-tv-netfix-youtube-bluetooth-black-1yr-wrty-55192249.html">
#            <img alt='Amtec 43L12, 43" FHD Smart Android TV, Netfix, Youtube, Bluetooth - Black (1YR WRTY)' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/94/229155/1.jpg?4796" height="185" src="..." width="185"/>
#            <div class="name">
#             Amtec 43L12, 43" FHD Smart Android TV, Netfix, Youtube, Bluetooth - Black (1YR WRTY)
#            </div>
#            <div class="prc" data-oprc="KSh 28,000">
#             KSh 19,350
#            </div>
#            <div class="bdg _dsct">
#             31%
#            </div>
#           </a>
#          </article>
#          <article class="prd _box col _hvr">
#           <a class="core" data-ga4-discount="116.38" data-ga4-index="5" data-ga4-item_brand="Vision Plus" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Large screen TV" data-ga4-item_id="VI799EA2KEGZ0NAFAMZ" data-ga4-item_name='VP8855KV - 55" 4K Frameless V+ OS Smart TV (2YRS WRTY)' data-ga4-list="productfloor_1_category:Televisions_2313_en_KE" data-ga4-price="296.65" data-ga4-tags="BLF|BLF_04|COL_249|CP_2|CP_23|CP_26|CP_MT31|CP_UN238|CP_UN262|CP_UN263|CP_UN264|CP_UN265|JF|JMALL|MSTPRF|WRNTY_2|ZF_90" data-gtm-brand="Vision Plus" data-gtm-category="Electronics/Television &amp; Video/Televisions/Large screen TV" data-gtm-dimension23="132291" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="BLF|BLF_04|COL_249|CP_2|CP_23|CP_26|CP_MT31|CP_UN238|CP_UN262|CP_UN263|CP_UN264|CP_UN265|JF|JMALL|MSTPRF|WRNTY_2|ZF_90" data-gtm-dimension44="0" data-gtm-id="VI799EA2KEGZ0NAFAMZ" data-gtm-list="productfloor_1_category:Televisions_2313_en_KE" data-gtm-name='VP8855KV - 55" 4K Frameless V+ OS Smart TV (2YRS WRTY)' data-gtm-position="5" data-gtm-price="296.65" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vision-plus-vp8855kv-55-4k-frameless-v-os-smart-tv-2yrs-wrty-125899155.html">
#            <img alt='Vision Plus VP8855KV - 55" 4K Frameless V+ OS Smart TV (2YRS WRTY)' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/55/1998521/1.jpg?2188" height="185" src="..." width="185"/>
#            <div class="name">
#             Vision Plus VP8855KV - 55" 4K Frameless V+ OS Smart TV (2YRS WRTY)
#            </div>
#            <div class="prc" data-oprc="KSh 54,995">
#             KSh 39,499
#            </div>
#            <div class="bdg _dsct">
#             28%
#            </div>
#           </a>
#          </article>
#          <article class="prd _box col _hvr">
#           <a class="core" data-ga4-discount="74.35" data-ga4-index="6" data-ga4-item_brand="Royal" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Smart TVs" data-ga4-item_id="RO689EA2DYPHXNAFAMZ" data-ga4-item_name='43" Smart Frameless Full HD LED Television - Black.' data-ga4-list="productfloor_1_category:Televisions_2313_en_KE" data-ga4-price="150.96" data-ga4-tags="CFS|CP_2|CP_UN132|CP_UN246|CP_UN255|CP_UN256|INV_CLEAR|JA|JF|JMALL" data-gtm-brand="Royal" data-gtm-category="Electronics/Television &amp; Video/Televisions/Smart TVs" data-gtm-dimension23="151568" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="CFS|CP_2|CP_UN132|CP_UN246|CP_UN255|CP_UN256|INV_CLEAR|JA|JF|JMALL" data-gtm-dimension44="0" data-gtm-id="RO689EA2DYPHXNAFAMZ" data-gtm-list="productfloor_1_category:Televisions_2313_en_KE" data-gtm-name='43" Smart Frameless Full HD LED Television - Black.' data-gtm-position="6" data-gtm-price="150.96" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/royal-43-smart-frameless-full-hd-led-television-black.-190768344.html">
#            <img alt='Royal 43" Smart Frameless Full HD LED Television - Black.' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/44/3867091/1.jpg?7718" height="185" src="..." width="185"/>
#            <div class="name">
#             Royal 43" Smart Frameless Full HD LED Television - Black.
#            </div>
#            <div class="prc" data-oprc="KSh 30,000">
#             KSh 20,100
#            </div>
#            <div class="bdg _dsct">
#             33%
#            </div>
#           </a>
#          </article>
#          <article class="prd _box col _hvr">
#           <a class="core" data-ga4-discount="33.16" data-ga4-index="7" data-ga4-item_brand="Vitron" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Digital TVs" data-ga4-item_id="VI505EA1Q0QMQNAFAMZ" data-ga4-item_name='HTC3218F - 32" HD Frameless LED Digital TV (StarTimes Inbuilt Decoder) 1YR WRTY' data-ga4-list="productfloor_1_category:Televisions_2313_en_KE" data-ga4-price="83.36" data-ga4-tags="BLF|BLF_04|CP_2|CP_UN132|CP_UN256|JA|JF|JMALL|WRNTY_1|ZF_90" data-gtm-brand="Vitron" data-gtm-category="Electronics/Television &amp; Video/Televisions/Digital TVs" data-gtm-dimension23="44909" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="BLF|BLF_04|CP_2|CP_UN132|CP_UN256|JA|JF|JMALL|WRNTY_1|ZF_90" data-gtm-dimension44="0" data-gtm-id="VI505EA1Q0QMQNAFAMZ" data-gtm-list="productfloor_1_category:Televisions_2313_en_KE" data-gtm-name='HTC3218F - 32" HD Frameless LED Digital TV (StarTimes Inbuilt Decoder) 1YR WRTY' data-gtm-position="7" data-gtm-price="83.36" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vitron-htc3218f-32-hd-frameless-led-digital-tv-startimes-inbuilt-decoder-1yr-wrty-160707140.html">
#            <img alt='Vitron HTC3218F - 32" HD Frameless LED Digital TV (StarTimes Inbuilt Decoder) 1YR WRTY' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/04/1707061/1.jpg?4272" height="185" src="..." width="185"/>
#            <div class="name">
#             Vitron HTC3218F - 32" HD Frameless LED Digital TV (StarTimes Inbuilt Decoder) 1YR WRTY
#            </div>
#            <div class="prc" data-oprc="KSh 15,514">
#             KSh 11,099
#            </div>
#            <div class="bdg _dsct">
#             28%
#            </div>
#           </a>
#          </article>
#         </div>
#        </section>
#       </div>
#       <div class="col16 -pvs">
#        <section class="card -oh _fw -rad4">
#         <header class="row _no-g -fw-nw -j-bet -i-ctr -phm -mh-48px" style="color:#FFFFFF;background:#4B158D;">
#          <div class="cola -df -i-ctr -oh">
#           <h2 class="-m -fs20 -elli">
#            Vision Plus | TV Deals
#            <span class="-r">
#             | Up to 40% Off
#            </span>
#           </h2>
#          </div>
#          <div class="col -df -j-end -fsh0">
#           <a class="-df -i-ctr -upp -m -mls -pvxs" href="https://www.jumia.co.ke/mlp-vision-plus/">
#            See All
#            <svg class="ic" height="24" style="fill:#FFFFFF;" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#arrow-right">
#             </use>
#            </svg>
#           </a>
#          </div>
#         </header>
#         <div class="crs-w _main -phxs" data-crs-onview="">
#          <div class="crs row _no-g -fw-nw _6cl-4cm -pvxs">
#           <div class="itm col">
#            <article class="prd _box _hvr">
#             <a class="core" data-ga4-discount="45.03" data-ga4-index="1" data-ga4-item_brand="Vision Plus" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Digital TVs" data-ga4-item_id="VI799EA1QMSQ4NAFAMZ" data-ga4-item_name='32" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)' data-ga4-list="productfloor_2_category:Televisions_2313_en_KE" data-ga4-price="75.10" data-ga4-tags="APP30|BLF|BLF_04|BLF_10|CFS|CP_2|CP_MT31|CP_UN104|CP_UN105|CP_UN132|CP_UN157|JA|JF|JMALL|TBOOST|WRNTY_2|ZF_90" data-gtm-brand="Vision Plus" data-gtm-category="Electronics/Television &amp; Video/Televisions/Digital TVs" data-gtm-dimension23="132291" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="APP30|BLF|BLF_04|BLF_10|CFS|CP_2|CP_MT31|CP_UN104|CP_UN105|CP_UN132|CP_UN157|JA|JF|JMALL|TBOOST|WRNTY_2|ZF_90" data-gtm-dimension44="0" data-gtm-id="VI799EA1QMSQ4NAFAMZ" data-gtm-list="productfloor_2_category:Televisions_2313_en_KE" data-gtm-name='32" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)' data-gtm-position="1" data-gtm-price="75.10" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vision-plus-32-digital-hd-frameless-tv-dvbt2s2-black-2yrs-wrty-125899150.html">
#              <img alt='Vision Plus 32" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/05/1998521/1.jpg?3014" height="185" src="..." width="185"/>
#              <div class="name">
#               Vision Plus 32" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)
#              </div>
#              <div class="prc" data-oprc="KSh 15,995">
#               KSh 9,999
#              </div>
#              <div class="bdg _dsct">
#               37%
#              </div>
#             </a>
#            </article>
#           </div>
#           <div class="itm col">
#            <article class="prd _box _hvr">
#             <a class="core" data-ga4-discount="25.19" data-ga4-index="2" data-ga4-item_brand="Vision Plus" data-ga4-item_category="Electronics" data-ga4-item_category2="Home Audio" data-ga4-item_category3="Home Theater Systems" data-ga4-item_category4="Sound Bars" data-ga4-item_id="VI799EA28JY18NAFAMZ" data-ga4-item_name="VP2110SB - 2.1CH Soundbar With Bluetooth - Black (2YRs WRTY)" data-ga4-list="productfloor_2_category:Televisions_2313_en_KE" data-ga4-price="49.88" data-ga4-tags="BLF|BLF_04|BLF_10|CP_2|CP_23|CP_26|CP_MT31|CP_UN262|CP_UN264|CP_UN265|JA|JF|JMALL|WRNTY_2|ZF_90" data-gtm-brand="Vision Plus" data-gtm-category="Electronics/Home Audio/Home Theater Systems/Sound Bars" data-gtm-dimension23="132291" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="BLF|BLF_04|BLF_10|CP_2|CP_23|CP_26|CP_MT31|CP_UN262|CP_UN264|CP_UN265|JA|JF|JMALL|WRNTY_2|ZF_90" data-gtm-dimension44="0" data-gtm-id="VI799EA28JY18NAFAMZ" data-gtm-list="productfloor_2_category:Televisions_2313_en_KE" data-gtm-name="VP2110SB - 2.1CH Soundbar With Bluetooth - Black (2YRs WRTY)" data-gtm-position="2" data-gtm-price="49.88" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vision-plus-vp2110sb-2.1ch-soundbar-with-bluetooth-black-2yrs-wrty-125899253.html">
#              <img alt="Vision Plus VP2110SB - 2.1CH Soundbar With Bluetooth - Black (2YRs WRTY)" class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/35/2998521/1.jpg?2044" height="185" src="..." width="185"/>
#              <div class="name">
#               Vision Plus VP2110SB - 2.1CH Soundbar With Bluetooth - Black (2YRs WRTY)
#              </div>
#              <div class="prc" data-oprc="KSh 9,995">
#               KSh 6,641
#              </div>
#              <div class="bdg _dsct">
#               34%
#              </div>
#             </a>
#            </article>
#           </div>
#           <div class="itm col">
#            <article class="prd _box _hvr">
#             <a class="core" data-ga4-discount="23.66" data-ga4-index="3" data-ga4-item_brand="Vision Plus" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Smart TVs" data-ga4-item_id="VI799EA2WDA8CNAFAMZ" data-ga4-item_name='43" Full HD Android Frameless Smart TV,Dvb-T2/S2 +Free Wall Bracket (2YRS WRTY)' data-ga4-list="productfloor_2_category:Televisions_2313_en_KE" data-ga4-price="156.59" data-ga4-tags="BLF|BLF_04|CFS|CP_2|CP_23|CP_26|CP_MT31|CP_UN132|CP_UN246|CP_UN255|CP_UN262|CP_UN263|CP_UN264|CP_UN265|JA|JF|JMALL|WRNTY_2|ZF_90" data-gtm-brand="Vision Plus" data-gtm-category="Electronics/Television &amp; Video/Televisions/Smart TVs" data-gtm-dimension23="132291" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="BLF|BLF_04|CFS|CP_2|CP_23|CP_26|CP_MT31|CP_UN132|CP_UN246|CP_UN255|CP_UN262|CP_UN263|CP_UN264|CP_UN265|JA|JF|JMALL|WRNTY_2|ZF_90" data-gtm-dimension44="0" data-gtm-id="VI799EA2WDA8CNAFAMZ" data-gtm-list="productfloor_2_category:Televisions_2313_en_KE" data-gtm-name='43" Full HD Android Frameless Smart TV,Dvb-T2/S2 +Free Wall Bracket (2YRS WRTY)' data-gtm-position="3" data-gtm-price="156.59" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vision-plus-43-full-hd-android-frameless-smart-tvdvb-t2s2-free-wall-bracket-2yrs-wrty-125899257.html">
#              <img alt='Vision Plus 43" Full HD Android Frameless Smart TV,Dvb-T2/S2 +Free Wall Bracket (2YRS WRTY)' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/75/2998521/1.jpg?2188" height="185" src="..." width="185"/>
#              <div class="name">
#               Vision Plus 43" Full HD Android Frameless Smart TV,Dvb-T2/S2 +Free Wall Bracket (2YRS WRTY)
#              </div>
#              <div class="prc" data-oprc="KSh 24,000">
#               KSh 20,850
#              </div>
#              <div class="bdg _dsct">
#               13%
#              </div>
#             </a>
#            </article>
#           </div>
#           <div class="itm col">
#            <article class="prd _box _hvr">
#             <a class="core" data-ga4-discount="64.33" data-ga4-index="4" data-ga4-item_brand="Vision Plus" data-ga4-item_category="Electronics" data-ga4-item_category2="Television &amp; Video" data-ga4-item_category3="Televisions" data-ga4-item_category4="Smart TVs" data-ga4-item_id="VI799EA1VZP64NAFAMZ" data-ga4-item_name='32" HD Frameless Smart TV, DVB-T2/S2, Android +Free Wall Mount (2YRs WRTY)' data-ga4-list="productfloor_2_category:Televisions_2313_en_KE" data-ga4-price="93.35" data-ga4-tags="BLF|BLF_04|COL_317|CP_2|CP_23|CP_26|CP_MT31|CP_UN132|CP_UN246|CP_UN255|CP_UN265|JA|JF|JMALL|MSTPRF|WRNTY_2|ZF_90" data-gtm-brand="Vision Plus" data-gtm-category="Electronics/Television &amp; Video/Televisions/Smart TVs" data-gtm-dimension23="132291" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gtm-dimension37="0" data-gtm-dimension43="BLF|BLF_04|COL_317|CP_2|CP_23|CP_26|CP_MT31|CP_UN132|CP_UN246|CP_UN255|CP_UN265|JA|JF|JMALL|MSTPRF|WRNTY_2|ZF_90" data-gtm-dimension44="0" data-gtm-id="VI799EA1VZP64NAFAMZ" data-gtm-list="productfloor_2_category:Televisions_2313_en_KE" data-gtm-name='32" HD Frameless Smart TV, DVB-T2/S2, Android +Free Wall Mount (2YRs WRTY)' data-gtm-position="4" data-gtm-price="93.35" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/vision-plus-32-hd-frameless-smart-tv-dvb-t2s2-android-free-wall-mount-2yrs-wrty-125899141.html">
#              <img alt='Vision Plus 32" HD Frameless Smart TV, DVB-T2/S2, Android +Free Wall Mount (2YRs WRTY)' class="img" data-lazy="true" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/14/1998521/1.jpg?2188" height="185" src="..." width="185"/>
#              <div class="name">
#               Vision Plus 32" HD Frameless Smart TV, DVB-T2/S2, Android +Free Wall Mount (2YRs WRTY)
#              </div>
#              <div class="prc" data-oprc="KSh 20,995">
#               KSh 12,430
#              </div>
#              <div class="bdg _dsct">
#               41%
#              </div>
#             </a>
#            </article>
#           </div>
#           <div class="itm col">
#            <article class="prd _box _hvr">
# ...
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/bruhm/">
#         Bruhm
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/canon/">
#         Canon
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/cantu/">
#         Cantu
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/coke/">
#         Coke
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/dell/">
#         DELL
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/dove1/">
#         Dove
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/dr-rashel/">
#         Dr. Rashel
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/epson/">
#         Epson
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/garnier/">
#         Garnier
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/hisense/">
#         Hisense
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/hp/">
#         HP
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/infinix/">
#         Infinix
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/itel/">
#         Itel
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/jameson/">
#         Jameson
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/loreal-paris/">
#         L'Oréal Paris
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/lenovo/">
#         Lenovo
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/logitech/">
#         Logitech
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/maybelline/">
#         Maybelline
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/brand-mika/">
#         Mika
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nivea/">
#         NIVEA
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nunix/">
#         Nunix
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/oppo/">
#         Oppo
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/ramtons/">
#         Ramtons
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/roch/">
#         Roch
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/samsung/">
#         Samsung
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/sandisk/">
#         Sandisk
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/skyworth/">
#         Skyworth
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/sony/">
#         Sony
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/tcl/">
#         TCL
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/tecno/">
#         Tecno
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/transcend/">
#         Transcend
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/tusker/">
#         Tusker
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/usn/">
#         USN
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/vision-plus/">
#         Vision Plus
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/vitron/">
#         Vitron
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/von/">
#         VON
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/xiaomi/">
#         XIAOMI
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="vb row -i-ctr -j-ctr _foot _gy5 -hr -mtl">
#      <div class="col3 -df -j-start">
#      </div>
#      <div class="col10 -df -j-ctr -fs0">
#       <a class="vent-link" href="https://pay.jumia.co.ke/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=Venturebar" rel="nofollow noopener" target="_blank" title="Jumia Pay">
#        <svg class="ic" height="24" viewbox="0 0 60 24" width="60">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.2771d4ef.svg#venture-pay">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <div class="col3 -df -j-end -wt -mla">
#      </div>
#     </div>
#    </footer>
#    <div id="pop">
#     <div aria-hidden="false" aria-label="newsletter_popup_close-cta" aria-modal="true" class="popup _open _l" data-pop="" data-pop-id="newsletter" role="dialog">
#      <section aria-labelledby="pop-ttl" class="cw">
#       <button aria-label="newsletter_popup_close-cta" class="cls">
#        <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#close">
#         </use>
#        </svg>
#       </button>
#       <h2 class="ttl -vh-sr" id="pop-ttl">
#        Welcome to Jumia!
#       </h2>
#       <div class="cont _nl">
#        <div class="-df">
#         <div class="-fsh0" style="width:265px;background:url('https://ke.jumia.is/cms/2021/W15/CP/Banners/KE_Cross_0421_PU.jpg') top/cover no-repeat;">
#         </div>
#         <div class="-pvxl -phl -tac -fw">
#          <h2 class="-fs29 -phxl">
#           Welcome to Jumia!
#          </h2>
#          <div class="-ptl -phs">
#           <p class="-fs16 -m -pbxs">
#            Subscribe to our newsletter
#           </p>
#           and be the first one to know about our amazing deals
#          </div>
#          <form action="/newsletter/subscription/default/" class="-ptm -tal" data-eventaction="Subscribed" data-eventcategory="Newsletter Popup" data-eventname="newsletter_popup_submit" data-track-onnlsuccess="true" id="nl-pop-f" method="post">
#           <div class="fi-w -mhs _ic">
#            <input aria-label="E-mail" class="fi" id="fi-nl-pop-email" name="email" placeholder="Enter E-mail Address" required="" type="email" value=""/>
#            <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg#email">
#             </use>
#            </svg>
#           </div>
#           <div class="fi-w _cb -mhs">
#            <input class="cb" id="fi-nl-pop-legalText" name="legalText" required="" type="checkbox" value="1"/>
#            <label class="lbl -fs12" for="fi-nl-pop-legalText">
#             I agree to Jumia’s Privacy and Cookie Policy. You can unsubscribe from newsletters at any time.
#            </label>
#            <div class="-fw">
#             <a class="_link -or5 -fs12" href="https://www.jumia.co.ke/sp-privacy/" rel="noopener" target="_blank">
#              I accept the Legal Terms
#             </a>
#            </div>
#           </div>
#           <div class="-df -ptxs -phxs">
#            <button class="btn _prim _md -fw -mhxs" name="gender" value="male">
#             Male
#            </button>
#            <button class="btn _prim _md -fw -mhxs" name="gender" value="female">
#             Female
#            </button>
#           </div>
#           <input name="csrfToken" type="hidden" value="41d37369179de9cc5aedd9234259e0ec"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </div>
#   <script>
#    var dataLayer=[{"countryCode":"KE","language":"en","platform":"desktop","url":"/televisions/","abTests":"SearchABTest:global_last#Cart:S#SponProdPdp:A#SponProdPdpV3:B","pageType":"catalog","pageSubtype":"category","pageKey":"catalog_category","pageTitle":"Television - Buy TVs at Discounted Prices Online | Jumia Kenya","pageContentKey":"televisions","catFilterIds":"1492/2289/2313","catFilterNames":["Electronics","Television & Video","Televisions"],"sponsored":{"apiKey":"2e7f86fff8576b23d14d35b46656ebf2e55b4becb7505fc0083240688c849bf9CPM","userId":"7968639293045087077677cd16955403","pageId":"Televisions","pageType":"category"},"joinedPageType":"catalog_category","skus":["VI799EA1QMSQ4NAFAMZ","VI505EA0K42QFNAFAMZ","VI505EA1AUSHINAFAMZ","LY007EA4F5BQWNAFAMZ","HI137EA3DYZHINAFAMZ","GE840EA2A5EWFNAFAMZ","GE840EA2IZAKNNAFAMZ","VI505EA01T4Z0NAFAMZ","VI505EA2YBKINNAFAMZ","VI799EA2WDA8CNAFAMZ","VI799EA1VZP64NAFAMZ","VI505EA0FTFTQNAFAMZ","AM617EA1K3NOJNAFAMZ","VI505EA0UHR23NAFAMZ","VI505EA1R8C39NAFAMZ","VI799EA2938H8NAFAMZ","VI505EA0SM39ENAFAMZ","TC187EA46NFD1NAFAMZ","VI505EA04Y5PQNAFAMZ","VI505EA2T1A49NAFAMZ","VI505EA1E5HHONAFAMZ","VI505EA0HC3ALNAFAMZ","GL111EA4E5LRNNAFAMZ","VI799EA2KEGZ0NAFAMZ","AM617EA2AT60QNAFAMZ","VI505EA213FRENAFAMZ","VI505EA1MJRTGNAFAMZ","VI505EA1Q0QMQNAFAMZ","VI505EA40MSU8NAFAMZ","HI137EA2XA9JHNAFAMZ","AR850EA47SO89NAFAMZ","VI505EA0QJMIZNAFAMZ","TC187EA2I1514NAFAMZ","VI505EA0IZJALNAFAMZ","GL585EA1PMEQVNAFAMZ","TC187EA4FZGLZNAFAMZ","VI505EA4T9P72NAFAMZ","VI505EA0MEYBRNAFAMZ","HI200EA1XZ3PGNAFAMZ","VI505EA4AFE5ZNAFAMZ"]}];(function(w,d,s,l,i,f){function go(){w[l]=w[l]||[];w[l].push({"gtm.start":new Date().getTime(),event:"gtm.js"});f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!="dataLayer"?"&l="+l:"";j.async=true;j.src="//www.googletagmanager.com/gtm.js?id="+i+dl;j.addEventListener('load',function(){dataLayer.push({event:'pageView'});(function(){setTimeout((function(){window.dataLayer.push({event:"pageViewLvl2"}),setTimeout((function(){window.dataLayer.push({event:"pageViewLvl3"})}),500)}),500)})()});f.parentNode.insertBefore(j,f);}w.addEventListener("load",go,false);})(window,document,'script','dataLayer','GTM-KS6DC65'); w=window;d=document;s="script";w.dlGA4=w.dlGA4||[];w.gtag=function(){w.dlGA4.push(arguments);};gtag("js",new Date);gtag("config","G-SDKHD9CQ3C",{"page_location":"/televisions/","platform":"desktop","send_page_view":false,"shop_country":"KE","shop_language":"en","ab_tests":"SearchABTest:global_last#Cart:S#SponProdPdp:A#SponProdPdpV3:B","page_type":"catalog","page_subtype":"category","page_title":"category-televisions","page_content_key":"televisions"});function go(){f=d.getElementsByTagName(s)[0];j=d.createElement(s);j.async=!0;j.src="//www.googletagmanager.com/gtag/js?id=G-SDKHD9CQ3C&l=dlGA4";gtag("event","page_view");f.parentNode.insertBefore(j,f);}w.addEventListener("load",go,!1); var moeDataCenter="dc_2";!function(e,n,i,t,a,r,o,d){if(!moeDataCenter||!moeDataCenter.match(/^dc_[0-9]+$/gm))return console.error("Data center has not been passed correctly. Please follow the SDK installation instruction carefully.");var s=e[a]=e[a]||[];if(s.invoked=0,s.initialised>0||s.invoked>0)return console.error("MoEngage Web SDK initialised multiple times. Please integrate the Web SDK only once!"),!1;e.moengage_object=a;var l={},g=function n(i){return function(){for(var n=arguments.length,t=Array(n),a=0;a<n;a++)t[a]=arguments[a];(e.moengage_q=e.moengage_q||[]).push({f:i,a:t})}},u=["track_event","add_user_attribute","add_first_name","add_last_name","add_email","add_mobile","add_user_name","add_gender","add_birthday","destroy_session","add_unique_user_id","update_unique_user_id","moe_events","call_web_push","track","location_type_attribute"],m={onsite:["getData","registerCallback"]};for(var c in u)l[u[c]]=g(u[c]);for(var v in m)for(var f in m[v])null==l[v]&&(l[v]={}),l[v][m[v][f]]=g(v+"."+m[v][f]);r=n.createElement(i),o=n.getElementsByTagName("head")[0],r.async=1,r.src=t,o.appendChild(r),e.moe=e.moe|| ...
#   </script>
#   <script>
#    window.__STORE__={"view":"Catalog","activeLanguage":"en","countryCode":"KE","languages":{"en":{"text":"English","default":true}},"tracking":{"gtm":{"key":"GTM-KS6DC65","catFilterIds":"1492/2289/2313","catFilterNames":["Electronics","Television & Video","Televisions"],"sponsored":{"apiKey":"2e7f86fff8576b23d14d35b46656ebf2e55b4becb7505fc0083240688c849bf9CPM","userId":"7968639293045087077677cd16955403","pageId":"Televisions","pageType":"category"}},"ga4":{"key":"G-SDKHD9CQ3C"},"moengage":{"dataCenter":"dc_2","appId":"8UETEU0UG1ZWZOD9HUUD2RFC"},"data":{"url":"/televisions/","abTests":"SearchABTest:global_last#Cart:S#SponProdPdp:A#SponProdPdpV3:B","pageType":"catalog","pageSubtype":"category","pageKey":"catalog_category","pageTitle":"category-televisions","pageContentKey":"televisions"}},"csrfToken":"41d37369179de9cc5aedd9234259e0ec","capiId":"_1736233321_{eventType}","user":{"isGuest":true},"messages":[],"cart":{"count":0},"shop":"jumia","abTests":{"SearchABTest":"global_last","Cart":"S","SponProdPdp":"A","SponProdPdpV3":"B"},"sprites":{"icons":"https://www.jumia.co.ke/assets_he/images/i-icons.df665ea2.svg","global":"https://www.jumia.co.ke/assets_he/images/i-global.2771d4ef.svg","shop-jumia":"https://www.jumia.co.ke/assets_he/images/i-shop-jumia.9dea3b69.svg"},"liveChat":{"loadingText":"Live Chat is loading...","botImg":"https://www.jumia.co.ke/assets_he/images/bot.5beef7d8.svg"},"htmlErrors":{"valueMissing":"Required field","typeMismatch":"Invalid Information","patternMismatch":"Invalid Information","rangeOverflow":".","rangeUnderflow":"form_html-errors_range_underflow","tooLong":"Text too long","tooShort":"Text too short"},"addToCart":{"common":{"buyNowQtySelection":{"showQtySelector":true,"cartQtyIncreaseCTA":"increase cart quantity","cartQtyDecreaseCTA":"decrease cart quantity"}},"default":{"buyNowCTA":"Add to cart","buyNowQtySelection":{"showQtySelector":true,"cartQtyIncreaseCTA":"increase cart quantity","cartQtyDecreaseCTA":"decrease cart quantity"},"isXhr":true}},"popups":{"addToCart":{"data":{"buyNowCTA":"Add to cart","buyNowQtySelection":{"showQtySelector":true,"cartQtyIncreaseCTA":"increase cart quantity","cartQtyDecreaseCTA":"decrease cart quantity"},"unavailableText":"Currently unavailable","viewUrl":"/cart/","continueCTA":"Continue Shopping","viewCTA":"Go to Cart","popupTitle":"Please select a variation","closeCTA":"close popup"},"template":"AddToCart"},"filters":{"dynData":{"1":{"title":"Jumia Express","markup":"<div class=\"markup\">JUMIA <span style=\"color:#ff9900\">Express</span> \nFor all the products indicated as <b>'-Enjoy free delivery around Nairobi , Kiambu &amp; Mombasa for all Jumia Express' </b>, benefit from:\n<br/>\n<br/>\n- Free delivery on orders above <b> KES 1999 </b> in Nairobi, Kiambu and Mombasa Only\n<br/>\n-Next day delivery in Nairobi &amp; Kiambu if you order before 5pm.\n<br/>\n<br/>\nFree delivery offer is not valid for bulky items.\n<br/>\nClick  <a href=\"https://www.jumia.co.ke/sp-jumia-express/\" style=\"font-weight:bold;\">here</a> to get more details </div>"}}},"addToWishlist":{"data":{"title":"Please select a variation","wishlistCTA":"Add to wishlist","isLinkButton":true,"formUrl":"/wishlist/add/"},"template":"AddToWishlist"},"newsletter":{"data":{"title":"Welcome to Jumia!","closeCTA":"newsletter_popup_close-cta"},"trackingData":{"popupView":{"type":"Newsletter"},"popupClose":{"type":"Newsletter"}},"template":"Default","shouldOpen":true,"size":"L","hideTitle":true}},"products":[{"sku":"VI799EA1QMSQ4NAFAMZ","name":"32\" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)","displayName":"Vision Plus 32\" Digital HD Frameless TV, DVBT2/S2 - Black (2YRS WRTY)","brand":"Vision Plus","sellerId":132291,"isShopExpress":true,"categories":["Electronics","Television & Video","Televisions","Digital TVs"],"prices":{"rawPrice":"9999.00","price":"KSh 9,999","priceEuro":"74.23","taxEuro":"0.00","oldPrice":"KSh 15,995","oldPriceEuro":"118.73","discount":"37%","discountEuro":"44.51"},"tags":" ...
#   </script>
#   <script crossorigin="" src="https://www.jumia.co.ke/assets_he/js/common.bb66a7b8.js" type="module">
#   </script>
#   <script crossorigin="" src="https://www.jumia.co.ke/assets_he/js/pages/catalog/index.4407cdd0.js" type="module">
#   </script>
#   <script nomodule="" src="https://www.jumia.co.ke/assets_he/js/common.es5.7272f156.js">
#   </script>
#   <script nomodule="" src="https://www.jumia.co.ke/assets_he/js/pages/catalog/index.es5.eaf31bdd.js">
#   </script>
#  </body>
# </html>
