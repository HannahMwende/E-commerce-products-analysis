# %% [markdown]
# ## Laptops Data.

# %%
# Import libraries
import pandas as pd
import re

# %%
# Data loading
laptops_df = pd.read_csv("./csv_files/laptops.csv")
laptops_df.head()
# Out:
#                                                 Name       Price  \
# 0  HP  Refurbished EliteBook 640GB HDD, 8GB RAM, ...  KSh 20,300
# 1  HP Refurbished EliteBook 820 Core I5, 8GB RAM ...  KSh 16,499
# 2  Lenovo ThinkPad T490 Touchscreen Core I5 -8th ...  KSh 27,999
# 3  HP Refurbished EliteBook 840 G3 Intel Core I5 ...  KSh 23,500
# 4  HP GAMING-LAPTOP -HP ELITEBOOK 755 AMD RYZEN 7...  KSh 35,000
#
#             Reviews       Ratings
# 0  3.7 out of 5(13)  3.7 out of 5
# 1     5 out of 5(1)    5 out of 5
# 2     4 out of 5(9)    4 out of 5
# 3     4 out of 5(1)    4 out of 5
# 4   4.4 out of 5(9)  4.4 out of 5

# %%
# Cleaning laptops data
# Extract brand name
def extract_brand(name):
    match = re.search(r'(HP|Lenovo|Dell|Acer|)', name, re.IGNORECASE)
    return match.group(0) if match else 'Unknown'

# Extract RAM
def extract_ram(name):
    match = re.search(r'(\d+GB)\s*RAM', name)
    return match.group(1) if match else 'Unknown'

# Extract ROM (HDD/SSD)
def extract_rom(name):
    match = re.search(r'(\d+GB|TB)\s*(HDD|SSD)', name)
    return match.group(0) if match else 'Uknown'

# Extract processor type
def extract_processor(name):
    match = re.search(r'Intel\s*(Core\s*I\d)', name)
    return match.group(1) if match else 'Unknown'
                    
def extract_screen_size(name):
    match = re.search(r'(\d+\.?\d*)"\s*', name)
    return match.group(1) if match else 'Unknown'

# Extract the price from the 'Price' column
def extract_price(price):
    match = re.search(r'KSh\s*(\d+([,]\d{3})*)', price)
    if match:
        return float(match.group(1).replace(',', ''))
    return None

# Extract reviews 
def extract_reviews(reviews):
    match = re.search(r'\((\d+)\)', reviews)
    if match:
        return int(match.group(1))
    return None

# Extract ratings (the number before "out of 5")
def extract_ratings(ratings):
    match = re.search(r'(\d+\.\d+)', ratings)
    if match:
        return float(match.group(1))
    return None

# Apply extraction functions to the DataFrame
laptops_df['Brand'] = laptops_df['Name'].apply(extract_brand)
laptops_df['RAM'] = laptops_df['Name'].apply(extract_ram)
laptops_df['ROM'] = laptops_df['Name'].apply(extract_rom)
laptops_df['Processor'] = laptops_df['Name'].apply(extract_processor)
laptops_df['Screen_Size'] = laptops_df['Name'].apply(extract_screen_size)
laptops_df['Price'] = laptops_df['Price'].apply(extract_price)
laptops_df['Reviews'] = laptops_df['Reviews'].apply(extract_reviews)
laptops_df['Ratings'] = laptops_df['Ratings'].apply(extract_ratings)

# Create the new DataFrame with the extracted data
cleaned_data = laptops_df[['Name','Brand', 'RAM', 'ROM', 'Processor', 'Screen_Size', 'Price','Reviews','Ratings']]

# Save the cleaned data to a new CSV file
cleaned_data.to_csv('./csv_files/laptops_clean.csv', index=False)

# %%
laptops = pd.read_csv("./csv_files/laptops_clean.csv")
laptops.head(50)
# Out:
#                                                  Name   Brand      RAM  \
# 0   HP  Refurbished EliteBook 640GB HDD, 8GB RAM, ...      HP      8GB
# 1   HP Refurbished EliteBook 820 Core I5, 8GB RAM ...      HP      8GB
# 2   Lenovo ThinkPad T490 Touchscreen Core I5 -8th ...  Lenovo      8GB
# 3   HP Refurbished EliteBook 840 G3 Intel Core I5 ...      HP  Unknown
# 4   HP GAMING-LAPTOP -HP ELITEBOOK 755 AMD RYZEN 7...      HP     16GB
# 5   HP Refurbished EliteBook 8460p Core I5, 4GB Ra...      HP  Unknown
# 6   Lenovo Refurbished 8GB RAM, 500GB Hard Disk, X...  Lenovo      8GB
# 7   HP EliteBook 840 G4 Intel Core I7 7Th Gen,16GB...      HP  Unknown
# 8   Lenovo Refurbished Thinkpad X250 Intel Core I5...  Lenovo  Unknown
# 9   Lenovo Refurbished Thinkpad X240 Intel Core I5...  Lenovo  Unknown
# 10  HP Refurbished EliteBook 820, Intel Core I5, S...      HP      8GB
# 11  HP Refurbished Elitebook 840 G5 8th Generation...      HP      8GB
# 12  Lenovo ThinkPad X390 Core i5-8th Gen 8GB Ram 2...  Lenovo  Unknown
# 13  DELL Latitude 7280, Core I5 8GB RAM 256GB SSD,...    DELL      8GB
# 14  HP EliteBook 820 G3 Core I5 8GB-256GB SSD 6th ...      HP  Unknown
# 15  HP Refurbished Elitebook 840   Touchscreen Cor...      HP      8GB
# 16  HP Refurbished EliteBook RAM 8GB HDD 500GB Cor...      HP  Unknown
# 17  Lenovo Refurbished Thinkpad X250 Intel Core I5...  Lenovo  Unknown
# 18  HP EliteBook 820  Core I5 8GB RAM 512gb SSD Sl...      HP      8GB
# 19  Lenovo IdeaPad 1, Intel Celeron N4020, 8GB RAM...  Lenovo      8GB
# 20  HP Refurbished Elitebook 840 G3 6th Gen , Core...      HP      8GB
# 21  HP EliteBook 820  Core I7 8GB RAM 1TB Slim Ult...      HP      8GB
# 22  HP Refurbished EliteBook 8460p Core I5 - HDD 5...      HP      4GB
# 23  HP EliteBook 820 G3 Intel Core I7 6th Gen 8GB ...      HP      8GB
# 24  HP Refurbished Elitebook 820 G3 6th Gen , Core...      HP     16GB
# 25  Lenovo Thinkpad Refurbished ThinkPad Yoga 11e ...  Lenovo      4GB
# 26  HP Refurbished Elitebook 840 G3 6th Gen , Core...      HP      8GB
# 27  Lenovo  Refurbished ThinkPad Yoga 11e Intel Ce...  Lenovo      8GB
# 28  Lenovo Refurbished ThinkPad Yoga 11e X360 Inte...  Lenovo      4GB
# 29  HP Refurbished EliteBook 840, Intel Core I5, 1...      HP      4GB
# 30  HP  Refurbished Elitebook 840 G5 8th Generatio...      HP     16GB
# 31  HP Refurbished Elitebook 820 G3 Core I5 8GB RA...      HP      8GB
# 32  Lenovo Refurbished Thinkpad X131e 12" Intel Ce...  Lenovo  Unknown
# 33  HP Refurbished ProBook 640 G1 Core I5 4th Gen ...      HP      8GB
# 34  HP EliteBook 840 G4 Intel Core I7 7Th Gen,8GB ...      HP  Unknown
# 35  Lenovo REFURBISHED THINKPAD YOGA 11E 4 GB RAM,...  Lenovo  Unknown
# 36  HP  Refurbished EliteBook 640GB HDD, 8GB RAM, ...      HP      8GB
# 37  HP Refurbished EliteBook 820 Core I5, 8GB RAM ...      HP      8GB
# 38  Lenovo ThinkPad T490 Touchscreen Core I5 -8th ...  Lenovo      8GB
# 39  HP Refurbished EliteBook 840 G3 Intel Core I5 ...      HP  Unknown
# 40  HP GAMING-LAPTOP -HP ELITEBOOK 755 AMD RYZEN 7...      HP     16GB
# 41  HP Refurbished EliteBook 8460p Core I5, 4GB Ra...      HP  Unknown
# 42  Lenovo Refurbished 8GB RAM, 500GB Hard Disk, X...  Lenovo      8GB
# 43  HP EliteBook 840 G4 Intel Core I7 7Th Gen,16GB...      HP  Unknown
# 44  Lenovo Refurbished Thinkpad X250 Intel Core I5...  Lenovo  Unknown
# 45  Lenovo Refurbished Thinkpad X240 Intel Core I5...  Lenovo  Unknown
# 46  HP Refurbished EliteBook 820, Intel Core I5, S...      HP      8GB
# 47  HP Refurbished Elitebook 840 G5 8th Generation...      HP      8GB
# 48  Lenovo ThinkPad X390 Core i5-8th Gen 8GB Ram 2...  Lenovo  Unknown
# 49  DELL Latitude 7280, Core I5 8GB RAM 256GB SSD,...    DELL      8GB
#
#           ROM Processor Screen_Size    Price  Reviews  Ratings
# 0   640GB HDD   Core I5     Unknown  20300.0       13      3.7
# 1   500GB HDD   Unknown     Unknown  16499.0        1      NaN
# 2   256GB SSD   Unknown          14  27999.0        9      NaN
# 3   500GB HDD   Core I5     Unknown  23500.0        1      NaN
# 4   256GB SSD   Unknown     Unknown  35000.0        9      4.4
# 5   500GB HDD   Unknown     Unknown  13999.0        2      NaN
# 6      Uknown   Unknown     Unknown  14999.0        1      NaN
# 7   256GB SSD   Core I7     Unknown  39449.0        7      4.3
# 8      Uknown   Core I5     Unknown  14999.0       11      3.7
# 9      Uknown   Core I5     Unknown  14999.0        2      4.5
# 10     Uknown   Core I5        12.5  17499.0        4      NaN
# 11  256GB SSD   Unknown     Unknown  28999.0        1      NaN
# 12  256GB SSD   Unknown     Unknown  24999.0        2      NaN
# 13  256GB SSD   Unknown        12.5  19499.0       21      4.7
# 14  256GB SSD   Unknown        12.5  20000.0       20      3.8
# 15     Uknown   Unknown          14  19999.0        5      4.6
# 16    8GB HDD   Unknown          14  18999.0       10      4.1
# 17     Uknown   Core I5     Unknown  15999.0        7      3.9
# 18     Uknown   Unknown     Unknown  21999.0        4      NaN
# 19  256GB SSD   Unknown          14  31999.0        1      NaN
# 20     Uknown   Unknown          14  24999.0       17      3.5
# 21     Uknown   Unknown     Unknown  25998.0        2      NaN
# 22     Uknown   Unknown          14  13499.0       58      3.8
# 23  256GB SSD   Core I7     Unknown  29000.0        6      4.7
# 24     Uknown   Unknown        12.5  29499.0        3      NaN
# 25     Uknown   Unknown        11.6  12000.0        8      3.9
# 26     Uknown   Unknown          14  24000.0        1      NaN
# 27  500GB HDD   Unknown     Unknown  16500.0       14      4.1
# 28     Uknown   Unknown        11.6  13989.0       46      3.8
# 29     Uknown   Core I5          14  16999.0        5      3.2
# 30     Uknown   Unknown          14  32000.0        1      NaN
# 31  500GB HDD   Unknown        12.5  21000.0        1      NaN
# 32     Uknown   Unknown          12  12899.0       29      NaN
# 33     Uknown   Unknown     Unknown  15299.0        1      NaN
# 34  256GB SSD   Core I7     Unknown  33949.0        3      3.7
# 35     Uknown   Unknown     Unknown  12050.0       46      3.4
# 36  640GB HDD   Core I5     Unknown  20300.0       13      3.7
# 37  500GB HDD   Unknown     Unknown  16499.0        1      NaN
# 38  256GB SSD   Unknown          14  27999.0        9      NaN
# 39  500GB HDD   Core I5     Unknown  23500.0        1      NaN
# 40  256GB SSD   Unknown     Unknown  35000.0        9      4.4
# 41  500GB HDD   Unknown     Unknown  13999.0        2      NaN
# 42     Uknown   Unknown     Unknown  14999.0        1      NaN
# 43  256GB SSD   Core I7     Unknown  39449.0        7      4.3
# 44     Uknown   Core I5     Unknown  14999.0       11      3.7
# 45     Uknown   Core I5     Unknown  14999.0        2      4.5
# 46     Uknown   Core I5        12.5  17499.0        4      NaN
# 47  256GB SSD   Unknown     Unknown  28999.0        1      NaN
# 48  256GB SSD   Unknown     Unknown  24999.0        2      NaN
# 49  256GB SSD   Unknown        12.5  19499.0       21      4.7

# %% [markdown]
# ## Fridges Data

# %%
# Fridges data
df = pd.read_csv("./csv_files/fridges.csv")
df.head(5)
# Out:
#                                                 Name       Price  \
# 0  Ramtons RF/335 - 85L Single Door Refrigerator ...  KSh 15,999
# 1  Hisense 94 Liters Single Door Fridge REF094DR ...  KSh 16,799
# 2  Ramtons RF/203, 2 Door Direct Cool Fridge, 128...  KSh 28,099
# 3  Roch RFR-120S-I Single Door Refrigerator - 90 ...  KSh 16,299
# 4  Nunix 138L Double Door Fridge Energy Efficient...  KSh 27,500
#
#              Reviews       Ratings
# 0   4.1 out of 5(66)  4.1 out of 5
# 1   4.4 out of 5(87)  4.4 out of 5
# 2   4.2 out of 5(69)  4.2 out of 5
# 3  4.2 out of 5(477)  4.2 out of 5
# 4  3.9 out of 5(149)  3.9 out of 5

# %%
# Extract brand name and model.
def extract_brand_and_model(name):
    match = re.match(r"([A-Za-z]+(?: [A-Za-z]+)*)(?:\s[RF|REF|FM|DF|D|]{2,4}[\d]+)?", name)
    if match:
        return match.group(1).strip()
    return ''

# Extract size in litres
def extract_size(name):
    match = re.search(r'(\d+)\s*Litres?', name)
    if match:
        return int(match.group(1))
    return None

# Extract number of doors
def extract_doors(name):
    match = re.search(r'(\d+)\s*Door', name)
    if match:
        return int(match.group(1))
    return None

# Extract color
def extract_color(name):
    color_keywords = ['Silver', 'White', 'Black', 'Grey', 'Red', 'Blue', 'Green', 'Beige', 'Stainless', 'Chrome']
    for color in color_keywords:
        if color.lower() in name.lower():
            return color
    return None

# Extract warranty
def extract_warranty(name):
    match = re.search(r'(\d+)\s*YRs?\s*WRTY', name)
    if match:
        return int(match.group(1))
    return None

# Extract the price from the 'Price' column
def extract_price(price):
    match = re.search(r'KSh\s*(\d+([,]\d{3})*)', price)
    if match:
        return float(match.group(1).replace(',', ''))
    return None

# Extract reviews 
def extract_reviews(reviews):
    match = re.search(r'\((\d+)\)', reviews)
    if match:
        return int(match.group(1))
    return None

# Extract ratings (the number before "out of 5")
def extract_ratings(ratings):
    match = re.search(r'(\d+\.\d+)', ratings)
    if match:
        return float(match.group(1))
    return None

# Apply the extraction functions to the DataFrame
df['Brand'] = df['Name'].apply(extract_brand_and_model)
df['Size(Litres)'] = df['Name'].apply(extract_size)
df['Doors'] = df['Name'].apply(extract_doors)
df['Color'] = df['Name'].apply(extract_color)
df['Warranty(Years)'] = df['Name'].apply(extract_warranty)
df['Price'] = df['Price'].apply(extract_price)
df['Reviews'] = df['Reviews'].apply(extract_reviews)
df['Ratings'] = df['Ratings'].apply(extract_ratings)

data = df[['Name', 'Brand', 'Size(Litres)','Doors', 'Color', 'Warranty(Years)', 'Price', 'Reviews', 'Ratings']]

# Save the modified DataFrame to a new CSV file
data.to_csv('./csv_files/fridges_clean.csv', index=False)

print("Data extraction and CSV creation completed successfully!")
# Out:
# Data extraction and CSV creation completed successfully!

# %%
clean_df = pd.read_csv("./csv_files/fridges_clean.csv")
clean_df.head(100)
# Out:
#                                                  Name          Brand  \
# 0   Ramtons RF/335 - 85L Single Door Refrigerator ...     Ramtons RF
# 1   Hisense 94 Liters Single Door Fridge REF094DR ...        Hisense
# 2   Ramtons RF/203, 2 Door Direct Cool Fridge, 128...     Ramtons RF
# 3   Roch RFR-120S-I Single Door Refrigerator - 90 ...       Roch RFR
# 4   Nunix 138L Double Door Fridge Energy Efficient...          Nunix
# ..                                                ...            ...
# 95  Smart Pro SFR 175-DT-I Double Door Refrigerato...  Smart Pro SFR
# 96  Ramtons RF/257- 2 Door Direct Cool Fridge - 21...     Ramtons RF
# 97  Hisense RS-12DR4SA Single Door Direct Cool Fri...     Hisense RS
# 98  Roch RFR-150DT-I Top-Mounted Defrost Fridge - ...       Roch RFR
# 99  Ramtons RF/174 - 2 Door Direct Cool Fridge - 1...     Ramtons RF
#
#     Size(Litres)  Doors   Color  Warranty(Years)    Price  Reviews  Ratings
# 0            NaN    NaN  Silver              1.0  15999.0       66      4.1
# 1            NaN    NaN     NaN              2.0  16799.0       87      4.4
# 2          128.0    2.0  Silver              1.0  28099.0       69      4.2
# 3           90.0    NaN  Silver              NaN  16299.0      477      4.2
# 4            NaN    NaN     NaN              1.0  27500.0      149      3.9
# ..           ...    ...     ...              ...      ...      ...      ...
# 95           NaN    NaN  Silver              1.0  27299.0        1      NaN
# 96         213.0    2.0  Silver              1.0  46900.0       41      4.8
# 97           NaN    NaN  Silver              2.0  21239.0       50      4.6
# 98           NaN    NaN     NaN              1.0  27699.0       39      4.1
# 99         128.0    2.0   White              1.0  29500.0       58      4.3
#
# [100 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Name                 0
# Price                0
# Reviews              0
# Ratings            230
# Brand                0
# Size(Liters)       926
# Doors              868
# Color              433
# Warranty(Years)    201
# dtype: int64
